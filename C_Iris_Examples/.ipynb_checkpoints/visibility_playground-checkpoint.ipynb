# %%
from iris_helpers import sorted_vertices
import numpy as np
import matplotlib.pyplot as plt
from pydrake.geometry.optimization import (
    HPolyhedron, VPolytope, Iris, IrisOptions)
from functools import partial

# %%
iris_options = IrisOptions()
iris_options.require_sample_point_is_contained = True
iris_options.iteration_limit = 5
iris_options.termination_threshold = -1
iris_options.relative_termination_threshold = 0.05

dim = 2
domain = HPolyhedron.MakeBox([-10.] * dim, [10.] * dim)

def iris_mut_env(seed, obstacles, domain, iris_options):
    return Iris(obstacles, seed, domain, iris_options)

iris_handle_env = partial(iris_mut_env,
                      domain = domain, 
                      iris_options = iris_options)

# %%
from pydrake.geometry.optimization import IrisMultiContainment

# %%
def switch_ellipse_description(A, b):
    d = np.linalg.solve(A.T@A, -A.T@b)
    return Hyperellipsoid(A,d), A, d

def get_lj_ellipse(pts, eps = 0.01):
    dim = pt1.shape[0]
    prog = MathematicalProgram()
    A = prog.NewSymmetricContinuousVariables(dim, 'A')
    b = prog.NewContinuousVariables(dim, 'b')
    prog.AddMaximizeLogDeterminantCost(A)
    for idx, pt in enumerate(pts):
        S = prog.NewSymmetricContinuousVariables(dim+1, 'S')
        prog.AddPositiveSemidefiniteConstraint(S)
        prog.AddLinearEqualityConstraint(S[0,0] == 1)
        v = (A@pt + b.reshape(2,1)).T
        c = (S[1:,1:]-np.eye(dim)).reshape(-1)
        for idx in range(dim):
            prog.AddLinearEqualityConstraint(S[0,1 + idx]-v[0,idx], 0 )
        for ci in c:
            prog.AddLinearEqualityConstraint(ci, 0 )

    prog.AddPositiveSemidefiniteConstraint(A)

    sol = Solve(prog)
    if sol.is_success():
        return switch_ellipse_description(sol.GetSolution(A), sol.GetSolution(b))
    else:
        return None, None, None
    
def plot_ellipse(ax, A, center, n_samples):
    angs = np.linspace(0, 2*np.pi, n_samples+1)
    coords = np.zeros((2, n_samples + 1))
    coords[0, :] = np.cos(angs)
    coords[1, :] = np.sin(angs)
    Bu = np.linalg.inv(A)@coords
    pts = Bu + center.reshape(2,1)
    ax.plot(pts[0, :], pts[1, :], linewidth = 1)

# %%
#generate random Polytope
def generate_random_poly(sa = 10, sb = 1):
    dim = 2
    maxsize = HPolyhedron.MakeBox([-10.] * dim, [10.] * dim)
    A = []
    b = []
    ax = np.random.uniform(1, sa)
    bx = np.random.uniform(0.5, sb)
    rot = np.random.uniform(0, np.pi)
    rmat =np.array([[np.cos(rot), -np.sin(rot)], [np.sin(rot), np.cos(rot)]])
    E = rmat@np.array([[ax, 0], [0, bx]]) @rmat.T

    Einv = np.linalg.inv(E)
    numfaces = np.random.choice(8) + 7
    for idx in range(numfaces):
        a = np.random.uniform(0, 2*np.pi)
        dirrand = np.array([np.cos(a), np.sin(a)])
        A.append(Einv@dirrand)
        b.append(1.0)

    a = np.random.uniform(0, 2*np.pi)
    mag = np.random.uniform(0, 9)
    dirrand = np.array([np.cos(a), np.sin(a)])*mag 
    reg = HPolyhedron(np.array(A), np.array(b)+ np.array(A)@dirrand)
    region = maxsize.Intersection(reg)
    pts = np.array([E@np.array([np.cos(alph), np.sin(alph)]) + dirrand for alph in np.linspace(0,2*np.pi, 50)])
    return region, E, dirrand, pts

region, Ell, shift, pts = generate_random_poly()

fig, ax = plt.subplots()
ax.plot([-10, 10, 10, -10, -10], [-10, -10, 10, 10, -10], 'k')
ax.plot(pts[:,0], pts[:,1])
vert = sorted_vertices(VPolytope(region))
vert = np.hstack((vert, vert[:, :1]))
ax.plot(vert[0], vert[1], c = 'r')
ax.scatter([0],[0], c = 'k', s = 10)
ax.axis('equal')
# Out:
# (-11.006009230683865, 11.12619384436114, -11.0, 11.0)

# %%
# generate environment
np.random.seed(26)
def generate_cfree(N): 
    region, Ell, shift, pts = generate_random_poly(sa = 10, sb = 0.9)
    regions = [region]
    for idx in range(N):
        while True:
            terminate = False
            r, E, dx, pts = generate_random_poly()
            for r2 in regions:
                if r.IntersectsWith(r2):
                    terminate = True
                    break
            if terminate:
                break
        regions.append(domain.Intersection(r))
    return regions
regions = generate_cfree(7)

def get_colliding_pt(cfree, obstacles):
    regs = cfree + obstacles
    good_sample = False #(not self.col_handle(pos_samp)) 
    for idx in range(10000):
        rand = np.random.rand(2)
        pos_samp = np.array([-10, -10]) + rand*np.array([20, 20])
        pt_inregions = False
        for r in regs:
            if r.PointInSet(pos_samp):
                pt_inregions = True
                break
        if not pt_inregions:
            return pos_samp
    return None

tries = 0
ret  = 0
obstacle_regions = []
while True:
    ret = get_colliding_pt(cfree = regions, obstacles = obstacle_regions)
    if ret is not None:
        obstacle_regions.append(iris_handle_env(ret, regions+obstacle_regions))
        #print('adding region')
    else:
        break    

def plot_env(ax, regions, obstacle_regions):
    ax.plot([-10, 10, 10, -10, -10], [-10, -10, 10, 10, -10], 'k', linewidth = 5)
    #ax.fill([-10, 10, 10, -10, -10], [-10, -10, 10, 10, -10], 'r', alpha = 0.5)
    
    #ax.plot(pts[:,0], pts[:,1])
    for r in regions:
        vert = sorted_vertices(VPolytope(r))
        vert = np.hstack((vert, vert[:, :1]))

        for idx in range(vert.shape[1]-1):
            #print('newvert')

            a = vert[:,idx]
            b = vert[:,idx+1]
            dist = np.linalg.norm(a-b)
            tval = np.linspace(0,1, int(dist*30)+20)
            piece = []
            for t in tval:
                pt = a*(1-t) + b * t
                in_other = False
                for r2 in regions:
                    if r2 != r and r2.PointInSet(pt):
                        in_other = True
                        break 

                if not in_other:
                    piece.append(pt)
            if len(piece):
                pts = np.array(piece)
                #ax.scatter(pts[:,0], pts[:,1])
                spacing = 1/50 *np.linalg.norm(a-b)

                curr_piece = [piece[0]]
                prev_draw = True
                for pt_idx in range(len(piece)-1):
                    b = piece[pt_idx+1]
                    a = piece[pt_idx]
                    close = np.linalg.norm(a-b)<1.5*spacing
                    if close:
                        curr_piece = [a, b]
                        pts = np.array(curr_piece)
                        #print('drawing')
                        #ax.plot(pts[:,0], pts[:,1], linewidth = 5, c = 'k', alpha = 0.6)#@, alpha = 0.8)
        #ax.fill(vert[0], vert[1], c = 'w')
        ax.plot(vert[0], vert[1],linewidth = 1, linestyle = 'dashed',alpha = 0.9)
        
    #ax.scatter([0],[0], c = 'k', s = 10)
    for r in obstacle_regions:
        vert = sorted_vertices(VPolytope(r))
        vert = np.hstack((vert, vert[:, :1]))
        ax.fill(vert[0], vert[1], c = 'b', alpha = 0.5)
        ax.plot(vert[0], vert[1], c = 'k')
        
fig, ax = plt.subplots(figsize = (10,10))     
plot_env(ax, regions, obstacle_regions)
ax.axis('equal')
# Out:
# (-11.0, 11.0, -11.0, 11.0)

# %%
def rand_point_in_regs(cfree_regs):
    good_sample = False #(not self.col_handle(pos_samp)) 
    mindist = np.array([-10, -10])
    minmaxdiff = np.array([20, 20])
    for idx in range(10000):
        rand = np.random.rand(2)
        pos_samp = mindist + rand*minmaxdiff
        pt_inregions = False
        for r in cfree_regs:
            if r.PointInSet(pos_samp):
                pt_inregions = True
                break
        if pt_inregions:
            return pos_samp
    return None

def point_in_regions(pt, regions): 
    for r in regions:
        if r.PointInSet(pt):
            return True
    return False 

def collision(pt, obs, eps = 0.3):
    for r in obs:
        for idx in range(10):
            p = pt + eps*(np.random.rand(dim)-0.5)
            if r.PointInSet(p):
                return True
    return False

col_handle = partial(collision, obs=obstacle_regions)

def is_los(q1, q2, cfree, domain):
    if not domain.PointInSet(q1) or not domain.PointInSet(q2):
        return False, []
    tval = np.linspace(0,1, 40)
    for t in tval:
        pt = (1-t)*q1 + t* q2
        if not point_in_regions(pt, cfree):
            return False, []
    return True, []

los_handle = partial(is_los, cfree = regions, domain = domain)

iris_options = IrisOptions()
iris_options.require_sample_point_is_contained = True
iris_options.iteration_limit = 5
iris_options.termination_threshold = -1
iris_options.relative_termination_threshold = 0.05

dim = 2
domain = HPolyhedron.MakeBox([-10.] * dim, [10.] * dim)

def iris_mut(seed, obstacles, domain, iris_options):
    return Iris(obstacles, seed, domain, iris_options)

iris_handle = partial(iris_mut, obstacles = obstacle_regions,
                      domain = domain, 
                      iris_options = iris_options)

#treat other regions as obstacles 
def morph_iris2(pt, regions, obstacles, domain, options):
    obs = [o for o in obstacles]
    for r in regions:
        offset = 0.25*np.min(1/np.linalg.eig(r.MaximumVolumeInscribedEllipsoid().A())[0])
        rnew = HPolyhedron(r.A(), r.b()-offset)
        obs.append(rnew)
    return Iris(obs, pt, domain, iris_options)

iris_handle2 = partial(morph_iris2, 
                      obstacles = obstacle_regions, 
                      domain = domain, 
                      options = iris_options)   

def get_cover_est(cover, cfree, N = 10000):
    ntot = 0
    for idx in range(N):
        pt=rand_point_in_regs(cfree)
        if point_in_regions(pt, cover):
            ntot +=1
    return ntot*1.0/N

# %%
def generate_env_and_helperfunctions(seed):
    np.random.seed(seed)
    cfreepieces = np.random.randint(4,7)
    regions = generate_cfree(cfreepieces)
    tries = 0
    ret  = 0
    obstacle_regions = []
    while True:
        ret = get_colliding_pt(cfree = regions, obstacles = obstacle_regions)
        if ret is not None:
            obstacle_regions.append(iris_handle_env(ret, regions+obstacle_regions))
            #print('adding region')
        else:
            break 
    col_handle = partial(collision, obs=obstacle_regions)
    los_handle = partial(is_los, cfree = regions, domain = domain)
    iris_handle = partial(iris_mut, obstacles = obstacle_regions,
                      domain = domain, 
                      iris_options = iris_options)
    iris_handle2 = partial(morph_iris2, 
                      obstacles = obstacle_regions, 
                      domain = domain, 
                      options = iris_options)
    return regions, obstacle_regions, col_handle, los_handle, iris_handle, iris_handle2

# %%
import networkx as nx
def refine_guards1(vs):
    to_split = []
    for goi in vs.guard_regions:
        ker = []
        for sampdat in vs.samples_outside_regions.values():
            pos = sampdat[0]
            vis = [vs.regions.index(rviz) for rviz in sampdat[1]]
            if len(vis)==1 and vis[0] == goi:
                ker.append(pos)
        targ_seed = vs.seed_points[goi]
        g1,g2 = None, None
        if len(ker) >10:
            found = False
            for idx, k1 in enumerate(ker[:-1]):
                for k2 in ker[idx:]:
                    #print('a')
                    if not los_handle(k1, k2)[0]:
                        g1 = k1
                        g2 = k2
                        found = True
                        break
                if found:
                    break
        ker = np.array(ker)
        #sample_set = np.array(sample_set)
        #print(len(ker))
        #print(g1,g2)
        if g1 is not None:
            to_split.append([goi, targ_seed, ker, g1, g2])
            print('[VPRMSeeding] Guard found to split')
            return to_split
    print('[VPRMSeeding] No guard to split')
    return to_split
    
def refine_guards2(vs, to_split):
    print('[VPRMSeeding] N = ', len(to_split), ' guards to split')
    if len(to_split):
        print('[VPRMSeeding] Splitting guard ')
        goi, targ_seed, ker, g1, g2 = to_split[0]
        #generate new regions
        r1 = iris_handle(g1)
        r2 = iris_handle(g2)
        vs.regions += [r1, r2]
        #vs.guard_regions += [vs.regions.index(r) for r in [r1,r2]]
        vs.seed_points += [g1, g2]
        r_old = vs.regions[goi]
        keys_to_del = []
        for s_key in vs.samples_outside_regions.keys():
            vis_regs = vs.samples_outside_regions[s_key][1] 
            if r_old in vis_regs:
                vis_regs.remove(r_old)
            s_Q = vs.samples_outside_regions[s_key][0]
            if vs.need_to_convert_samples:
                s_conv = self.point_to_region_space(s_Q)
            else:
                s_conv = s_Q 
            #if r1.PointInSet(s_conv.reshape(-1,1)):
            #    keys_to_del.append(s_key)
            #if r2.PointInSet(s_conv.reshape(-1,1)):
            #    keys_to_del.append(s_key)
            if vs.is_in_line_of_sight(s_Q.reshape(-1,1), g1.reshape(-1,1))[0]:
                vis_regs.append(r1)
            if vs.is_in_line_of_sight(s_Q.reshape(-1,1), g2.reshape(-1,1))[0]:
                vis_regs.append(r2)
        for k in keys_to_del:
            del vs.samples_outside_regions[k]
        del vs.seed_points[goi]
        del vs.regions[goi]
    vs.guard_regions = [vs.regions.index(r) for r in vs.regions]
    vs.connectivity_graph = nx.Graph()
    for idx in range(len(vs.guard_regions)):
        vs.connectivity_graph.add_node(idx)

    for idx1 in range(len(vs.guard_regions)):
        for idx2 in range(idx1 +1, len(vs.guard_regions)):
            r1 = vs.regions[idx1]
            r2 = vs.regions[idx2]
            if r1.IntersectsWith(r2):
                vs.connectivity_graph.add_edge(idx1,idx2)

# %%
# investigating using the kernel to grow regions
from visprm import VPRMSeeding
#poi = [np.array([-6, 0]), np.array([0, 8]), np.array([4, -7.5])]
#np.random.seed(12)
seed = 20
regions, obstacle_regions, col_handle, los_handle, iris_handle, iris_handle2 = generate_env_and_helperfunctions(seed)
vs = VPRMSeeding([],
                 alpha = 0.05,
                 eps = 0.05,
                 limits = [np.array([-10.] * dim), np.array([10.] * dim)],# [lb, ub],
                 collision_handle = col_handle,
                 is_in_line_of_sight = los_handle, 
                 iris_handle=iris_handle,
                 iris_handle_with_obstacles = iris_handle2,
                 )
# Out:
# [00:09:19] [VPRMSeeding] Expecting points of interest in q
# [00:09:19] [VPRMSeeding] GuardInsertion attempts M: 58
# [00:09:19] [VPRMSeeding] 0.95 probability that unseen region is less than 5.0 "%" of Cfree

# %%
vs.guard_phase()
# Out:
# [00:09:19] [VPRMSeeding] New guard placed N =  0 it =  0
# [00:09:20] [VPRMSeeding] Sample set size 0
# [00:09:20] [VPRMSeeding] New guard placed N =  1 it =  2
# [00:09:21] [VPRMSeeding] Sample set size 1
# [00:09:21] [VPRMSeeding] New guard placed N =  2 it =  2
# [00:09:23] [VPRMSeeding] Sample set size 2

# %%
keep_splitting = True
while keep_splitting:
    to_split = refine_guards1(vs)
    if len(to_split):
        #goi, targ_seed, ker, g1, g2 = to_split[0]
        refine_guards2(vs, to_split)
        vs.guard_phase()
        keep_splitting = True
    else:
        keep_splitting = False
# Out:
# [VPRMSeeding] No guard to split

# %%
kers = [vs.compute_kernel_of_guard(g) for g in vs.guard_regions]
kers = [k + [vs.seed_points[g]] for k,g in zip(kers, vs.guard_regions)]

# %%
fig, ax = plt.subplots(figsize = (10,10))

guards = np.array([vs.seed_points[s] for s in vs.guard_regions])
guard_regions = [vs.regions[r] for r in vs.guard_regions]
guard_reg_verts =[]
for g in guard_regions:
    vert = sorted_vertices(VPolytope(g))
    vert = np.hstack((vert, vert[:, :1]))
    guard_reg_verts.append(vert)
sample_set = []
for sampdat in vs.samples_outside_regions.values():
    pos = sampdat[0]
    sample_set.append(pos)
sample_set = np.array(sample_set)   

print('min convex cover:', len(regions), 'regions, guard_regions:', len(vs.guard_regions), ' regions')
N_cover = 10000
cover_est = get_cover_est(guard_regions, regions, N = N_cover)
print('Estimated cover of cfree = ', cover_est, '(N =', N_cover,')')

plot_env(ax, regions, obstacle_regions)
ax.axis('equal')
for r in guard_reg_verts:
    ax.plot(r[0, :], r[1, :], c = 'r', linewidth = 2)

if len(sample_set):
    ax.scatter(sample_set[:, 0], sample_set[:, 1], c = 'k', s = 1)
# if len(to_split):
#     ax.scatter(targ_seed[0], targ_seed[1], c = 'm', s = 50)
#     ax.scatter(np.array([g1, g2])[-2:, 0], np.array([g1, g2])[-2:, 1], c = 'r', s = 40)
# kers = []
for k in kers:
    pts = np.array(k)
    ax.scatter(pts[:,0], pts[:,1], s= 80)
ax.scatter(guards[:, 0], guards[:, 1], c = 'b', s = 20)
plt.show()
# Out:
# min convex cover: 8 regions, guard_regions: 3  regions
# Estimated cover of cfree =  0.7803 (N = 10000 )

# %%
from visprm import VPRMSeeding
#poi = [np.array([-6, 0]), np.array([0, 8]), np.array([4, -7.5])]
#np.random.seed(12)
regions, obstacle_regions, col_handle, los_handle, iris_handle, iris_handle2 = generate_env_and_helperfunctions(12)
vs = VPRMSeeding([],
                 alpha = 0.05,
                 eps = 0.05,
                 limits = [np.array([-10.] * dim), np.array([10.] * dim)],# [lb, ub],
                 collision_handle = col_handle,
                 is_in_line_of_sight = los_handle, 
                 iris_handle=iris_handle,
                 iris_handle_with_obstacles = iris_handle2,
                 )
# Out:
# [22:38:56] [VPRMSeeding] Expecting points of interest in q
# [22:38:56] [VPRMSeeding] GuardInsertion attempts M: 58
# [22:38:56] [VPRMSeeding] 0.95 probability that unseen region is less than 5.0 "%" of Cfree

# %%
vs.guard_phase()
# Out:
# [22:38:56] [VPRMSeeding] New guard placed N =  0 it =  0
# [22:38:58] [VPRMSeeding] Sample set size 0
# [22:38:58] [VPRMSeeding] New guard placed N =  1 it =  1
# [22:39:00] [VPRMSeeding] Sample set size 0
# [22:39:00] [VPRMSeeding] New guard placed N =  2 it =  2
# [22:39:01] [VPRMSeeding] Sample set size 1
# [22:39:01] [VPRMSeeding] New guard placed N =  3 it =  3
# [22:39:04] [VPRMSeeding] Sample set size 3

# %%
guards = np.array([vs.seed_points[s] for s in vs.guard_regions])
guard_regions = [vs.regions[r] for r in vs.guard_regions]
guard_reg_verts =[]
for g in guard_regions:
    vert = sorted_vertices(VPolytope(g))
    vert = np.hstack((vert, vert[:, :1]))
    guard_reg_verts.append(vert)
sample_set = []
for sampdat in vs.samples_outside_regions.values():
    pos = sampdat[0]
    sample_set.append(pos)
sample_set = np.array(sample_set)   
print(len(sample_set))
# Out:
# 60

# %%
print('min convex cover:', len(regions), 'regions, guard_regions:', len(vs.guard_regions), ' regions')
N_cover = 10000
cover_est = get_cover_est(guard_regions, regions, N = N_cover)
print('Estimated cover of cfree = ', cover_est, '(N =', N_cover,')')
fig, ax = plt.subplots(figsize = (10,10))
plot_env(ax, regions, obstacle_regions)
ax.axis('equal')
for r in guard_reg_verts:
    ax.plot(r[0, :], r[1, :], c = 'r', linewidth = 2)
ax.scatter(guards[:, 0], guards[:, 1], c = 'b', s = 40)
ax.scatter(guards[0, 0], guards[0, 1], c = 'm', s = 40)
if len(sample_set):
    ax.scatter(sample_set[:, 0], sample_set[:, 1], c = 'k', s = 1)
plt.show()
# Out:
# min convex cover: 8 regions, guard_regions: 4  regions
# Estimated cover of cfree =  0.7311 (N = 10000 )

# %%
to_split = refine_guards1(vs)
if len(to_split):
    goi, targ_seed, ker, g1, g2 = to_split[0]
refine_guards2(vs, to_split)
if len(to_split):
    vs.guard_phase()
# Out:
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard  1 / 1

# %%
#do plotting
print('min convex cover:', len(regions), 'regions, guard_regions:', len(vs.guard_regions), ' regions')
N_cover = 10000
cover_est = get_cover_est(guard_regions, regions, N = N_cover)
print('Estimated cover of cfree = ', cover_est, '(N =', N_cover,')')
fig, ax = plt.subplots(figsize = (10,10))
plot_env(ax, regions, obstacle_regions)
ax.axis('equal')
for r in guard_reg_verts:
    ax.plot(r[0, :], r[1, :], c = 'r', linewidth = 2)
ax.scatter(guards[:, 0], guards[:, 1], c = 'b', s = 40)
if len(to_split):
    ax.scatter(targ_seed[0], targ_seed[1], c = 'm', s = 50)
    ax.scatter(np.array([g1, g2])[-2:, 0], np.array([g1, g2])[-2:, 1], c = 'r', s = 40)
if len(sample_set):
    ax.scatter(sample_set[:, 0], sample_set[:, 1], c = 'k', s = 1)
plt.show()
# Out:
# min convex cover: 8 regions, guard_regions: 5  regions
# Estimated cover of cfree =  0.7283 (N = 10000 )

# %%
guards = np.array([vs.seed_points[s] for s in vs.guard_regions])
guard_regions = [vs.regions[r] for r in vs.guard_regions]
guard_reg_verts =[]
for g in guard_regions:
    vert = sorted_vertices(VPolytope(g))
    vert = np.hstack((vert, vert[:, :1]))
    guard_reg_verts.append(vert)
sample_set = []
for sampdat in vs.samples_outside_regions.values():
    pos = sampdat[0]
    sample_set.append(pos)
sample_set = np.array(sample_set)

# %%
print('min convex cover:', len(regions), 'regions, guard_regions:', len(vs.guard_regions), ' regions')
N_cover = 10000
cover_est = get_cover_est(guard_regions, regions, N = N_cover)
print('Estimated cover of cfree = ', cover_est, '(N =', N_cover,')')
fig, ax = plt.subplots(figsize = (10,10))
plot_env(ax, regions, obstacle_regions)
ax.axis('equal')
for r in guard_reg_verts:
    ax.plot(r[0, :], r[1, :], c = 'r', linewidth = 2)
ax.scatter(guards[:, 0], guards[:, 1], c = 'b', s = 40)
ax.scatter(guards[-2:, 0], guards[-2:, 1], c = 'r', s = 40)
ax.scatter(sample_set[:, 0], sample_set[:, 1], c = 'k', s = 1)
plt.show()
# Out:
# min convex cover: 8 regions, guard_regions: 5  regions
# Estimated cover of cfree =  0.7835 (N = 10000 )

# %%
vs.fill_remaining_space_phase()
# Out:
# [16:16:13] [VPRMSeeding] New Region placed N =  5 , it =  6
# [16:16:16] [VPRMSeeding] New Region placed N =  6 , it =  13
# [16:16:17] [VPRMSeeding] New Region placed N =  7 , it =  15
# [16:16:19] [VPRMSeeding] New Region placed N =  8 , it =  17
# [16:16:20] [VPRMSeeding] New Region placed N =  9 , it =  12
# [16:16:23] [VPRMSeeding] New Region placed N =  10 , it =  7
# [16:16:26] [VPRMSeeding] New Region placed N =  11 , it =  43
# [16:16:27] [VPRMSeeding] New Region placed N =  12 , it =  11
# [16:16:30] [VPRMSeeding] New Region placed N =  13 , it =  12
# [16:16:31] [VPRMSeeding] New Region placed N =  14 , it =  0
# [16:16:34] [VPRMSeeding] New Region placed N =  15 , it =  21
# True

# %%
all_regs = vs.regions
guards = np.array([vs.seed_points[s] for s in vs.guard_regions])
guard_regions = [vs.regions[r] for r in vs.guard_regions]

all_reg_verts =[]
for g in all_regs:
    vert = sorted_vertices(VPolytope(g))
    vert = np.hstack((vert, vert[:, :1]))
    all_reg_verts.append(vert)
    
sample_set = []
for sampdat in vs.samples_outside_regions.values():
    pos = sampdat[0]
    sample_set.append(pos)
sample_set = np.array(sample_set)

# %%
print('min convex cover:', len(regions), 'regions, guard_regions:', len(vs.guard_regions), ' regions')
print('regions placed:', len(vs.regions))
N_cover = 10000
cover_est = get_cover_est(all_regs, regions, N = N_cover)
print('Estimated cover of cfree = ', cover_est, '(N =', N_cover,')')
fig, ax = plt.subplots(figsize = (10,10))
plot_env(ax, regions, obstacle_regions)
ax.axis('equal')
for r in all_reg_verts:
    ax.plot(r[0, :], r[1, :], c = 'r', linewidth = 2)
ax.scatter(guards[:, 0], guards[:, 1], c = 'b', s = 40)
ax.scatter(guards[-2:, 0], guards[-2:, 1], c = 'r', s = 40)
if len(sample_set):
    ax.scatter(sample_set[:, 0], sample_set[:, 1], c = 'k', s = 1)
plt.show()
# Out:
# min convex cover: 8 regions, guard_regions: 5  regions
# regions placed: 16
# Estimated cover of cfree =  0.9728 (N = 10000 )

# %%
from visprm import RandSeeding

rs = RandSeeding([],
              alpha = 0.1,
              eps = 0.01,
              limits = [np.array([-10.] * dim), np.array([10.] * dim)],
              collision_handle = col_handle,
              iris_handle=iris_handle,
              iris_handle_with_obstacles = iris_handle2,
              terminate_early = False)
rs.set_init_regions()
# Out:
# [16:16:38] [RandSeeding] Expecting points of interest in q
# [16:16:38] [RandSeeding] GuardInsertion attempts M: 229
# [16:16:38] [RandSeeding] 0.9 probability that unseen region is less than 1.0 "%" of Cfree

# %%
rs.sample_regions_phase()
# Out:
# [16:16:38] [RandSeeding] New Region placed N =  0 , it =  0
# [16:16:39] [RandSeeding] New Region placed N =  1 , it =  0
# [16:16:40] [RandSeeding] New Region placed N =  2 , it =  2
# [16:16:42] [RandSeeding] New Region placed N =  3 , it =  2
# [16:16:44] [RandSeeding] New Region placed N =  4 , it =  0
# [16:16:45] [RandSeeding] New Region placed N =  5 , it =  2
# [16:16:47] [RandSeeding] New Region placed N =  6 , it =  1
# [16:16:49] [RandSeeding] New Region placed N =  7 , it =  2
# [16:16:52] [RandSeeding] New Region placed N =  8 , it =  0
# [16:16:55] [RandSeeding] New Region placed N =  9 , it =  9
# [16:16:57] [RandSeeding] New Region placed N =  10 , it =  49
# [16:16:58] [RandSeeding] New Region placed N =  11 , it =  8
# [16:17:00] [RandSeeding] New Region placed N =  12 , it =  13
# [16:17:02] [RandSeeding] New Region placed N =  13 , it =  22
# [16:17:03] [RandSeeding] New Region placed N =  14 , it =  15
# [16:17:05] [RandSeeding] New Region placed N =  15 , it =  17
# [16:17:08] [RandSeeding] New Region placed N =  16 , it =  7
# False

# %%
print('min convex cover:', len(regions), 'regions, rand regions:', len(rs.regions), ' regions')
seeds_rand = np.array(rs.seed_points)
regions_rand = [r for r in rs.regions]
N_cover = 10000
cover_est = get_cover_est(regions_rand, regions, N = N_cover)
print('Estimated cover of cfree = ', cover_est, '(N =', N_cover,')')
reg_verts_rand =[]
for g in regions_rand:
    vert = sorted_vertices(VPolytope(g))
    vert = np.hstack((vert, vert[:, :1]))
    reg_verts_rand.append(vert)

fig, ax = plt.subplots(figsize = (10,10))
plot_env(ax, regions, obstacle_regions)
ax.axis('equal')
for r in reg_verts_rand:
    ax.plot(r[0, :], r[1, :], c = 'r', linewidth = 2)
ax.scatter(seeds_rand[:, 0], seeds_rand[:, 1], c = 'b', s = 40)
plt.show()
# Out:
# min convex cover: 8 regions, rand regions: 17  regions
# Estimated cover of cfree =  0.952 (N = 10000 )

# %%
#EVALLL

# %%
from datetime import date, datetime
import time
from visprm import RandSeeding
now = datetime.now()
timestamp = now.strftime("%y_%m_%d_%H_%M_%S")
filename = timestamp+'_2d_randenv_eval_uisng_fill_remaining_space.log'
with open(filename, 'w+') as file:  
    for i in range(100):
        np.random.seed(i)
        #generate env
        regions, obstacle_regions, col_handle, los_handle, \
        iris_handle, iris_handle2 = generate_env_and_helperfunctions(i)
        vs = VPRMSeeding([],
                     alpha = 0.05,
                     eps = 0.1,
                     limits = [np.array([-10.] * dim), np.array([10.] * dim)],# [lb, ub],
                     collision_handle = col_handle,
                     is_in_line_of_sight = los_handle, 
                     iris_handle=iris_handle,
                     iris_handle_with_obstacles = iris_handle2,
                     )

        t1 = time.time()
        vs.guard_phase()
        vs.fill_remaining_space_phase()
        t2 = time.time()
        coverage = get_cover_est(vs.regions, regions, N = 10000)
        coverage_guards = get_cover_est([vs.regions[g] for g in vs.guard_regions], regions, N = 10000)
        run_string = [(f"""{'--visprmraw'},\n"""),
                     (f"""{ 'seed:'}{i},\n"""),
                     (f"""{'nr: '}{len(vs.regions)},\n"""),
                     (f"""{'ng: '}{len(vs.guard_regions)},\n"""),
                     (f"""{'coverage: '}{coverage:.4f},\n"""),
                     (f"""{'coverage_guards: '}{coverage_guards:.4f},\n"""),
                     (f"""{'runtime: '}{t2-t1:.4f},\n"""),
                     (f"""{'optcover: '}{len(regions)},\n"""),
                     ]
        file.writelines(run_string)
        
        vs = VPRMSeeding([],
                     alpha = 0.05,
                     eps = 0.1,
                     limits = [np.array([-10.] * dim), np.array([10.] * dim)],# [lb, ub],
                     collision_handle = col_handle,
                     is_in_line_of_sight = los_handle, 
                     iris_handle=iris_handle,
                     iris_handle_with_obstacles = iris_handle2,
                     )

        t1 = time.time()
        vs.guard_phase()
        keep_splitting = True
        while keep_splitting:
            to_split = refine_guards1(vs)
            if len(to_split):
                #goi, targ_seed, ker, g1, g2 = to_split[0]
                refine_guards2(vs, to_split)
                vs.guard_phase()
                keep_splitting = True
            else:
                keep_splitting = False
        vs.fill_remaining_space_phase()
        t2 = time.time()
        coverage = get_cover_est(vs.regions, regions, N = 10000)
        coverage_guards = get_cover_est([vs.regions[g] for g in vs.guard_regions], regions, N = 10000)
        run_string = [(f"""{'--visprmimp'},\n"""),
                     (f"""{ 'seed:'}{i},\n"""),
                     (f"""{'nr: '}{len(vs.regions)},\n"""),
                     (f"""{'ng: '}{len(vs.guard_regions)},\n"""),
                     (f"""{'coverage: '}{coverage:.4f},\n"""),
                     (f"""{'coverage_guards: '}{coverage_guards:.4f},\n"""),
                     (f"""{'runtime: '}{t2-t1:.4f},\n"""),
                     (f"""{'optcover: '}{len(regions)},\n"""),
                     ]
        file.writelines(run_string)
        
        rs = RandSeeding([],
              alpha = 0.05,
              eps = 0.1,
              limits = [np.array([-10.] * dim), np.array([10.] * dim)],
              collision_handle = col_handle,
              iris_handle=iris_handle,
              iris_handle_with_obstacles = iris_handle2,
              terminate_early = False)
        t1 = time.time()
        rs.set_init_regions()
        rs.sample_regions_phase()
        t2 = time.time()
        coverage = get_cover_est(rs.regions, regions, N = 10000)
        run_string = [(f"""{'--rand'},\n"""),
                     (f"""{ 'seed:'}{i},\n"""),
                     (f"""{'nr: '}{len(rs.regions)},\n"""),
                     (f"""{'ng: '}{0},\n"""),
                     (f"""{'coverage: '}{coverage:.4f},\n"""),
                     (f"""{'coverage_guards: '}{0:.4f},\n"""),
                     (f"""{'runtime: '}{t2-t1:.4f},\n"""),
                     (f"""{'optcover: '}{len(regions)},\n"""),
                     ]
        file.writelines(run_string)
# Out:
# [01:05:17] [VPRMSeeding] Expecting points of interest in q
# [01:05:17] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:05:17] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:05:17] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:05:18] [VPRMSeeding] Sample set size 0
# [01:05:19] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:05:20] [VPRMSeeding] Sample set size 0
# [01:05:20] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:05:21] [VPRMSeeding] Sample set size 0
# [01:05:21] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:05:23] [VPRMSeeding] Sample set size 0
# [01:05:30] [VPRMSeeding] New Region placed N =  4 , it =  0
# [01:05:33] [VPRMSeeding] Expecting points of interest in q
# [01:05:33] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:05:33] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:05:33] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:05:35] [VPRMSeeding] Sample set size 0
# [01:05:35] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:05:36] [VPRMSeeding] Sample set size 0
# [01:05:36] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:05:38] [VPRMSeeding] Sample set size 0
# [01:05:38] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:05:40] [VPRMSeeding] Sample set size 0
# [01:05:40] [VPRMSeeding] New guard placed N =  4 it =  1
# [01:05:42] [VPRMSeeding] Sample set size 0
# [VPRMSeeding] No guard to split
# [01:05:45] [VPRMSeeding] New Region placed N =  5 , it =  3
# [01:05:47] [RandSeeding] Expecting points of interest in q
# [01:05:47] [RandSeeding] GuardInsertion attempts M: 28
# [01:05:47] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:05:47] [RandSeeding] New Region placed N =  0 , it =  0
# [01:05:49] [RandSeeding] New Region placed N =  1 , it =  0
# [01:05:50] [RandSeeding] New Region placed N =  2 , it =  2
# [01:05:52] [RandSeeding] New Region placed N =  3 , it =  0
# [01:05:53] [RandSeeding] New Region placed N =  4 , it =  6
# [01:05:55] [RandSeeding] New Region placed N =  5 , it =  0
# [01:05:57] [RandSeeding] New Region placed N =  6 , it =  3
# [01:06:28] [VPRMSeeding] Expecting points of interest in q
# [01:06:28] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:06:28] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:06:28] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:06:30] [VPRMSeeding] Sample set size 0
# [01:06:30] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:06:32] [VPRMSeeding] Sample set size 0
# [01:06:32] [VPRMSeeding] New guard placed N =  2 it =  2
# [01:06:34] [VPRMSeeding] Sample set size 1
# [01:06:34] [VPRMSeeding] New guard placed N =  3 it =  4
# [01:06:36] [VPRMSeeding] Sample set size 4
# [01:06:37] [VPRMSeeding] New Region placed N =  4 , it =  0
# [01:06:39] [VPRMSeeding] New Region placed N =  5 , it =  1
# [01:06:41] [VPRMSeeding] New Region placed N =  6 , it =  10
# [01:06:43] [VPRMSeeding] New Region placed N =  7 , it =  4
# [01:06:45] [VPRMSeeding] New Region placed N =  8 , it =  2
# [01:06:48] [VPRMSeeding] New Region placed N =  9 , it =  7
# [01:06:50] [VPRMSeeding] Expecting points of interest in q
# [01:06:50] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:06:50] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:06:50] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:06:52] [VPRMSeeding] Sample set size 0
# [01:06:52] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:06:54] [VPRMSeeding] Sample set size 0
# [01:06:54] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:06:56] [VPRMSeeding] Sample set size 0
# [01:06:57] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:06:59] [VPRMSeeding] Sample set size 0
# [VPRMSeeding] No guard to split
# [01:07:05] [VPRMSeeding] New Region placed N =  4 , it =  2
# [01:07:07] [VPRMSeeding] New Region placed N =  5 , it =  5
# [01:07:09] [RandSeeding] Expecting points of interest in q
# [01:07:09] [RandSeeding] GuardInsertion attempts M: 28
# [01:07:09] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:07:09] [RandSeeding] New Region placed N =  0 , it =  0
# [01:07:11] [RandSeeding] New Region placed N =  1 , it =  0
# [01:07:14] [RandSeeding] New Region placed N =  2 , it =  0
# [01:07:15] [RandSeeding] New Region placed N =  3 , it =  0
# [01:07:17] [RandSeeding] New Region placed N =  4 , it =  5
# [01:07:19] [RandSeeding] New Region placed N =  5 , it =  1
# [01:07:21] [RandSeeding] New Region placed N =  6 , it =  18
# [01:07:22] [RandSeeding] New Region placed N =  7 , it =  2
# [01:07:23] [RandSeeding] New Region placed N =  8 , it =  0
# [01:07:27] [RandSeeding] New Region placed N =  9 , it =  6
# [01:07:40] [VPRMSeeding] Expecting points of interest in q
# [01:07:40] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:07:40] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:07:40] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:07:42] [VPRMSeeding] Sample set size 0
# [01:07:42] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:07:43] [VPRMSeeding] Sample set size 0
# [01:07:43] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:07:44] [VPRMSeeding] Sample set size 0
# [01:07:44] [VPRMSeeding] New guard placed N =  3 it =  2
# [01:07:45] [VPRMSeeding] Sample set size 1
# [01:07:53] [VPRMSeeding] New Region placed N =  4 , it =  25
# [01:07:54] [VPRMSeeding] Expecting points of interest in q
# [01:07:54] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:07:54] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:07:54] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:07:55] [VPRMSeeding] Sample set size 0
# [01:07:55] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:07:56] [VPRMSeeding] Sample set size 0
# [01:07:57] [VPRMSeeding] New guard placed N =  2 it =  7
# [01:07:58] [VPRMSeeding] Sample set size 6
# [01:07:59] [VPRMSeeding] New guard placed N =  3 it =  12
# [01:08:00] [VPRMSeeding] Sample set size 17
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [VPRMSeeding] No guard to split
# [01:08:26] [VPRMSeeding] New Region placed N =  5 , it =  15
# [01:08:27] [RandSeeding] Expecting points of interest in q
# [01:08:27] [RandSeeding] GuardInsertion attempts M: 28
# [01:08:27] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:08:27] [RandSeeding] New Region placed N =  0 , it =  0
# [01:08:28] [RandSeeding] New Region placed N =  1 , it =  0
# [01:08:29] [RandSeeding] New Region placed N =  2 , it =  8
# [01:08:31] [RandSeeding] New Region placed N =  3 , it =  10
# [01:08:32] [RandSeeding] New Region placed N =  4 , it =  26
# [01:08:34] [RandSeeding] New Region placed N =  5 , it =  0
# [01:09:00] [VPRMSeeding] Expecting points of interest in q
# [01:09:00] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:09:00] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:09:00] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:09:02] [VPRMSeeding] Sample set size 0
# [01:09:03] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:09:05] [VPRMSeeding] Sample set size 0
# [01:09:05] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:09:06] [VPRMSeeding] Sample set size 0
# [01:09:06] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:09:08] [VPRMSeeding] Sample set size 0
# [01:09:10] [VPRMSeeding] New Region placed N =  4 , it =  8
# [01:09:12] [VPRMSeeding] New Region placed N =  5 , it =  5
# [01:09:14] [VPRMSeeding] New Region placed N =  6 , it =  21
# [01:09:15] [VPRMSeeding] New Region placed N =  7 , it =  9
# [01:09:17] [VPRMSeeding] New Region placed N =  8 , it =  22
# [01:09:19] [VPRMSeeding] New Region placed N =  9 , it =  9
# [01:09:21] [VPRMSeeding] Expecting points of interest in q
# [01:09:21] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:09:21] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:09:21] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:09:23] [VPRMSeeding] Sample set size 0
# [01:09:23] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:09:26] [VPRMSeeding] Sample set size 0
# [01:09:26] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:09:28] [VPRMSeeding] Sample set size 0
# [01:09:28] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:09:29] [VPRMSeeding] Sample set size 0
# [01:09:29] [VPRMSeeding] New guard placed N =  4 it =  2
# [01:09:31] [VPRMSeeding] Sample set size 1
# [01:09:39] [VPRMSeeding] New guard placed N =  5 it =  11
# [01:09:41] [VPRMSeeding] Sample set size 11
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [VPRMSeeding] No guard to split
# [01:11:01] [RandSeeding] Expecting points of interest in q
# [01:11:01] [RandSeeding] GuardInsertion attempts M: 28
# [01:11:01] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:11:01] [RandSeeding] New Region placed N =  0 , it =  0
# [01:11:02] [RandSeeding] New Region placed N =  1 , it =  0
# [01:11:05] [RandSeeding] New Region placed N =  2 , it =  0
# [01:11:06] [RandSeeding] New Region placed N =  3 , it =  0
# [01:11:09] [RandSeeding] New Region placed N =  4 , it =  19
# [01:11:10] [RandSeeding] New Region placed N =  5 , it =  6
# [01:11:13] [RandSeeding] New Region placed N =  6 , it =  0
# [01:11:14] [RandSeeding] New Region placed N =  7 , it =  3
# [01:11:15] [RandSeeding] New Region placed N =  8 , it =  1
# [01:11:53] [VPRMSeeding] Expecting points of interest in q
# [01:11:53] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:11:53] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:11:53] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:11:55] [VPRMSeeding] Sample set size 0
# [01:11:55] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:11:57] [VPRMSeeding] Sample set size 0
# [01:11:57] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:12:00] [VPRMSeeding] Sample set size 0
# [01:12:00] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:12:03] [VPRMSeeding] Sample set size 0
# [01:12:03] [VPRMSeeding] New guard placed N =  4 it =  2
# [01:12:05] [VPRMSeeding] Sample set size 1
# [01:12:05] [VPRMSeeding] New guard placed N =  5 it =  2
# [01:12:08] [VPRMSeeding] Sample set size 2
# [01:12:08] [VPRMSeeding] New guard placed N =  6 it =  3
# [01:12:11] [VPRMSeeding] Sample set size 4
# [01:12:24] [VPRMSeeding] New Region placed N =  7 , it =  10
# [01:12:26] [VPRMSeeding] New Region placed N =  8 , it =  17
# [01:12:29] [VPRMSeeding] Expecting points of interest in q
# [01:12:29] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:12:29] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:12:29] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:12:31] [VPRMSeeding] Sample set size 0
# [01:12:31] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:12:34] [VPRMSeeding] Sample set size 0
# [01:12:34] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:12:36] [VPRMSeeding] Sample set size 0
# [01:12:36] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:12:39] [VPRMSeeding] Sample set size 0
# [01:12:39] [VPRMSeeding] New guard placed N =  4 it =  1
# [01:12:42] [VPRMSeeding] Sample set size 0
# [01:12:42] [VPRMSeeding] New guard placed N =  5 it =  1
# [01:12:44] [VPRMSeeding] Sample set size 0
# [01:12:45] [VPRMSeeding] New guard placed N =  6 it =  1
# [01:12:47] [VPRMSeeding] Sample set size 0
# [VPRMSeeding] No guard to split
# [01:13:03] [VPRMSeeding] New Region placed N =  7 , it =  16
# [01:13:06] [RandSeeding] Expecting points of interest in q
# [01:13:06] [RandSeeding] GuardInsertion attempts M: 28
# [01:13:06] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:13:06] [RandSeeding] New Region placed N =  0 , it =  0
# [01:13:08] [RandSeeding] New Region placed N =  1 , it =  0
# [01:13:11] [RandSeeding] New Region placed N =  2 , it =  0
# [01:13:12] [RandSeeding] New Region placed N =  3 , it =  2
# [01:13:15] [RandSeeding] New Region placed N =  4 , it =  0
# [01:13:18] [RandSeeding] New Region placed N =  5 , it =  3
# [01:13:20] [RandSeeding] New Region placed N =  6 , it =  2
# [01:13:23] [RandSeeding] New Region placed N =  7 , it =  2
# [01:13:26] [RandSeeding] New Region placed N =  8 , it =  2
# [01:13:29] [RandSeeding] New Region placed N =  9 , it =  1
# [01:13:31] [RandSeeding] New Region placed N =  10 , it =  0
# [01:13:33] [RandSeeding] New Region placed N =  11 , it =  1
# [01:13:36] [RandSeeding] New Region placed N =  12 , it =  2
# [01:14:01] [VPRMSeeding] Expecting points of interest in q
# [01:14:01] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:14:01] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:14:01] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:14:03] [VPRMSeeding] Sample set size 0
# [01:14:03] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:14:04] [VPRMSeeding] Sample set size 0
# [01:14:04] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:14:06] [VPRMSeeding] Sample set size 0
# [01:14:06] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:14:08] [VPRMSeeding] Sample set size 0
# [01:14:08] [VPRMSeeding] New guard placed N =  4 it =  1
# [01:14:10] [VPRMSeeding] Sample set size 0
# [01:14:13] [VPRMSeeding] New Region placed N =  5 , it =  3
# [01:14:14] [VPRMSeeding] New Region placed N =  6 , it =  13
# [01:14:15] [VPRMSeeding] New Region placed N =  7 , it =  1
# [01:14:18] [VPRMSeeding] New Region placed N =  8 , it =  7
# [01:14:21] [VPRMSeeding] Expecting points of interest in q
# [01:14:21] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:14:21] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:14:21] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:14:23] [VPRMSeeding] Sample set size 0
# [01:14:23] [VPRMSeeding] New guard placed N =  1 it =  2
# [01:14:24] [VPRMSeeding] Sample set size 1
# [01:14:24] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:14:27] [VPRMSeeding] Sample set size 1
# [01:14:27] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:14:29] [VPRMSeeding] Sample set size 1
# [01:14:29] [VPRMSeeding] New guard placed N =  4 it =  2
# [01:14:31] [VPRMSeeding] Sample set size 2
# [01:14:31] [VPRMSeeding] New guard placed N =  5 it =  3
# [01:14:32] [VPRMSeeding] Sample set size 4
# [VPRMSeeding] No guard to split
# [01:14:41] [VPRMSeeding] New Region placed N =  6 , it =  16
# [01:14:43] [VPRMSeeding] New Region placed N =  7 , it =  3
# [01:14:45] [RandSeeding] Expecting points of interest in q
# [01:14:45] [RandSeeding] GuardInsertion attempts M: 28
# [01:14:45] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:14:45] [RandSeeding] New Region placed N =  0 , it =  0
# [01:14:47] [RandSeeding] New Region placed N =  1 , it =  0
# [01:14:48] [RandSeeding] New Region placed N =  2 , it =  0
# [01:14:51] [RandSeeding] New Region placed N =  3 , it =  0
# [01:14:52] [RandSeeding] New Region placed N =  4 , it =  0
# [01:14:54] [RandSeeding] New Region placed N =  5 , it =  0
# [01:14:56] [RandSeeding] New Region placed N =  6 , it =  1
# [01:14:58] [RandSeeding] New Region placed N =  7 , it =  1
# [01:14:59] [RandSeeding] New Region placed N =  8 , it =  7
# [01:15:02] [RandSeeding] New Region placed N =  9 , it =  15
# [01:15:03] [RandSeeding] New Region placed N =  10 , it =  4
# [01:15:36] [VPRMSeeding] Expecting points of interest in q
# [01:15:36] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:15:36] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:15:36] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:15:38] [VPRMSeeding] Sample set size 0
# [01:15:38] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:15:40] [VPRMSeeding] Sample set size 0
# [01:15:40] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:15:41] [VPRMSeeding] Sample set size 0
# [01:15:41] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:15:43] [VPRMSeeding] Sample set size 0
# [01:15:43] [VPRMSeeding] New guard placed N =  4 it =  3
# [01:15:46] [VPRMSeeding] Sample set size 2
# [01:15:46] [VPRMSeeding] New guard placed N =  5 it =  6
# [01:15:48] [VPRMSeeding] Sample set size 7
# [01:15:57] [VPRMSeeding] New Region placed N =  6 , it =  27
# [01:15:59] [VPRMSeeding] New Region placed N =  7 , it =  13
# [01:16:01] [VPRMSeeding] Expecting points of interest in q
# [01:16:01] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:16:01] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:16:01] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:16:03] [VPRMSeeding] Sample set size 0
# [01:16:03] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:16:05] [VPRMSeeding] Sample set size 0
# [01:16:05] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:16:07] [VPRMSeeding] Sample set size 0
# [01:16:08] [VPRMSeeding] New guard placed N =  3 it =  4
# [01:16:10] [VPRMSeeding] Sample set size 3
# [01:16:12] [VPRMSeeding] New guard placed N =  4 it =  20
# [01:16:14] [VPRMSeeding] Sample set size 22
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [VPRMSeeding] No guard to split
# [01:16:28] [VPRMSeeding] New Region placed N =  6 , it =  9
# [01:16:30] [RandSeeding] Expecting points of interest in q
# [01:16:30] [RandSeeding] GuardInsertion attempts M: 28
# [01:16:30] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:16:30] [RandSeeding] New Region placed N =  0 , it =  0
# [01:16:32] [RandSeeding] New Region placed N =  1 , it =  0
# [01:16:35] [RandSeeding] New Region placed N =  2 , it =  2
# [01:16:37] [RandSeeding] New Region placed N =  3 , it =  0
# [01:16:39] [RandSeeding] New Region placed N =  4 , it =  0
# [01:16:40] [RandSeeding] New Region placed N =  5 , it =  1
# [01:16:42] [RandSeeding] New Region placed N =  6 , it =  6
# [01:16:43] [RandSeeding] New Region placed N =  7 , it =  0
# [01:16:45] [RandSeeding] New Region placed N =  8 , it =  6
# [01:16:47] [RandSeeding] New Region placed N =  9 , it =  1
# [01:16:50] [RandSeeding] New Region placed N =  10 , it =  0
# [01:17:07] [VPRMSeeding] Expecting points of interest in q
# [01:17:07] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:17:07] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:17:07] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:17:09] [VPRMSeeding] Sample set size 0
# [01:17:09] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:17:11] [VPRMSeeding] Sample set size 0
# [01:17:11] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:17:13] [VPRMSeeding] Sample set size 0
# [01:17:15] [VPRMSeeding] New Region placed N =  3 , it =  2
# [01:17:16] [VPRMSeeding] New Region placed N =  4 , it =  21
# [01:17:17] [VPRMSeeding] New Region placed N =  5 , it =  5
# [01:17:20] [VPRMSeeding] New Region placed N =  6 , it =  7
# [01:17:22] [VPRMSeeding] Expecting points of interest in q
# [01:17:22] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:17:22] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:17:22] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:17:23] [VPRMSeeding] Sample set size 0
# [01:17:23] [VPRMSeeding] New guard placed N =  1 it =  2
# [01:17:25] [VPRMSeeding] Sample set size 1
# [01:17:25] [VPRMSeeding] New guard placed N =  2 it =  3
# [01:17:27] [VPRMSeeding] Sample set size 3
# [01:17:27] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:17:29] [VPRMSeeding] Sample set size 3
# [VPRMSeeding] No guard to split
# [01:17:31] [VPRMSeeding] New Region placed N =  4 , it =  8
# [01:17:34] [RandSeeding] Expecting points of interest in q
# [01:17:34] [RandSeeding] GuardInsertion attempts M: 28
# [01:17:34] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:17:34] [RandSeeding] New Region placed N =  0 , it =  0
# [01:17:36] [RandSeeding] New Region placed N =  1 , it =  0
# [01:17:37] [RandSeeding] New Region placed N =  2 , it =  2
# [01:17:38] [RandSeeding] New Region placed N =  3 , it =  0
# [01:17:40] [RandSeeding] New Region placed N =  4 , it =  0
# [01:17:42] [RandSeeding] New Region placed N =  5 , it =  9
# [01:17:43] [RandSeeding] New Region placed N =  6 , it =  9
# [01:17:46] [RandSeeding] New Region placed N =  7 , it =  3
# [01:18:00] [VPRMSeeding] Expecting points of interest in q
# [01:18:00] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:18:00] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:18:00] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:18:01] [VPRMSeeding] Sample set size 0
# [01:18:01] [VPRMSeeding] New guard placed N =  1 it =  2
# [01:18:02] [VPRMSeeding] Sample set size 1
# [01:18:02] [VPRMSeeding] New Region placed N =  2 , it =  0
# [01:18:03] [VPRMSeeding] New Region placed N =  3 , it =  0
# [01:18:04] [VPRMSeeding] New Region placed N =  4 , it =  0
# [01:18:05] [VPRMSeeding] New Region placed N =  5 , it =  0
# [01:18:07] [VPRMSeeding] New Region placed N =  6 , it =  1
# [01:18:08] [VPRMSeeding] New Region placed N =  7 , it =  0
# [01:18:09] [VPRMSeeding] New Region placed N =  8 , it =  3
# [01:18:12] [VPRMSeeding] Expecting points of interest in q
# [01:18:12] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:18:12] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:18:12] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:18:14] [VPRMSeeding] Sample set size 0
# [01:18:14] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:18:15] [VPRMSeeding] Sample set size 0
# [01:18:15] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:18:16] [VPRMSeeding] Sample set size 0
# [01:18:16] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:18:18] [VPRMSeeding] Sample set size 0
# [VPRMSeeding] No guard to split
# [01:18:27] [RandSeeding] Expecting points of interest in q
# [01:18:27] [RandSeeding] GuardInsertion attempts M: 28
# [01:18:27] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:18:27] [RandSeeding] New Region placed N =  0 , it =  0
# [01:18:28] [RandSeeding] New Region placed N =  1 , it =  0
# [01:18:30] [RandSeeding] New Region placed N =  2 , it =  3
# [01:18:31] [RandSeeding] New Region placed N =  3 , it =  0
# [01:18:32] [RandSeeding] New Region placed N =  4 , it =  3
# [01:18:33] [RandSeeding] New Region placed N =  5 , it =  0
# [01:18:35] [RandSeeding] New Region placed N =  6 , it =  17
# [01:18:36] [RandSeeding] New Region placed N =  7 , it =  0
# [01:18:38] [RandSeeding] New Region placed N =  8 , it =  24
# [01:19:04] [VPRMSeeding] Expecting points of interest in q
# [01:19:04] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:19:04] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:19:04] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:19:05] [VPRMSeeding] Sample set size 0
# [01:19:05] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:19:07] [VPRMSeeding] Sample set size 0
# [01:19:07] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:19:09] [VPRMSeeding] Sample set size 0
# [01:19:10] [VPRMSeeding] New Region placed N =  3 , it =  3
# [01:19:12] [VPRMSeeding] New Region placed N =  4 , it =  0
# [01:19:14] [VPRMSeeding] New Region placed N =  5 , it =  7
# [01:19:15] [VPRMSeeding] New Region placed N =  6 , it =  8
# [01:19:17] [VPRMSeeding] New Region placed N =  7 , it =  1
# [01:19:18] [VPRMSeeding] New Region placed N =  8 , it =  14
# [01:19:20] [VPRMSeeding] New Region placed N =  9 , it =  23
# [01:19:23] [VPRMSeeding] Expecting points of interest in q
# [01:19:23] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:19:23] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:19:23] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:19:25] [VPRMSeeding] Sample set size 0
# [01:19:25] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:19:27] [VPRMSeeding] Sample set size 0
# [01:19:27] [VPRMSeeding] New guard placed N =  2 it =  3
# [01:19:29] [VPRMSeeding] Sample set size 2
# [01:19:29] [VPRMSeeding] New guard placed N =  3 it =  4
# [01:19:31] [VPRMSeeding] Sample set size 5
# [01:19:32] [VPRMSeeding] New guard placed N =  4 it =  5
# [01:19:33] [VPRMSeeding] Sample set size 9
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [VPRMSeeding] No guard to split
# [01:19:43] [VPRMSeeding] New Region placed N =  6 , it =  9
# [01:19:45] [VPRMSeeding] New Region placed N =  7 , it =  24
# [01:19:48] [VPRMSeeding] New Region placed N =  8 , it =  15
# [01:19:50] [RandSeeding] Expecting points of interest in q
# [01:19:50] [RandSeeding] GuardInsertion attempts M: 28
# [01:19:50] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:19:50] [RandSeeding] New Region placed N =  0 , it =  0
# [01:19:52] [RandSeeding] New Region placed N =  1 , it =  0
# [01:19:54] [RandSeeding] New Region placed N =  2 , it =  1
# [01:19:56] [RandSeeding] New Region placed N =  3 , it =  3
# [01:19:57] [RandSeeding] New Region placed N =  4 , it =  1
# [01:19:59] [RandSeeding] New Region placed N =  5 , it =  1
# [01:20:01] [RandSeeding] New Region placed N =  6 , it =  19
# [01:20:02] [RandSeeding] New Region placed N =  7 , it =  8
# [01:20:04] [RandSeeding] New Region placed N =  8 , it =  14
# [01:20:06] [RandSeeding] New Region placed N =  9 , it =  12
# [01:20:09] [RandSeeding] New Region placed N =  10 , it =  17
# [01:20:28] [VPRMSeeding] Expecting points of interest in q
# [01:20:28] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:20:28] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:20:28] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:20:30] [VPRMSeeding] Sample set size 0
# [01:20:30] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:20:31] [VPRMSeeding] Sample set size 0
# [01:20:31] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:20:33] [VPRMSeeding] Sample set size 0
# [01:20:33] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:20:34] [VPRMSeeding] Sample set size 0
# [01:20:35] [VPRMSeeding] New guard placed N =  4 it =  1
# [01:20:36] [VPRMSeeding] Sample set size 0
# [01:20:40] [VPRMSeeding] New guard placed N =  5 it =  9
# [01:20:41] [VPRMSeeding] Sample set size 8
# [01:22:27] [VPRMSeeding] Expecting points of interest in q
# [01:22:27] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:22:27] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:22:27] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:22:29] [VPRMSeeding] Sample set size 0
# [01:22:29] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:22:30] [VPRMSeeding] Sample set size 0
# [01:22:30] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:22:32] [VPRMSeeding] Sample set size 0
# [01:22:32] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:22:34] [VPRMSeeding] Sample set size 0
# [01:22:34] [VPRMSeeding] New guard placed N =  4 it =  2
# [01:22:36] [VPRMSeeding] Sample set size 1
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [01:23:22] [VPRMSeeding] No sample found outside of regions
# [VPRMSeeding] No guard to split
# [01:23:23] [RandSeeding] Expecting points of interest in q
# [01:23:23] [RandSeeding] GuardInsertion attempts M: 28
# [01:23:23] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:23:23] [RandSeeding] New Region placed N =  0 , it =  0
# [01:23:25] [RandSeeding] New Region placed N =  1 , it =  0
# [01:23:26] [RandSeeding] New Region placed N =  2 , it =  0
# [01:23:27] [RandSeeding] New Region placed N =  3 , it =  0
# [01:23:29] [RandSeeding] New Region placed N =  4 , it =  4
# [01:23:32] [RandSeeding] New Region placed N =  5 , it =  8
# [01:23:33] [RandSeeding] New Region placed N =  6 , it =  10
# [01:23:35] [RandSeeding] New Region placed N =  7 , it =  17
# [01:23:37] [RandSeeding] New Region placed N =  8 , it =  23
# [01:23:55] [VPRMSeeding] Expecting points of interest in q
# [01:23:55] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:23:55] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:23:55] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:23:56] [VPRMSeeding] Sample set size 0
# [01:23:56] [VPRMSeeding] New guard placed N =  1 it =  2
# [01:23:58] [VPRMSeeding] Sample set size 1
# [01:23:58] [VPRMSeeding] New guard placed N =  2 it =  3
# [01:23:59] [VPRMSeeding] Sample set size 3
# [01:24:01] [VPRMSeeding] New Region placed N =  3 , it =  0
# [01:24:02] [VPRMSeeding] New Region placed N =  4 , it =  11
# [01:24:04] [VPRMSeeding] New Region placed N =  5 , it =  14
# [01:24:06] [VPRMSeeding] Expecting points of interest in q
# [01:24:06] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:24:06] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:24:06] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:24:08] [VPRMSeeding] Sample set size 0
# [01:24:08] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:24:10] [VPRMSeeding] Sample set size 0
# [01:24:10] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:24:11] [VPRMSeeding] Sample set size 0
# [01:24:11] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:24:13] [VPRMSeeding] Sample set size 0
# [01:24:13] [VPRMSeeding] New guard placed N =  4 it =  4
# [01:24:14] [VPRMSeeding] Sample set size 3
# [VPRMSeeding] No guard to split
# [01:24:43] [RandSeeding] Expecting points of interest in q
# [01:24:43] [RandSeeding] GuardInsertion attempts M: 28
# [01:24:43] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:24:43] [RandSeeding] New Region placed N =  0 , it =  0
# [01:24:45] [RandSeeding] New Region placed N =  1 , it =  0
# [01:24:47] [RandSeeding] New Region placed N =  2 , it =  0
# [01:24:48] [RandSeeding] New Region placed N =  3 , it =  2
# [01:24:49] [RandSeeding] New Region placed N =  4 , it =  0
# [01:24:50] [RandSeeding] New Region placed N =  5 , it =  3
# [01:24:51] [RandSeeding] New Region placed N =  6 , it =  6
# [01:25:23] [VPRMSeeding] Expecting points of interest in q
# [01:25:23] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:25:23] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:25:23] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:25:25] [VPRMSeeding] Sample set size 0
# [01:25:25] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:25:27] [VPRMSeeding] Sample set size 0
# [01:25:27] [VPRMSeeding] New guard placed N =  2 it =  2
# [01:25:29] [VPRMSeeding] Sample set size 1
# [01:25:30] [VPRMSeeding] New guard placed N =  3 it =  3
# [01:25:32] [VPRMSeeding] Sample set size 3
# [01:25:32] [VPRMSeeding] New guard placed N =  4 it =  1
# [01:25:35] [VPRMSeeding] Sample set size 3
# [01:25:35] [VPRMSeeding] New guard placed N =  5 it =  2
# [01:25:37] [VPRMSeeding] Sample set size 4
# [01:25:53] [VPRMSeeding] New guard placed N =  6 it =  10
# [01:25:55] [VPRMSeeding] Sample set size 13
# [01:27:03] [VPRMSeeding] Expecting points of interest in q
# [01:27:03] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:27:03] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:27:03] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:27:05] [VPRMSeeding] Sample set size 0
# [01:27:05] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:27:07] [VPRMSeeding] Sample set size 0
# [01:27:07] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:27:09] [VPRMSeeding] Sample set size 0
# [01:27:09] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:27:11] [VPRMSeeding] Sample set size 0
# [01:27:11] [VPRMSeeding] New guard placed N =  4 it =  1
# [01:27:13] [VPRMSeeding] Sample set size 0
# [01:27:17] [VPRMSeeding] New guard placed N =  5 it =  23
# [01:27:19] [VPRMSeeding] Sample set size 22
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [VPRMSeeding] No guard to split
# [01:28:36] [RandSeeding] Expecting points of interest in q
# [01:28:36] [RandSeeding] GuardInsertion attempts M: 28
# [01:28:36] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:28:36] [RandSeeding] New Region placed N =  0 , it =  0
# [01:28:38] [RandSeeding] New Region placed N =  1 , it =  0
# [01:28:41] [RandSeeding] New Region placed N =  2 , it =  0
# [01:28:42] [RandSeeding] New Region placed N =  3 , it =  2
# [01:28:45] [RandSeeding] New Region placed N =  4 , it =  1
# [01:28:47] [RandSeeding] New Region placed N =  5 , it =  1
# [01:28:49] [RandSeeding] New Region placed N =  6 , it =  3
# [01:28:51] [RandSeeding] New Region placed N =  7 , it =  2
# [01:28:54] [RandSeeding] New Region placed N =  8 , it =  21
# [01:28:56] [RandSeeding] New Region placed N =  9 , it =  1
# [01:29:23] [VPRMSeeding] Expecting points of interest in q
# [01:29:23] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:29:23] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:29:23] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:29:24] [VPRMSeeding] Sample set size 0
# [01:29:24] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:29:26] [VPRMSeeding] Sample set size 0
# [01:29:26] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:29:28] [VPRMSeeding] Sample set size 0
# [01:29:28] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:29:30] [VPRMSeeding] Sample set size 0
# [01:29:30] [VPRMSeeding] New guard placed N =  4 it =  2
# [01:29:32] [VPRMSeeding] Sample set size 1
# [01:29:33] [VPRMSeeding] New guard placed N =  5 it =  1
# [01:29:34] [VPRMSeeding] Sample set size 1
# [01:29:41] [VPRMSeeding] New guard placed N =  6 it =  1
# [01:29:42] [VPRMSeeding] Sample set size 1
# [01:30:07] [VPRMSeeding] No sample found outside of regions
# [01:30:08] [VPRMSeeding] Expecting points of interest in q
# [01:30:08] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:30:08] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:30:08] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:30:10] [VPRMSeeding] Sample set size 0
# [01:30:10] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:30:12] [VPRMSeeding] Sample set size 0
# [01:30:12] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:30:13] [VPRMSeeding] Sample set size 0
# [01:30:13] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:30:15] [VPRMSeeding] Sample set size 0
# [01:30:15] [VPRMSeeding] New guard placed N =  4 it =  1
# [01:30:16] [VPRMSeeding] Sample set size 0
# [01:30:16] [VPRMSeeding] New guard placed N =  5 it =  1
# [01:30:18] [VPRMSeeding] Sample set size 0
# [01:30:19] [VPRMSeeding] New guard placed N =  6 it =  2
# [01:30:20] [VPRMSeeding] Sample set size 1
# [01:30:46] [VPRMSeeding] No sample found outside of regions
# [VPRMSeeding] No guard to split
# [01:30:47] [RandSeeding] Expecting points of interest in q
# [01:30:47] [RandSeeding] GuardInsertion attempts M: 28
# [01:30:47] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:30:47] [RandSeeding] New Region placed N =  0 , it =  0
# [01:30:49] [RandSeeding] New Region placed N =  1 , it =  0
# [01:30:52] [RandSeeding] New Region placed N =  2 , it =  0
# [01:30:53] [RandSeeding] New Region placed N =  3 , it =  0
# [01:30:54] [RandSeeding] New Region placed N =  4 , it =  3
# [01:30:55] [RandSeeding] New Region placed N =  5 , it =  0
# [01:30:58] [RandSeeding] New Region placed N =  6 , it =  0
# [01:31:00] [RandSeeding] New Region placed N =  7 , it =  8
# [01:31:01] [RandSeeding] New Region placed N =  8 , it =  22
# [01:31:16] [VPRMSeeding] Expecting points of interest in q
# [01:31:16] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:31:16] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:31:16] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:31:18] [VPRMSeeding] Sample set size 0
# [01:31:18] [VPRMSeeding] New guard placed N =  1 it =  2
# [01:31:19] [VPRMSeeding] Sample set size 1
# [01:31:19] [VPRMSeeding] New guard placed N =  2 it =  2
# [01:31:20] [VPRMSeeding] Sample set size 2
# [01:31:20] [VPRMSeeding] New guard placed N =  3 it =  2
# [01:31:21] [VPRMSeeding] Sample set size 3
# [01:31:26] [VPRMSeeding] Expecting points of interest in q
# [01:31:26] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:31:26] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:31:26] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:31:28] [VPRMSeeding] Sample set size 0
# [01:31:28] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:31:30] [VPRMSeeding] Sample set size 0
# [01:31:30] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:31:31] [VPRMSeeding] Sample set size 0
# [01:31:31] [VPRMSeeding] New guard placed N =  3 it =  5
# [01:31:32] [VPRMSeeding] Sample set size 4
# [VPRMSeeding] No guard to split
# [01:31:37] [VPRMSeeding] New Region placed N =  4 , it =  12
# [01:31:39] [RandSeeding] Expecting points of interest in q
# [01:31:39] [RandSeeding] GuardInsertion attempts M: 28
# [01:31:39] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:31:39] [RandSeeding] New Region placed N =  0 , it =  0
# [01:31:40] [RandSeeding] New Region placed N =  1 , it =  1
# [01:31:41] [RandSeeding] New Region placed N =  2 , it =  0
# [01:31:43] [RandSeeding] New Region placed N =  3 , it =  1
# [01:31:45] [RandSeeding] New Region placed N =  4 , it =  16
# [01:32:14] [VPRMSeeding] Expecting points of interest in q
# [01:32:14] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:32:14] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:32:14] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:32:17] [VPRMSeeding] Sample set size 0
# [01:32:17] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:32:19] [VPRMSeeding] Sample set size 0
# [01:32:19] [VPRMSeeding] New guard placed N =  2 it =  3
# [01:32:21] [VPRMSeeding] Sample set size 2
# [01:32:22] [VPRMSeeding] New guard placed N =  3 it =  7
# [01:32:24] [VPRMSeeding] Sample set size 8
# [01:32:27] [VPRMSeeding] New Region placed N =  4 , it =  4
# [01:32:30] [VPRMSeeding] Expecting points of interest in q
# [01:32:30] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:32:30] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:32:30] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:32:33] [VPRMSeeding] Sample set size 0
# [01:32:33] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:32:35] [VPRMSeeding] Sample set size 0
# [01:32:35] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:32:37] [VPRMSeeding] Sample set size 0
# [01:32:38] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:32:40] [VPRMSeeding] Sample set size 0
# [01:32:40] [VPRMSeeding] New guard placed N =  4 it =  1
# [01:32:42] [VPRMSeeding] Sample set size 0
# [01:33:09] [VPRMSeeding] No sample found outside of regions
# [VPRMSeeding] No guard to split
# [01:33:10] [RandSeeding] Expecting points of interest in q
# [01:33:10] [RandSeeding] GuardInsertion attempts M: 28
# [01:33:10] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:33:10] [RandSeeding] New Region placed N =  0 , it =  0
# [01:33:13] [RandSeeding] New Region placed N =  1 , it =  1
# [01:33:15] [RandSeeding] New Region placed N =  2 , it =  3
# [01:33:17] [RandSeeding] New Region placed N =  3 , it =  0
# [01:33:20] [RandSeeding] New Region placed N =  4 , it =  4
# [01:33:22] [RandSeeding] New Region placed N =  5 , it =  2
# [01:33:24] [RandSeeding] New Region placed N =  6 , it =  20
# [01:33:25] [RandSeeding] New Region placed N =  7 , it =  1
# [01:33:27] [RandSeeding] New Region placed N =  8 , it =  7
# [01:33:56] [VPRMSeeding] Expecting points of interest in q
# [01:33:56] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:33:56] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:33:56] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:33:58] [VPRMSeeding] Sample set size 0
# [01:33:58] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:34:00] [VPRMSeeding] Sample set size 0
# [01:34:00] [VPRMSeeding] New guard placed N =  2 it =  2
# [01:34:02] [VPRMSeeding] Sample set size 1
# [01:34:02] [VPRMSeeding] New guard placed N =  3 it =  10
# [01:34:03] [VPRMSeeding] Sample set size 10
# [01:34:04] [VPRMSeeding] New Region placed N =  4 , it =  3
# [01:34:05] [VPRMSeeding] New Region placed N =  5 , it =  5
# [01:34:07] [VPRMSeeding] New Region placed N =  6 , it =  0
# [01:34:08] [VPRMSeeding] New Region placed N =  7 , it =  0
# [01:34:10] [VPRMSeeding] New Region placed N =  8 , it =  0
# [01:34:13] [VPRMSeeding] New Region placed N =  9 , it =  12
# [01:34:15] [VPRMSeeding] New Region placed N =  10 , it =  16
# [01:34:17] [VPRMSeeding] Expecting points of interest in q
# [01:34:17] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:34:17] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:34:17] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:34:19] [VPRMSeeding] Sample set size 0
# [01:34:19] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:34:21] [VPRMSeeding] Sample set size 0
# [01:34:21] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:34:24] [VPRMSeeding] Sample set size 0
# [01:34:24] [VPRMSeeding] New guard placed N =  3 it =  4
# [01:34:26] [VPRMSeeding] Sample set size 3
# [01:34:26] [VPRMSeeding] New guard placed N =  4 it =  2
# [01:34:28] [VPRMSeeding] Sample set size 4
# [01:34:28] [VPRMSeeding] New guard placed N =  5 it =  1
# [01:34:31] [VPRMSeeding] Sample set size 4
# [01:34:57] [VPRMSeeding] No sample found outside of regions
# [VPRMSeeding] No guard to split
# [01:34:58] [RandSeeding] Expecting points of interest in q
# [01:34:58] [RandSeeding] GuardInsertion attempts M: 28
# [01:34:58] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:34:58] [RandSeeding] New Region placed N =  0 , it =  0
# [01:35:00] [RandSeeding] New Region placed N =  1 , it =  0
# [01:35:02] [RandSeeding] New Region placed N =  2 , it =  3
# [01:35:04] [RandSeeding] New Region placed N =  3 , it =  0
# [01:35:06] [RandSeeding] New Region placed N =  4 , it =  3
# [01:35:08] [RandSeeding] New Region placed N =  5 , it =  5
# [01:35:10] [RandSeeding] New Region placed N =  6 , it =  3
# [01:35:12] [RandSeeding] New Region placed N =  7 , it =  1
# [01:35:35] [VPRMSeeding] Expecting points of interest in q
# [01:35:35] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:35:35] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:35:35] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:35:37] [VPRMSeeding] Sample set size 0
# [01:35:37] [VPRMSeeding] New guard placed N =  1 it =  2
# [01:35:39] [VPRMSeeding] Sample set size 1
# [01:35:39] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:35:40] [VPRMSeeding] Sample set size 1
# [01:35:41] [VPRMSeeding] New Region placed N =  3 , it =  0
# [01:35:42] [VPRMSeeding] New Region placed N =  4 , it =  1
# [01:35:44] [VPRMSeeding] New Region placed N =  5 , it =  3
# [01:35:46] [VPRMSeeding] New Region placed N =  6 , it =  1
# [01:35:47] [VPRMSeeding] New Region placed N =  7 , it =  7
# [01:35:50] [VPRMSeeding] New Region placed N =  8 , it =  7
# [01:35:53] [VPRMSeeding] Expecting points of interest in q
# [01:35:53] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:35:53] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:35:53] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:35:55] [VPRMSeeding] Sample set size 0
# [01:35:55] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:35:56] [VPRMSeeding] Sample set size 0
# [01:35:56] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:35:58] [VPRMSeeding] Sample set size 0
# [01:35:58] [VPRMSeeding] New guard placed N =  3 it =  1
# [01:36:00] [VPRMSeeding] Sample set size 0
# [VPRMSeeding] No guard to split
# [01:36:02] [VPRMSeeding] New Region placed N =  4 , it =  1
# [01:36:03] [VPRMSeeding] New Region placed N =  5 , it =  4
# [01:36:06] [VPRMSeeding] New Region placed N =  6 , it =  20
# [01:36:07] [VPRMSeeding] New Region placed N =  7 , it =  13
# [01:36:10] [RandSeeding] Expecting points of interest in q
# [01:36:10] [RandSeeding] GuardInsertion attempts M: 28
# [01:36:10] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:36:10] [RandSeeding] New Region placed N =  0 , it =  0
# [01:36:12] [RandSeeding] New Region placed N =  1 , it =  0
# [01:36:14] [RandSeeding] New Region placed N =  2 , it =  0
# [01:36:17] [RandSeeding] New Region placed N =  3 , it =  0
# [01:36:18] [RandSeeding] New Region placed N =  4 , it =  1
# [01:36:19] [RandSeeding] New Region placed N =  5 , it =  7
# [01:36:22] [RandSeeding] New Region placed N =  6 , it =  3
# [01:36:24] [RandSeeding] New Region placed N =  7 , it =  6
# [01:36:25] [RandSeeding] New Region placed N =  8 , it =  7
# [01:36:58] [VPRMSeeding] Expecting points of interest in q
# [01:36:58] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:36:58] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:36:58] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:37:00] [VPRMSeeding] Sample set size 0
# [01:37:00] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:37:02] [VPRMSeeding] Sample set size 0
# [01:37:02] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:37:04] [VPRMSeeding] Sample set size 0
# [01:37:05] [VPRMSeeding] New Region placed N =  3 , it =  1
# [01:37:06] [VPRMSeeding] New Region placed N =  4 , it =  0
# [01:37:08] [VPRMSeeding] New Region placed N =  5 , it =  2
# [01:37:09] [VPRMSeeding] New Region placed N =  6 , it =  6
# [01:37:12] [VPRMSeeding] New Region placed N =  7 , it =  1
# [01:37:15] [VPRMSeeding] Expecting points of interest in q
# [01:37:15] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:37:15] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:37:15] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:37:17] [VPRMSeeding] Sample set size 0
# [01:37:17] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:37:19] [VPRMSeeding] Sample set size 0
# [01:37:19] [VPRMSeeding] New guard placed N =  2 it =  2
# [01:37:22] [VPRMSeeding] Sample set size 1
# [01:37:22] [VPRMSeeding] New guard placed N =  3 it =  2
# [01:37:24] [VPRMSeeding] Sample set size 2
# [VPRMSeeding] No guard to split
# [01:37:26] [VPRMSeeding] New Region placed N =  4 , it =  8
# [01:37:28] [VPRMSeeding] New Region placed N =  5 , it =  3
# [01:37:30] [VPRMSeeding] New Region placed N =  6 , it =  13
# [01:37:31] [VPRMSeeding] New Region placed N =  7 , it =  1
# [01:37:34] [RandSeeding] Expecting points of interest in q
# [01:37:34] [RandSeeding] GuardInsertion attempts M: 28
# [01:37:34] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:37:34] [RandSeeding] New Region placed N =  0 , it =  0
# [01:37:35] [RandSeeding] New Region placed N =  1 , it =  1
# [01:37:38] [RandSeeding] New Region placed N =  2 , it =  0
# [01:37:39] [RandSeeding] New Region placed N =  3 , it =  5
# [01:37:42] [RandSeeding] New Region placed N =  4 , it =  10
# [01:37:43] [RandSeeding] New Region placed N =  5 , it =  6
# [01:37:45] [RandSeeding] New Region placed N =  6 , it =  1
# [01:38:01] [VPRMSeeding] Expecting points of interest in q
# [01:38:01] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:38:01] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:38:01] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:38:02] [VPRMSeeding] Sample set size 0
# [01:38:02] [VPRMSeeding] New guard placed N =  1 it =  3
# [01:38:03] [VPRMSeeding] Sample set size 2
# [01:38:04] [VPRMSeeding] New guard placed N =  2 it =  14
# [01:38:05] [VPRMSeeding] Sample set size 15
# [01:38:06] [VPRMSeeding] New guard placed N =  3 it =  6
# [01:38:08] [VPRMSeeding] Sample set size 20
# [01:38:09] [VPRMSeeding] New Region placed N =  4 , it =  7
# [01:38:11] [VPRMSeeding] New Region placed N =  5 , it =  11
# [01:38:12] [VPRMSeeding] New Region placed N =  6 , it =  10
# [01:38:13] [VPRMSeeding] New Region placed N =  7 , it =  3
# [01:38:15] [VPRMSeeding] Expecting points of interest in q
# [01:38:15] [VPRMSeeding] GuardInsertion attempts M: 28
# [01:38:15] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [01:38:15] [VPRMSeeding] New guard placed N =  0 it =  0
# [01:38:17] [VPRMSeeding] Sample set size 0
# [01:38:17] [VPRMSeeding] New guard placed N =  1 it =  1
# [01:38:18] [VPRMSeeding] Sample set size 0
# [01:38:18] [VPRMSeeding] New guard placed N =  2 it =  1
# [01:38:20] [VPRMSeeding] Sample set size 0
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [01:38:25] [VPRMSeeding] New guard placed N =  4 it =  0
# [01:38:26] [VPRMSeeding] Sample set size 27
# [VPRMSeeding] No guard to split
# ...
# [03:44:23] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:44:23] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:44:23] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:44:23] [VPRMSeeding] Sample set size 0
# [03:44:24] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:44:25] [VPRMSeeding] Sample set size 0
# [03:44:25] [VPRMSeeding] New guard placed N =  2 it =  3
# [03:44:26] [VPRMSeeding] Sample set size 2
# [03:44:26] [VPRMSeeding] New guard placed N =  3 it =  1
# [03:44:28] [VPRMSeeding] Sample set size 2
# [03:44:31] [VPRMSeeding] New Region placed N =  4 , it =  5
# [03:44:31] [VPRMSeeding] New Region placed N =  5 , it =  3
# [03:44:33] [VPRMSeeding] New Region placed N =  6 , it =  8
# [03:44:34] [VPRMSeeding] Expecting points of interest in q
# [03:44:34] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:44:34] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:44:34] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:44:35] [VPRMSeeding] Sample set size 0
# [03:44:35] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:44:36] [VPRMSeeding] Sample set size 0
# [03:44:37] [VPRMSeeding] New guard placed N =  2 it =  4
# [03:44:38] [VPRMSeeding] Sample set size 3
# [VPRMSeeding] No guard to split
# [03:44:41] [VPRMSeeding] New Region placed N =  3 , it =  3
# [03:44:43] [VPRMSeeding] New Region placed N =  4 , it =  11
# [03:44:43] [VPRMSeeding] New Region placed N =  5 , it =  25
# [03:44:45] [RandSeeding] Expecting points of interest in q
# [03:44:45] [RandSeeding] GuardInsertion attempts M: 28
# [03:44:45] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:44:45] [RandSeeding] New Region placed N =  0 , it =  0
# [03:44:46] [RandSeeding] New Region placed N =  1 , it =  0
# [03:44:48] [RandSeeding] New Region placed N =  2 , it =  21
# [03:45:19] [VPRMSeeding] Expecting points of interest in q
# [03:45:19] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:45:19] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:45:19] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:45:21] [VPRMSeeding] Sample set size 0
# [03:45:21] [VPRMSeeding] New guard placed N =  1 it =  2
# [03:45:24] [VPRMSeeding] Sample set size 1
# [03:45:24] [VPRMSeeding] New guard placed N =  2 it =  1
# [03:45:26] [VPRMSeeding] Sample set size 1
# [03:45:27] [VPRMSeeding] New guard placed N =  3 it =  4
# [03:45:28] [VPRMSeeding] Sample set size 4
# [03:45:28] [VPRMSeeding] New guard placed N =  4 it =  1
# [03:45:30] [VPRMSeeding] Sample set size 4
# [03:45:42] [VPRMSeeding] New Region placed N =  5 , it =  1
# [03:45:46] [VPRMSeeding] Expecting points of interest in q
# [03:45:46] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:45:46] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:45:46] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:45:47] [VPRMSeeding] Sample set size 0
# [03:45:47] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:45:50] [VPRMSeeding] Sample set size 0
# [03:45:50] [VPRMSeeding] New guard placed N =  2 it =  1
# [03:45:52] [VPRMSeeding] Sample set size 0
# [03:45:52] [VPRMSeeding] New guard placed N =  3 it =  15
# [03:45:54] [VPRMSeeding] Sample set size 14
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [VPRMSeeding] No guard to split
# [03:46:28] [VPRMSeeding] New Region placed N =  7 , it =  7
# [03:46:30] [RandSeeding] Expecting points of interest in q
# [03:46:30] [RandSeeding] GuardInsertion attempts M: 28
# [03:46:30] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:46:30] [RandSeeding] New Region placed N =  0 , it =  0
# [03:46:32] [RandSeeding] New Region placed N =  1 , it =  1
# [03:46:34] [RandSeeding] New Region placed N =  2 , it =  1
# [03:46:36] [RandSeeding] New Region placed N =  3 , it =  1
# [03:46:38] [RandSeeding] New Region placed N =  4 , it =  1
# [03:46:39] [RandSeeding] New Region placed N =  5 , it =  0
# [03:46:41] [RandSeeding] New Region placed N =  6 , it =  3
# [03:46:42] [RandSeeding] New Region placed N =  7 , it =  0
# [03:46:44] [RandSeeding] New Region placed N =  8 , it =  4
# [03:46:45] [RandSeeding] New Region placed N =  9 , it =  0
# [03:46:48] [RandSeeding] New Region placed N =  10 , it =  14
# [03:47:12] [VPRMSeeding] Expecting points of interest in q
# [03:47:12] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:47:12] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:47:12] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:47:14] [VPRMSeeding] Sample set size 0
# [03:47:14] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:47:15] [VPRMSeeding] Sample set size 0
# [03:47:16] [VPRMSeeding] New guard placed N =  2 it =  2
# [03:47:17] [VPRMSeeding] Sample set size 1
# [03:47:18] [VPRMSeeding] New guard placed N =  3 it =  4
# [03:47:19] [VPRMSeeding] Sample set size 4
# [03:47:20] [VPRMSeeding] New guard placed N =  4 it =  3
# [03:47:21] [VPRMSeeding] Sample set size 6
# [03:47:23] [VPRMSeeding] New Region placed N =  5 , it =  7
# [03:47:25] [VPRMSeeding] New Region placed N =  6 , it =  6
# [03:47:27] [VPRMSeeding] Expecting points of interest in q
# [03:47:27] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:47:27] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:47:27] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:47:29] [VPRMSeeding] Sample set size 0
# [03:47:29] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:47:30] [VPRMSeeding] Sample set size 0
# [03:47:31] [VPRMSeeding] New guard placed N =  2 it =  2
# [03:47:32] [VPRMSeeding] Sample set size 1
# [03:47:32] [VPRMSeeding] New guard placed N =  3 it =  1
# [03:47:34] [VPRMSeeding] Sample set size 1
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [VPRMSeeding] No guard to split
# [03:47:46] [RandSeeding] Expecting points of interest in q
# [03:47:46] [RandSeeding] GuardInsertion attempts M: 28
# [03:47:46] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:47:46] [RandSeeding] New Region placed N =  0 , it =  0
# [03:47:48] [RandSeeding] New Region placed N =  1 , it =  0
# [03:47:50] [RandSeeding] New Region placed N =  2 , it =  0
# [03:47:51] [RandSeeding] New Region placed N =  3 , it =  1
# [03:47:52] [RandSeeding] New Region placed N =  4 , it =  2
# [03:47:53] [RandSeeding] New Region placed N =  5 , it =  2
# [03:47:54] [RandSeeding] New Region placed N =  6 , it =  3
# [03:47:56] [RandSeeding] New Region placed N =  7 , it =  0
# [03:47:58] [RandSeeding] New Region placed N =  8 , it =  16
# [03:48:00] [RandSeeding] New Region placed N =  9 , it =  15
# [03:48:13] [VPRMSeeding] Expecting points of interest in q
# [03:48:13] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:48:13] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:48:14] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:48:15] [VPRMSeeding] Sample set size 0
# [03:48:15] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:48:16] [VPRMSeeding] Sample set size 0
# [03:48:16] [VPRMSeeding] New guard placed N =  2 it =  1
# [03:48:18] [VPRMSeeding] Sample set size 0
# [03:48:18] [VPRMSeeding] New guard placed N =  3 it =  1
# [03:48:19] [VPRMSeeding] Sample set size 0
# [03:48:24] [VPRMSeeding] New guard placed N =  4 it =  7
# [03:48:25] [VPRMSeeding] Sample set size 6
# [03:48:51] [VPRMSeeding] Expecting points of interest in q
# [03:48:51] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:48:51] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:48:51] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:48:52] [VPRMSeeding] Sample set size 0
# [03:48:52] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:48:54] [VPRMSeeding] Sample set size 0
# [03:48:54] [VPRMSeeding] New guard placed N =  2 it =  1
# [03:48:55] [VPRMSeeding] Sample set size 0
# [03:48:57] [VPRMSeeding] New guard placed N =  3 it =  15
# [03:48:58] [VPRMSeeding] Sample set size 14
# [VPRMSeeding] No guard to split
# [03:49:00] [VPRMSeeding] New Region placed N =  4 , it =  4
# [03:49:02] [VPRMSeeding] New Region placed N =  5 , it =  22
# [03:49:04] [RandSeeding] Expecting points of interest in q
# [03:49:04] [RandSeeding] GuardInsertion attempts M: 28
# [03:49:04] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:49:04] [RandSeeding] New Region placed N =  0 , it =  0
# [03:49:05] [RandSeeding] New Region placed N =  1 , it =  0
# [03:49:07] [RandSeeding] New Region placed N =  2 , it =  2
# [03:49:08] [RandSeeding] New Region placed N =  3 , it =  0
# [03:49:10] [RandSeeding] New Region placed N =  4 , it =  6
# [03:49:10] [RandSeeding] New Region placed N =  5 , it =  0
# [03:49:12] [RandSeeding] New Region placed N =  6 , it =  7
# [03:49:13] [RandSeeding] New Region placed N =  7 , it =  8
# [03:49:14] [RandSeeding] New Region placed N =  8 , it =  3
# [03:49:15] [RandSeeding] New Region placed N =  9 , it =  7
# [03:49:16] [RandSeeding] New Region placed N =  10 , it =  1
# [03:49:36] [VPRMSeeding] Expecting points of interest in q
# [03:49:36] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:49:36] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:49:36] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:49:38] [VPRMSeeding] Sample set size 0
# [03:49:38] [VPRMSeeding] New guard placed N =  1 it =  4
# [03:49:39] [VPRMSeeding] Sample set size 3
# [03:49:39] [VPRMSeeding] New guard placed N =  2 it =  1
# [03:49:41] [VPRMSeeding] Sample set size 3
# [03:49:41] [VPRMSeeding] New guard placed N =  3 it =  1
# [03:49:42] [VPRMSeeding] Sample set size 3
# [03:49:42] [VPRMSeeding] New guard placed N =  4 it =  4
# [03:49:44] [VPRMSeeding] Sample set size 6
# [03:49:47] [VPRMSeeding] New Region placed N =  5 , it =  3
# [03:49:49] [VPRMSeeding] New Region placed N =  6 , it =  3
# [03:49:51] [VPRMSeeding] Expecting points of interest in q
# [03:49:51] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:49:51] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:49:51] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:49:52] [VPRMSeeding] Sample set size 0
# [03:49:52] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:49:54] [VPRMSeeding] Sample set size 0
# [03:49:54] [VPRMSeeding] New guard placed N =  2 it =  10
# [03:49:55] [VPRMSeeding] Sample set size 9
# [03:49:55] [VPRMSeeding] New guard placed N =  3 it =  7
# [03:49:57] [VPRMSeeding] Sample set size 15
# [VPRMSeeding] No guard to split
# [03:49:58] [VPRMSeeding] New Region placed N =  4 , it =  1
# [03:50:00] [VPRMSeeding] New Region placed N =  5 , it =  12
# [03:50:02] [VPRMSeeding] New Region placed N =  6 , it =  0
# [03:50:04] [VPRMSeeding] New Region placed N =  7 , it =  0
# [03:50:06] [VPRMSeeding] New Region placed N =  8 , it =  7
# [03:50:07] [VPRMSeeding] New Region placed N =  9 , it =  20
# [03:50:09] [RandSeeding] Expecting points of interest in q
# [03:50:09] [RandSeeding] GuardInsertion attempts M: 28
# [03:50:09] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:50:09] [RandSeeding] New Region placed N =  0 , it =  0
# [03:50:10] [RandSeeding] New Region placed N =  1 , it =  0
# [03:50:12] [RandSeeding] New Region placed N =  2 , it =  1
# [03:50:14] [RandSeeding] New Region placed N =  3 , it =  0
# [03:50:15] [RandSeeding] New Region placed N =  4 , it =  0
# [03:50:16] [RandSeeding] New Region placed N =  5 , it =  2
# [03:50:17] [RandSeeding] New Region placed N =  6 , it =  1
# [03:50:19] [RandSeeding] New Region placed N =  7 , it =  7
# [03:50:41] [VPRMSeeding] Expecting points of interest in q
# [03:50:41] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:50:41] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:50:41] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:50:43] [VPRMSeeding] Sample set size 0
# [03:50:43] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:50:44] [VPRMSeeding] Sample set size 0
# [03:50:44] [VPRMSeeding] New guard placed N =  2 it =  4
# [03:50:45] [VPRMSeeding] Sample set size 3
# [03:50:46] [VPRMSeeding] New guard placed N =  3 it =  16
# [03:50:48] [VPRMSeeding] Sample set size 18
# [03:50:49] [VPRMSeeding] New Region placed N =  4 , it =  6
# [03:50:51] [VPRMSeeding] New Region placed N =  5 , it =  3
# [03:50:52] [VPRMSeeding] New Region placed N =  6 , it =  2
# [03:50:54] [VPRMSeeding] Expecting points of interest in q
# [03:50:54] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:50:54] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:50:54] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:50:56] [VPRMSeeding] Sample set size 0
# [03:50:56] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:50:57] [VPRMSeeding] Sample set size 0
# [03:50:57] [VPRMSeeding] New guard placed N =  2 it =  1
# [03:50:59] [VPRMSeeding] Sample set size 0
# [03:50:59] [VPRMSeeding] New guard placed N =  3 it =  1
# [03:51:00] [VPRMSeeding] Sample set size 0
# [03:51:01] [VPRMSeeding] New guard placed N =  4 it =  3
# [03:51:03] [VPRMSeeding] Sample set size 2
# [VPRMSeeding] Guard found to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard
# [VPRMSeeding] No guard to split
# [03:51:29] [RandSeeding] Expecting points of interest in q
# [03:51:29] [RandSeeding] GuardInsertion attempts M: 28
# [03:51:29] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:51:29] [RandSeeding] New Region placed N =  0 , it =  0
# [03:51:30] [RandSeeding] New Region placed N =  1 , it =  0
# [03:51:32] [RandSeeding] New Region placed N =  2 , it =  0
# [03:51:33] [RandSeeding] New Region placed N =  3 , it =  5
# [03:51:34] [RandSeeding] New Region placed N =  4 , it =  10
# [03:51:36] [RandSeeding] New Region placed N =  5 , it =  19
# [03:52:01] [VPRMSeeding] Expecting points of interest in q
# [03:52:01] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:52:01] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:52:01] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:52:02] [VPRMSeeding] Sample set size 0
# [03:52:02] [VPRMSeeding] New guard placed N =  1 it =  2
# [03:52:04] [VPRMSeeding] Sample set size 1
# [03:52:04] [VPRMSeeding] New guard placed N =  2 it =  4
# [03:52:06] [VPRMSeeding] Sample set size 4
# [03:52:06] [VPRMSeeding] New guard placed N =  3 it =  4
# [03:52:08] [VPRMSeeding] Sample set size 7
# [03:52:08] [VPRMSeeding] New guard placed N =  4 it =  3
# [03:52:10] [VPRMSeeding] Sample set size 9
# [03:52:40] [VPRMSeeding] Expecting points of interest in q
# [03:52:40] [VPRMSeeding] GuardInsertion attempts M: 28
# [03:52:40] [VPRMSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:52:40] [VPRMSeeding] New guard placed N =  0 it =  0
# [03:52:42] [VPRMSeeding] Sample set size 0
# [03:52:42] [VPRMSeeding] New guard placed N =  1 it =  1
# [03:52:44] [VPRMSeeding] Sample set size 0
# [03:52:44] [VPRMSeeding] New guard placed N =  2 it =  1
# [03:52:46] [VPRMSeeding] Sample set size 0
# [03:52:46] [VPRMSeeding] New guard placed N =  3 it =  1
# [03:52:48] [VPRMSeeding] Sample set size 0
# [03:52:49] [VPRMSeeding] New guard placed N =  4 it =  5
# [03:52:51] [VPRMSeeding] Sample set size 4
# [VPRMSeeding] No guard to split
# [03:53:32] [RandSeeding] Expecting points of interest in q
# [03:53:32] [RandSeeding] GuardInsertion attempts M: 28
# [03:53:32] [RandSeeding] 0.95 probability that unseen region is less than 10.0 "%" of Cfree
# [03:53:32] [RandSeeding] New Region placed N =  0 , it =  0
# [03:53:34] [RandSeeding] New Region placed N =  1 , it =  0
# [03:53:36] [RandSeeding] New Region placed N =  2 , it =  2
# [03:53:38] [RandSeeding] New Region placed N =  3 , it =  0
# [03:53:40] [RandSeeding] New Region placed N =  4 , it =  1
# [03:53:41] [RandSeeding] New Region placed N =  5 , it =  0
# [03:53:43] [RandSeeding] New Region placed N =  6 , it =  6

# %%
f = open("22_12_05_20_05_02_2d_randenv_eval_uisng_fill_remaining_space.log", "r")
lines = f.readlines()
vprmseed = {}
vprmseed['nr'] = []
vprmseed['ng'] = []
vprmseed['seed'] = []
vprmseed['coverage'] = []
vprmseed['coverage_guards'] = []
vprmseed['runtime'] = []
vprmseed['optcover'] = []

vprm2seed = {}
vprm2seed['nr'] = []
vprm2seed['ng'] = []
vprm2seed['seed'] = []
vprm2seed['coverage'] = []
vprm2seed['coverage_guards'] = []
vprm2seed['runtime'] = []
vprm2seed['optcover'] = []


randseed = {}
randseed['nr'] = []
randseed['ng'] = []
randseed['seed'] = []
randseed['coverage'] = []
randseed['coverage_guards'] = []
randseed['runtime'] = []
randseed['optcover'] = []


joint_keys = ['nr','ng','runtime', 'coverage', 'coverage_guards']
idx = 0
while idx< len(lines):
    if '--visprmraw' in lines[idx]:
        #print(lines[idx:idx+6])
        line_run = lines[idx:idx+8]
        vprmseed['seed'].append(int(line_run[1][5:-2]))
        vprmseed['nr'].append(int(line_run[2][4:-2]))
        vprmseed['ng'].append(int(line_run[3][4:-2]))  
        vprmseed['coverage'].append(float(line_run[4][9:-2]))
        vprmseed['coverage_guards'].append(float(line_run[5][16:-2]))
        vprmseed['runtime'].append(float(line_run[6][8:-2]))
        vprmseed['optcover'].append(int(line_run[7][9:-2]))
        #print(line_run[5][9:-2])
        #print(int(line_run[1][5:-2]))
        #  
        #  
        idx+=8
    elif '--visprmimp' in lines[idx]:
        #print(lines[idx:idx+5])
        line_run = lines[idx:idx+8]
        vprm2seed['seed'].append(int(line_run[1][5:-2]))
        vprm2seed['nr'].append(int(line_run[2][4:-2]))
        vprm2seed['ng'].append(int(line_run[3][4:-2]))  
        vprm2seed['coverage'].append(float(line_run[4][9:-2]))
        vprm2seed['coverage_guards'].append(float(line_run[5][16:-2]))
        vprm2seed['runtime'].append(float(line_run[6][8:-2]))
        vprm2seed['optcover'].append(int(line_run[7][9:-2]))
        idx +=8
    elif '--rand' in lines[idx]:
        #print(lines[idx:idx+5])
        line_run = lines[idx:idx+8]
        randseed['seed'].append(int(line_run[1][5:-2]))
        randseed['nr'].append(int(line_run[2][4:-2]))
        randseed['ng'].append(int(line_run[3][4:-2]))  
        randseed['coverage'].append(float(line_run[4][9:-2]))
        randseed['coverage_guards'].append(float(line_run[5][16:-2]))
        randseed['runtime'].append(float(line_run[6][8:-2]))
        randseed['optcover'].append(int(line_run[7][9:-2]))
        idx +=8
    #idx +=1
f.close()

# %%
minreg = np.min(vprmseed['optcover'])
maxreg = np.max(vprmseed['optcover'])
for r in (np.arange(maxreg-minreg + 1) + minreg):
    idx_plt = np.where(vprmseed['optcover'] == r )[0]
    idx_plt2 = np.where(np.array(vprm2seed['runtime'])[idx_plt] < 3.5*np.mean(np.array(vprm2seed['runtime'])[idx_plt]))[0]
    print('outliers:', len(idx_plt)-len(idx_plt2))
    #idx_plt = idx_plt[idx_plt2]
    fig, axs = plt.subplots(nrows = 1, ncols = len(joint_keys), figsize = (25, 5))
    for ax, key in zip(axs, joint_keys):
        nfields = 3
        xpos = np.arange(nfields)
        labels = [key+'_vis',key+'_visimp', key+'_rand']
        data_mean = [np.mean(np.array(vprmseed[key])[idx_plt]*1.0),
                     np.mean(np.array(vprm2seed[key])[idx_plt]*1.0),
                     np.mean(np.array(randseed[key])[idx_plt]*1.0)]
        data_std = [np.std(np.array(vprmseed[key])[idx_plt]*1.0),
                    np.std(np.array(vprm2seed[key])[idx_plt]*1.0),
                    np.std(np.array(randseed[key])[idx_plt]*1.0)]
        ax.bar(xpos, data_mean, yerr = data_std,color=['#1f77b4','#ff7f0e', '#2ca02c'], ecolor='black', capsize=20)
        ax.set_xticks(xpos)
        ax.set_xticklabels(labels)
        #if key == 'nr':
            #minor_ticks = np.arange(0, np.max(np.array(randseed[key])[idx_plt]*1.0))
            #ax.set_yticks(minor_ticks, minor=True)
            #major_ticks = np.arange(0, int(np.max(np.array(randseed[key])[idx_plt]*1.0)/2),2)
            #ax.set_yticks(minor_ticks, minor=True)
            #ax.set_yticks(major_ticks)
            #ax.grid(which='minor', alpha=0.5)
            #ax.set_yticklabels([str(l) for l in major_ticks])
        ax.grid(axis = 'y')
        #ax.grid(which='major', alpha=0.9)
        
    fig.suptitle('Optimal cover of Cfree '+ str(r)+', N ='+str(len(idx_plt)), fontsize=16)
# Out:
# outliers: 0
# outliers: 1
# outliers: 0

# %%
# Out:
# [22:41:12] [VPRMSeeding] Expecting points of interest in q
# [22:41:12] [VPRMSeeding] GuardInsertion attempts M: 58
# [22:41:12] [VPRMSeeding] 0.95 probability that unseen region is less than 5.0 "%" of Cfree

# %%
vs.guard_phase()
# Out:
# [22:42:38] [VPRMSeeding] New guard placed N =  0 it =  0
# [22:42:40] [VPRMSeeding] Sample set size 0
# [22:42:40] [VPRMSeeding] New guard placed N =  1 it =  1
# [22:42:42] [VPRMSeeding] Sample set size 0
# [22:42:42] [VPRMSeeding] New guard placed N =  2 it =  2
# [22:42:43] [VPRMSeeding] Sample set size 1
# [22:42:44] [VPRMSeeding] New guard placed N =  3 it =  3
# [22:42:46] [VPRMSeeding] Sample set size 3

# %%
# Out:
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] N =  1  guards to split
# [VPRMSeeding] Splitting guard  1 / 1

# %%
kers = [vs.compute_kernel_of_guard(g) for g in vs.guard_regions]

# %%
kers
# Out:
# [None, None, None, None, None]

# %%
np.array(vprm2seed['runtime'])[np.where(np.array(vprmseed['optcover'])==8)[0]]
# Out:
# array([ 48.6236,  23.0327,  17.0786,  41.2813,  14.2204,  20.2719,
#         11.0731,   2.4335, 198.4149,  17.3305,  11.6248,  26.3205,
#         16.6353,  17.7803,  16.7957,  17.3523,  22.4271,  16.5182,
#         22.6369,  74.8311,  15.882 ,   4.9132,  18.3519,  21.0962,
#         10.9409,  66.7331,  17.0792])

# %%
 np.array([[np.cos(rot), -np.sin(rot)], [np.sin(rot), np.cos(rot)]])
# Out:
# array([[ 0.28465179, -0.95863098],
#        [ 0.95863098,  0.28465179]])

# %%
np.array([[a, 0], [0, b]]) @ np.array([[np.cos(rot), -np.sin(rot)], [np.sin(rot), np.cos(rot)]])
# Out:
# <ipython-input-145-86ba80001d67>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array([[a, 0], [0, b]]) @ np.array([[np.cos(rot), -np.sin(rot)], [np.sin(rot), np.cos(rot)]])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-86ba80001d67> in <module>
# ----> 1 np.array([[a, 0], [0, b]]) @ np.array([[np.cos(rot), -np.sin(rot)], [np.sin(rot), np.cos(rot)]])
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# Latex: a^2

# %%
# Out:
# 300.0

# %%
maxsize.A().shape
# Out:
# (2, 1)

# %%
e = region.MaximumVolumeInscribedEllipsoid()

# %%
e.center()
e.A()
# Out:
# array([[ 0.68150551, -0.17727269],
#        [-0.17727269,  0.73182934]])
