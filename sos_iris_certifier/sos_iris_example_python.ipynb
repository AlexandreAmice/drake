# %%
# %load_ext autoreload

# %%
from certified_iris_generator import CertifiedIrisRegionGenerator
import sys
import os
import time
import numpy as np
from functools import partial
import itertools
import mcubes
import visualizations_utils as viz_utils
import iris_utils #TODO remove
from iris_plant_visualizer import IrisPlantVisualizer

# %%
#pydrake imports
from pydrake.common import FindResourceOrThrow
from pydrake.multibody.parsing import LoadModelDirectives, Parser, ProcessModelDirectives
from pydrake.multibody.plant import MultibodyPlant, AddMultibodyPlantSceneGraph
from pydrake.systems.framework import DiagramBuilder
from pydrake.all import InverseKinematics, RevoluteJoint
import pydrake.symbolic as sym
from pydrake.all import MathematicalProgram
import meshcat

# %% [markdown]
# # Build plant

# %%
builder = DiagramBuilder()
plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.001)
parser = Parser(plant)
parser.package_map().Add( "wsg_50_description", os.path.dirname(FindResourceOrThrow(
            "drake/manipulation/models/wsg_50_description/package.xml")))

simple_collision = True
directives_file = FindResourceOrThrow("drake/sos_iris_certifier/planar_iiwa_simple_collision_welded_gripper.yaml") \
    if simple_collision else FindResourceOrThrow("drake/sos_iris_certifier/planar_iiwa_dense_collision_welded_gripper.yaml")
directives = LoadModelDirectives(directives_file)
models = ProcessModelDirectives(directives, plant, parser)

q0 = [-0.2, -1.2, 1.6]
index = 0
for joint_index in plant.GetJointIndices(models[0].model_instance):
    joint = plant.get_mutable_joint(joint_index)
    if isinstance(joint, RevoluteJoint):
        joint.set_default_angle(q0[index])
        index += 1

plant.Finalize()
# visualizer = ConnectMeshcatVisualizer(builder, scene_graph, zmq_url=zmq_url, 
#                                       delete_prefix_on_load=False)

# diagram = builder.Build()
# visualizer.load()

# %% [markdown]
# # Setup meshcat visualization

# %%
do_viz = True
visualizer = IrisPlantVisualizer(plant, builder, scene_graph)
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7000/static/
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7001/static/
# Connecting to meshcat-server at zmq_url=tcp://127.0.0.1:6000...
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7000/static/
# Connected to meshcat-server.

# %% [markdown]
# # Build Certified Iris Region Object

# %%
iris_kwargs = {
    'iris_starting_ellipse_vol': 1e-5,
    'iris_plane_pullback': 1e-4,
    'iris_max_faces': -1
}

# %%
iris_generator = CertifiedIrisRegionGenerator(visualizer.diagram, plant, scene_graph, **iris_kwargs)

# %%
seed_points = np.tan(np.array([
                        [0.0, -2.016, 1.975], # in tight
                        [-1, -2, 0.5],        # neutral pose
                        [0.3, -0.8, 0.5],     # above shelf
                        [0.25, -1.6, -0.25],  # in shelf 1
                        [0.07, -1.8, -0.2],   # leaving shelf 1
                        [-0.1, -2, -0.3]      # out of shelf 1
                        ])    
                        /2)

regions, ellipses = iris_generator.iris_in_rational_space(seed_points)
# Out:
# 0
# snopt_example=[ 0.35529068 -0.22984731  0.02559963], growth = 0.05990553085918943
# snopt_example=[ 0.28673366 -0.30128467  0.33402563], growth = 0.09485392272232375
# snopt_example=[ 0.28776043 -0.30045108  0.32725976], growth = 0.09339195802962706
# terminating because a required containment point would have not been contained
# Time:   1.60 	Volume:  21.77 	Center: [1.44312073e-09 1.44280166e-09 1.44440504e-09]
# 0
# snopt_example=[ 0.35529266 -0.22984424  0.02559962], growth = 0.05990553077553568
# snopt_example=[ 0.30804713 -0.27858144  0.24207296], growth = 0.07703332293708175
# terminating because a required containment point would have not been contained
# Time:   0.97 	Volume:  21.77 	Center: [1.44312073e-09 1.44280166e-09 1.44440504e-09]
# snopt_example=[ 0.30547805 -0.52068241  0.30020753], growth = 354169277.01944494
# snopt_example=[ 0.19754042 -0.45436384  0.26846797], growth = 33224401.49490118
# snopt_example=[ 0.19598983 -0.45413506  0.27106354], growth = 32414169.41665411
# 0
# snopt_example=[ 0.25288847 -0.44449967 -0.37464989], growth = 0.912138483568273
# snopt_example=[ 0.18157379 -0.53600489  0.00189671], growth = 0.9684646251985066
# 1
# Time:   1.21 	Volume:  12.19 	Center: [-5.93192095e-01  1.95007389e-03 -8.55497895e-10]
# snopt_example=[ 0.14656408 -0.84562199 -0.13081511], growth = 343259046.2922268
# snopt_example=[ 0.17280708 -1.04877622 -0.10765289], growth = 29136367.0897274
# snopt_example=[ 0.06137677 -0.99983866 -0.14668241], growth = 54618887.631809235
# snopt_example=[ 0.17352108 -1.04860175 -0.1108319 ], growth = 28704798.86587906
# snopt_example=[ 0.06466578 -1.00097992 -0.15800253], growth = 55873730.15094948
# snopt_example=[ 0.1728816  -1.02194198 -0.13221416], growth = 23325971.551347733
# 0
# snopt_example=[ 0.00207098 -1.14285276  0.2377722 ], growth = 2.272280574017884
# snopt_example=[ 0.03282351 -1.05114402 -0.13175643], growth = 2.560665207447258
# snopt_example=[-0.01769206 -1.41938734 -0.37318404], growth = 1.4671353843082784
# 1
# Time:   1.53 	Volume:   0.10 	Center: [-0.23884111 -1.26392734  0.57306953]
# snopt_example=[ 0.0778842  -1.27513263 -0.08274095], growth = 23716006.20109558
# snopt_example=[ 0.03898985 -1.07021074 -0.17559715], growth = 417602916.3468838
# snopt_example=[ 0.09564873 -1.27442261 -0.12569953], growth = 45233827.539676666
# 0
# snopt_example=[-0.01859393 -1.31935946  0.11015956], growth = 1.3385684718502784
# snopt_example=[-0.06601946 -1.27711933 -0.13507732], growth = 1.2801487183572036
# terminating because a required containment point would have not been contained
# Time:   1.34 	Volume:   1.59 	Center: [-0.93707086 -1.24517522  0.44866111]
# snopt_example=[ 0.00289142 -1.57259365 -0.12735192], growth = 35981742.57167435
# snopt_example=[-0.04454859 -1.36744184 -0.26173144], growth = 483487364.33952713
# 0
# snopt_example=[-0.02534964 -1.54159187 -0.0449546 ], growth = 2.4022505649777557
# terminating because a required containment point would have not been contained
# Time:   1.07 	Volume:   1.14 	Center: [-1.02436376 -1.20636765  0.79325703]

# %%
trajectory_start = np.tan(np.array([-1, -2, 0.5])/2) # seed_points[1,:]
trajectory_end = np.tan(np.array([0.25, -1.6, -0.25])/2)  #seed_points[3,:]

# %%
# plot regions and collision constraint
if do_viz:
    visualizer.plot_regions(regions, ellipses)
    visualizer.plot_seedpoints(seed_points)
    visualizer.visualize_collision_constraint(N = 50)

# %% [markdown]
# ## Certify the regions

# %%
iris_generator.initalize_certifier(plane_order = 1, strict_pos_tol = 1e-4)
# Out:
# Time to initialize region program: 1.1547
# time to create Region Certification Problem: : 0.6598
# Time to initialize region program: 1.2132
# time to create Region Certification Problem: : 0.7493
# Time to initialize region program: 1.5558
# time to create Region Certification Problem: : 1.7024
# Time to initialize region program: 1.6348
# time to create Region Certification Problem: : 2.8344
# Time to initialize region program: 1.5424
# time to create Region Certification Problem: : 1.2899
# Time to initialize region program: 1.5429
# time to create Region Certification Problem: : 0.9933
# {<pydrake.geometry.optimization.HPolyhedron at 0x7f0d90d5b0b0>: <certified_iris_generator.RegionCertificationProblem at 0x7f0d90ed8820>,
#  <pydrake.geometry.optimization.HPolyhedron at 0x7f0d90d61870>: <certified_iris_generator.RegionCertificationProblem at 0x7f0d90d5fac0>,
#  <pydrake.geometry.optimization.HPolyhedron at 0x7f0d90d6de30>: <certified_iris_generator.RegionCertificationProblem at 0x7f0d90d5fee0>,
#  <pydrake.geometry.optimization.HPolyhedron at 0x7f0d9154aa70>: <certified_iris_generator.RegionCertificationProblem at 0x7f0d90d5fc40>,
#  <pydrake.geometry.optimization.HPolyhedron at 0x7f0d90d76a30>: <certified_iris_generator.RegionCertificationProblem at 0x7f0dc8482310>,
#  <pydrake.geometry.optimization.HPolyhedron at 0x7f0d90d76870>: <certified_iris_generator.RegionCertificationProblem at 0x7f0dc8482d60>}

# %%
do_linesearch_cert = True
if do_linesearch_cert:
    iris_generator.certify_and_adjust_regions_by_linesearch(1e-5)
# Out:
# Starting Region 1/6
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.8660254  1.65860451 0.10832327 0.8660254  0.07344629 1.62372753]
# max_eps = [1.73205081 3.31720903 0.21664655 1.73205081 0.14689259 3.24745507]
# Biggest difference: 3.317209025457233
# Smallest difference: 0.14689258966773977
# Fixed eps is not success
#
# min_eps = [0.8660254  1.65860451 0.10832327 0.8660254  0.07344629 1.62372753]
# cur_eps = [1.29903811 2.48790677 0.16248491 1.29903811 0.11016944 2.4355913 ]
# max_eps = [1.73205081 3.31720903 0.21664655 1.73205081 0.14689259 3.24745507]
# Biggest difference: 1.6586045127286164
# Smallest difference: 0.07344629483386989
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.62634388 1.24395338 0.08124245 0.46510824 0.05508472 1.21779565]
# max_eps = [1.25268776 2.48790677 0.1624849  0.93021648 0.11016943 2.4355913 ]
# Biggest difference: 2.487906768142779
# Smallest difference: 0.11016943388782734
# Fixed eps is not success
#
# min_eps = [0.62634388 1.24395338 0.08124245 0.46510824 0.05508472 1.21779565]
# cur_eps = [0.93951582 1.86593008 0.12186367 0.69766236 0.08262708 1.82669347]
# max_eps = [1.25268776 2.48790677 0.1624849  0.93021648 0.11016943 2.4355913 ]
# Biggest difference: 1.2439533840713894
# Smallest difference: 0.05508471694391367
# Fixed eps is not success
#
# min_eps = [0.93951582 1.86593008 0.12186367 0.69766236 0.08262708 1.82669347]
# cur_eps = [1.09610179 2.17691842 0.14217429 0.81393942 0.09639825 2.13114239]
# max_eps = [1.25268776 2.48790677 0.1624849  0.93021648 0.11016943 2.4355913 ]
# Biggest difference: 0.6219766920356946
# Smallest difference: 0.027542358471956838
# Fixed eps is not success
#
# min_eps = [1.09610179 2.17691842 0.14217429 0.81393942 0.09639825 2.13114239]
# cur_eps = [1.17439478 2.3324126  0.15232959 0.87207795 0.10328384 2.28336684]
# max_eps = [1.25268776 2.48790677 0.1624849  0.93021648 0.11016943 2.4355913 ]
# Biggest difference: 0.3109883460178473
# Smallest difference: 0.013771179235978412
# Fixed eps is not success
#
# min_eps = [1.17439478 2.3324126  0.15232959 0.87207795 0.10328384 2.28336684]
# cur_eps = [1.21354127 2.41015968 0.15740725 0.90114721 0.10672664 2.35947907]
# max_eps = [1.25268776 2.48790677 0.1624849  0.93021648 0.11016943 2.4355913 ]
# Biggest difference: 0.15549417300892365
# Smallest difference: 0.006885589617989199
# Fixed eps is not success
#
# min_eps = [1.21354127 2.41015968 0.15740725 0.90114721 0.10672664 2.35947907]
# cur_eps = [1.23311452 2.44903322 0.15994607 0.91568185 0.10844804 2.39753518]
# max_eps = [1.25268776 2.48790677 0.1624849  0.93021648 0.11016943 2.4355913 ]
# Biggest difference: 0.07774708650446183
# Smallest difference: 0.0034427948089946064
# Fixed eps is not success
#
# min_eps = [1.23311452 2.44903322 0.15994607 0.91568185 0.10844804 2.39753518]
# cur_eps = [1.24290114 2.46847    0.16121549 0.92294916 0.10930874 2.41656324]
# max_eps = [1.25268776 2.48790677 0.1624849  0.93021648 0.11016943 2.4355913 ]
# Biggest difference: 0.03887354325223091
# Smallest difference: 0.0017213974044972963
# Fixed eps is not success
#
# min_eps = [1.24290114 2.46847    0.16121549 0.92294916 0.10930874 2.41656324]
# cur_eps = [1.24779445 2.47818838 0.16185019 0.92658282 0.10973908 2.42607727]
# max_eps = [1.25268776 2.48790677 0.1624849  0.93021648 0.11016943 2.4355913 ]
# Biggest difference: 0.019436771626115235
# Smallest difference: 0.0008606987022486551
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.57801656 1.23909419 0.08092497 0.29989881 0.05486946 1.21303863]
# max_eps = [1.15603313 2.47818837 0.16184995 0.59979763 0.10973892 2.42607726]
# Biggest difference: 2.478188374330926
# Smallest difference: 0.10973892336861109
# Fixed eps is not success
#
# min_eps = [0.57801656 1.23909419 0.08092497 0.29989881 0.05486946 1.21303863]
# cur_eps = [0.86702484 1.85864128 0.12138746 0.44984822 0.08230419 1.81955795]
# max_eps = [1.15603313 2.47818837 0.16184995 0.59979763 0.10973892 2.42607726]
# Biggest difference: 1.239094187165463
# Smallest difference: 0.054869461684305544
# Fixed eps is not success
#
# min_eps = [0.86702484 1.85864128 0.12138746 0.44984822 0.08230419 1.81955795]
# cur_eps = [1.01152899 2.16841483 0.1416187  0.52482293 0.09602156 2.1228176 ]
# max_eps = [1.15603313 2.47818837 0.16184995 0.59979763 0.10973892 2.42607726]
# Biggest difference: 0.6195470935827316
# Smallest difference: 0.02743473084215277
# Fixed eps is not success
#
# min_eps = [1.01152899 2.16841483 0.1416187  0.52482293 0.09602156 2.1228176 ]
# cur_eps = [1.08378106 2.3233016  0.15173433 0.56231028 0.10288024 2.27444743]
# max_eps = [1.15603313 2.47818837 0.16184995 0.59979763 0.10973892 2.42607726]
# Biggest difference: 0.3097735467913658
# Smallest difference: 0.013717365421076391
# Fixed eps is not success
#
# min_eps = [1.08378106 2.3233016  0.15173433 0.56231028 0.10288024 2.27444743]
# cur_eps = [1.11990709 2.40074499 0.15679214 0.58105395 0.10630958 2.35026235]
# max_eps = [1.15603313 2.47818837 0.16184995 0.59979763 0.10973892 2.42607726]
# Biggest difference: 0.1548867733956829
# Smallest difference: 0.0068586827105382026
# Fixed eps is not success
#
# min_eps = [1.11990709 2.40074499 0.15679214 0.58105395 0.10630958 2.35026235]
# cur_eps = [1.13797011 2.43946668 0.15932104 0.59042579 0.10802425 2.3881698 ]
# max_eps = [1.15603313 2.47818837 0.16184995 0.59979763 0.10973892 2.42607726]
# Biggest difference: 0.07744338669784145
# Smallest difference: 0.003429341355269108
# Fixed eps is not success
#
# min_eps = [1.13797011 2.43946668 0.15932104 0.59042579 0.10802425 2.3881698 ]
# cur_eps = [1.14700162 2.45882753 0.1605855  0.59511171 0.10888159 2.40712353]
# max_eps = [1.15603313 2.47818837 0.16184995 0.59979763 0.10973892 2.42607726]
# Biggest difference: 0.03872169334892073
# Smallest difference: 0.0017146706776345472
# Fixed eps is not success
#
# min_eps = [1.14700162 2.45882753 0.1605855  0.59511171 0.10888159 2.40712353]
# cur_eps = [1.15151737 2.46850795 0.16121772 0.59745467 0.10931026 2.4166004 ]
# max_eps = [1.15603313 2.47818837 0.16184995 0.59979763 0.10973892 2.42607726]
# Biggest difference: 0.019360846674460586
# Smallest difference: 0.0008573353388172805
# Fixed eps is not success
#
# min_eps = [1.15151737 2.46850795 0.16121772 0.59745467 0.10931026 2.4166004 ]
# cur_eps = [1.15377525 2.47334816 0.16153384 0.59862615 0.10952459 2.42133883]
# max_eps = [1.15603313 2.47818837 0.16184995 0.59979763 0.10973892 2.42607726]
# Biggest difference: 0.00968042333723007
# Smallest difference: 0.0004286676694086472
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.50323495 1.23667408 0.08076692 0.13145198 0.05476229 1.21066941]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 2.473348162626376
# Smallest difference: 0.10952458935988975
# Fixed eps is not success
#
# min_eps = [0.50323495 1.23667408 0.08076692 0.13145198 0.05476229 1.21066941]
# cur_eps = [0.75485243 1.85501112 0.12115038 0.19717796 0.08214344 1.81600412]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 1.236674081313188
# Smallest difference: 0.054762294679944874
# Fixed eps is not success
#
# min_eps = [0.75485243 1.85501112 0.12115038 0.19717796 0.08214344 1.81600412]
# cur_eps = [0.88066117 2.16417964 0.14134211 0.23004096 0.09583402 2.11867148]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 0.618337040656594
# Smallest difference: 0.027381147339972434
# Fixed eps is not success
#
# min_eps = [0.88066117 2.16417964 0.14134211 0.23004096 0.09583402 2.11867148]
# cur_eps = [0.94356553 2.3187639  0.15143797 0.24647245 0.1026793  2.27000515]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 0.309168520328297
# Smallest difference: 0.013690573669986217
# Fixed eps is not success
#
# min_eps = [0.94356553 2.3187639  0.15143797 0.24647245 0.1026793  2.27000515]
# cur_eps = [0.97501772 2.39605603 0.1564859  0.2546882  0.10610195 2.34567199]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 0.15458426016414872
# Smallest difference: 0.006845286834993108
# Fixed eps is not success
#
# min_eps = [0.97501772 2.39605603 0.1564859  0.2546882  0.10610195 2.34567199]
# cur_eps = [0.99074381 2.4347021  0.15900987 0.25879608 0.10781327 2.38350541]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 0.07729213008207436
# Smallest difference: 0.003422643417496554
# Fixed eps is not success
#
# min_eps = [0.99074381 2.4347021  0.15900987 0.25879608 0.10781327 2.38350541]
# cur_eps = [0.99860686 2.45402513 0.16027185 0.26085001 0.10866893 2.40242212]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 0.0386460650410374
# Smallest difference: 0.001711321708748284
# Fixed eps is not success
#
# min_eps = [0.99860686 2.45402513 0.16027185 0.26085001 0.10866893 2.40242212]
# cur_eps = [1.00253838 2.46368665 0.16090284 0.26187698 0.10909676 2.41188047]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 0.0193230325205187
# Smallest difference: 0.000855660854374149
# Fixed eps is not success
#
# min_eps = [1.00253838 2.46368665 0.16090284 0.26187698 0.10909676 2.41188047]
# cur_eps = [1.00450414 2.4685174  0.16121834 0.26239047 0.10931067 2.41660965]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 0.00966151626025935
# Smallest difference: 0.00042783042718706754
# Fixed eps is not success
#
# min_eps = [1.00450414 2.4685174  0.16121834 0.26239047 0.10931067 2.41660965]
# cur_eps = [1.00548702 2.47093278 0.16137609 0.26264721 0.10941763 2.41897424]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 0.004830758130129453
# Smallest difference: 0.00021391521359352683
# Fixed eps is not success
#
# min_eps = [1.00548702 2.47093278 0.16137609 0.26264721 0.10941763 2.41897424]
# cur_eps = [1.00597846 2.47214047 0.16145496 0.26277558 0.10947111 2.42015654]
# max_eps = [1.0064699  2.47334816 0.16153383 0.26290395 0.10952459 2.42133883]
# Biggest difference: 0.0024153790650647267
# Smallest difference: 0.00010695760679675648
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.36022963 1.23607024 0.08072633 0.06193598 0.05473336 1.21007827]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 2.472140470230654
# Smallest difference: 0.10946672944021793
# Fixed eps is not success
#
# min_eps = [0.36022963 1.23607024 0.08072633 0.06193598 0.05473336 1.21007827]
# cur_eps = [0.54034445 1.85410535 0.1210895  0.09290396 0.08210005 1.8151174 ]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 1.236070235115327
# Smallest difference: 0.054733364720108965
# Fixed eps is not success
#
# min_eps = [0.54034445 1.85410535 0.1210895  0.09290396 0.08210005 1.8151174 ]
# cur_eps = [0.63040186 2.16312291 0.14127108 0.10838796 0.09578339 2.11763697]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 0.6180351175576635
# Smallest difference: 0.02736668236005449
# Fixed eps is not success
#
# min_eps = [0.63040186 2.16312291 0.14127108 0.10838796 0.09578339 2.11763697]
# cur_eps = [0.67543056 2.31763169 0.15136187 0.11612995 0.10262506 2.26889675]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 0.30901755877883197
# Smallest difference: 0.013683341180027245
# Fixed eps is not success
#
# min_eps = [0.67543056 2.31763169 0.15136187 0.11612995 0.10262506 2.26889675]
# cur_eps = [0.69794491 2.39488608 0.15640727 0.12000095 0.10604589 2.34452664]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 0.15450877938941598
# Smallest difference: 0.0068416705900136154
# Fixed eps is not success
#
# min_eps = [0.69794491 2.39488608 0.15640727 0.12000095 0.10604589 2.34452664]
# cur_eps = [0.70920209 2.43351328 0.15892997 0.12193645 0.10775631 2.38234159]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 0.07725438969470799
# Smallest difference: 0.0034208352950068077
# Fixed eps is not success
#
# min_eps = [0.70920209 2.43351328 0.15892997 0.12193645 0.10775631 2.38234159]
# cur_eps = [0.71483068 2.45282687 0.16019132 0.1229042  0.10861152 2.40124906]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 0.03862719484735422
# Smallest difference: 0.0017104176475034039
# Fixed eps is not success
#
# min_eps = [0.71483068 2.45282687 0.16019132 0.1229042  0.10861152 2.40124906]
# cur_eps = [0.71764497 2.46248367 0.16082199 0.12338808 0.10903913 2.4107028 ]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 0.01931359742367711
# Smallest difference: 0.0008552088237517019
# Fixed eps is not success
#
# min_eps = [0.71764497 2.46248367 0.16082199 0.12338808 0.10903913 2.4107028 ]
# cur_eps = [0.71905212 2.46731207 0.16113733 0.12363001 0.10925293 2.41542966]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 0.009656798711838555
# Smallest difference: 0.00042760441187585096
# Fixed eps is not success
#
# min_eps = [0.71905212 2.46731207 0.16113733 0.12363001 0.10925293 2.41542966]
# cur_eps = [0.71975569 2.46972627 0.161295   0.12375098 0.10935983 2.4177931 ]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 0.004828399355919277
# Smallest difference: 0.00021380220593791854
# Fixed eps is not success
#
# min_eps = [0.71975569 2.46972627 0.161295   0.12375098 0.10935983 2.4177931 ]
# cur_eps = [0.72010748 2.47093337 0.16137383 0.12381147 0.10941328 2.41897482]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 0.0024141996779594166
# Smallest difference: 0.00010690110296895927
# Fixed eps is not success
#
# min_eps = [0.72010748 2.47093337 0.16137383 0.12381147 0.10941328 2.41897482]
# cur_eps = [0.72028337 2.47153692 0.16141325 0.12384171 0.10944    2.41956567]
# max_eps = [0.72045927 2.47214047 0.16145267 0.12387195 0.10946673 2.42015653]
# Biggest difference: 0.0012070998389797083
# Smallest difference: 5.3450551484479636e-05
# Fixed eps is success
#
# min_eps = [0.72010748 2.47093337 0.16137383 0.12381147 0.10941328 2.41897482]
# cur_eps = [0.72019543 2.47123515 0.16139354 0.12382659 0.10942664 2.41927024]
# max_eps = [0.72028337 2.47153692 0.16141325 0.12384171 0.10944    2.41956567]
# Biggest difference: 0.0006035499194898541
# Smallest difference: 2.6725275742239818e-05
# Fixed eps is not success
#
# min_eps = [0.72019543 2.47123515 0.16139354 0.12382659 0.10942664 2.41927024]
# cur_eps = [0.7202394  2.47138603 0.16140339 0.12383415 0.10943332 2.41941796]
# max_eps = [0.72028337 2.47153692 0.16141325 0.12384171 0.10944    2.41956567]
# Biggest difference: 0.0003017749597451491
# Smallest difference: 1.3362637871119909e-05
# Fixed eps is not success
#
# Completed Region 1/6 in 57.665804624557495s
#
# Starting Region 2/6
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [1.13917665 1.64472927 0.73835444 0.59287416 0.08732154 0.99369636]
# max_eps = [2.2783533  3.28945853 1.47670889 1.18574832 0.17464308 1.98739273]
# Biggest difference: 3.2894585322173886
# Smallest difference: 0.174643082907584
# Fixed eps is not success
#
# min_eps = [1.13917665 1.64472927 0.73835444 0.59287416 0.08732154 0.99369636]
# cur_eps = [1.70876497 2.4670939  1.10753166 0.88931124 0.13098231 1.49054455]
# max_eps = [2.2783533  3.28945853 1.47670889 1.18574832 0.17464308 1.98739273]
# Biggest difference: 1.6447292661086943
# Smallest difference: 0.087321541453792
# Fixed eps is not success
#
# min_eps = [1.70876497 2.4670939  1.10753166 0.88931124 0.13098231 1.49054455]
# cur_eps = [1.99355914 2.87827622 1.29212028 1.03752978 0.1528127  1.73896864]
# max_eps = [2.2783533  3.28945853 1.47670889 1.18574832 0.17464308 1.98739273]
# Biggest difference: 0.822364633054347
# Smallest difference: 0.043660770726896
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.99677957 1.41093953 0.64606014 0.418794   0.07640635 0.77444957]
# max_eps = [1.99355913 2.82187906 1.29212027 0.83758799 0.1528127  1.54889913]
# Biggest difference: 2.821879063495644
# Smallest difference: 0.15281269854270624
# Fixed eps is not success
#
# min_eps = [0.99677957 1.41093953 0.64606014 0.418794   0.07640635 0.77444957]
# cur_eps = [1.49516935 2.1164093  0.9690902  0.62819099 0.11460952 1.16167435]
# max_eps = [1.99355913 2.82187906 1.29212027 0.83758799 0.1528127  1.54889913]
# Biggest difference: 1.410939531747822
# Smallest difference: 0.07640634927135312
# Fixed eps is not success
#
# min_eps = [1.49516935 2.1164093  0.9690902  0.62819099 0.11460952 1.16167435]
# cur_eps = [1.74436424 2.46914418 1.13060524 0.73288949 0.13371111 1.35528674]
# max_eps = [1.99355913 2.82187906 1.29212027 0.83758799 0.1528127  1.54889913]
# Biggest difference: 0.7054697658739109
# Smallest difference: 0.03820317463567656
# Fixed eps is not success
#
# min_eps = [1.74436424 2.46914418 1.13060524 0.73288949 0.13371111 1.35528674]
# cur_eps = [1.86896169 2.64551162 1.21136275 0.78523874 0.1432619  1.45209294]
# max_eps = [1.99355913 2.82187906 1.29212027 0.83758799 0.1528127  1.54889913]
# Biggest difference: 0.35273488293695543
# Smallest difference: 0.019101587317838287
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.93448084 1.28740559 0.60568138 0.31621961 0.07163095 0.59687776]
# max_eps = [1.86896169 2.57481119 1.21136275 0.63243922 0.1432619  1.19375551]
# Biggest difference: 2.57481118686663
# Smallest difference: 0.14326190491649007
# Fixed eps is not success
#
# min_eps = [0.93448084 1.28740559 0.60568138 0.31621961 0.07163095 0.59687776]
# cur_eps = [1.40172126 1.93110839 0.90852207 0.47432941 0.10744643 0.89531664]
# max_eps = [1.86896169 2.57481119 1.21136275 0.63243922 0.1432619  1.19375551]
# Biggest difference: 1.287405593433315
# Smallest difference: 0.07163095245824504
# Fixed eps is not success
#
# min_eps = [1.40172126 1.93110839 0.90852207 0.47432941 0.10744643 0.89531664]
# cur_eps = [1.63534147 2.25295979 1.05994241 0.55338432 0.12535417 1.04453607]
# max_eps = [1.86896169 2.57481119 1.21136275 0.63243922 0.1432619  1.19375551]
# Biggest difference: 0.6437027967166575
# Smallest difference: 0.03581547622912251
# Fixed eps is not success
#
# min_eps = [1.63534147 2.25295979 1.05994241 0.55338432 0.12535417 1.04453607]
# cur_eps = [1.75215158 2.41388549 1.13565258 0.59291177 0.13430804 1.11914579]
# max_eps = [1.86896169 2.57481119 1.21136275 0.63243922 0.1432619  1.19375551]
# Biggest difference: 0.32185139835832866
# Smallest difference: 0.017907738114561256
# Fixed eps is not success
#
# min_eps = [1.75215158 2.41388549 1.13565258 0.59291177 0.13430804 1.11914579]
# cur_eps = [1.81055663 2.49434834 1.17350767 0.61267549 0.13878497 1.15645065]
# max_eps = [1.86896169 2.57481119 1.21136275 0.63243922 0.1432619  1.19375551]
# Biggest difference: 0.1609256991791641
# Smallest difference: 0.008953869057280628
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.90527832 1.20853377 0.51371574 0.30633775 0.06939249 0.46202434]
# max_eps = [1.81055663 2.41706754 1.02743148 0.61267549 0.13878497 0.92404867]
# Biggest difference: 2.4170675425086614
# Smallest difference: 0.13878497036086979
# Fixed eps is not success
#
# min_eps = [0.90527832 1.20853377 0.51371574 0.30633775 0.06939249 0.46202434]
# cur_eps = [1.35791747 1.81280066 0.77057361 0.45950662 0.10408873 0.69303651]
# max_eps = [1.81055663 2.41706754 1.02743148 0.61267549 0.13878497 0.92404867]
# Biggest difference: 1.2085337712543307
# Smallest difference: 0.06939248518043489
# Fixed eps is not success
#
# min_eps = [1.35791747 1.81280066 0.77057361 0.45950662 0.10408873 0.69303651]
# cur_eps = [1.58423705 2.1149341  0.89900255 0.53609106 0.12143685 0.80854259]
# max_eps = [1.81055663 2.41706754 1.02743148 0.61267549 0.13878497 0.92404867]
# Biggest difference: 0.6042668856271654
# Smallest difference: 0.034696242590217446
# Fixed eps is not success
#
# min_eps = [1.58423705 2.1149341  0.89900255 0.53609106 0.12143685 0.80854259]
# cur_eps = [1.69739684 2.26600082 0.96321701 0.57438327 0.13011091 0.86629563]
# max_eps = [1.81055663 2.41706754 1.02743148 0.61267549 0.13878497 0.92404867]
# Biggest difference: 0.3021334428135827
# Smallest difference: 0.017348121295108723
# Fixed eps is not success
#
# min_eps = [1.69739684 2.26600082 0.96321701 0.57438327 0.13011091 0.86629563]
# cur_eps = [1.75397674 2.34153418 0.99532425 0.59352938 0.13444794 0.89517215]
# max_eps = [1.81055663 2.41706754 1.02743148 0.61267549 0.13878497 0.92404867]
# Biggest difference: 0.15106672140679134
# Smallest difference: 0.008674060647554355
# Fixed eps is not success
#
# min_eps = [1.75397674 2.34153418 0.99532425 0.59352938 0.13444794 0.89517215]
# cur_eps = [1.78226669 2.37930086 1.01137787 0.60310244 0.13661646 0.90961041]
# max_eps = [1.81055663 2.41706754 1.02743148 0.61267549 0.13878497 0.92404867]
# Biggest difference: 0.07553336070339567
# Smallest difference: 0.004337030323777191
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.89113334 1.14396578 0.45166824 0.30155122 0.06830822 0.39222314]
# max_eps = [1.78226668 2.28793156 0.90333648 0.60310243 0.13661645 0.78444629]
# Biggest difference: 2.287931560998904
# Smallest difference: 0.136616448573605
# Fixed eps is not success
#
# min_eps = [0.89113334 1.14396578 0.45166824 0.30155122 0.06830822 0.39222314]
# cur_eps = [1.33670001 1.71594867 0.67750236 0.45232682 0.10246234 0.58833471]
# max_eps = [1.78226668 2.28793156 0.90333648 0.60310243 0.13661645 0.78444629]
# Biggest difference: 1.143965780499452
# Smallest difference: 0.0683082242868025
# Fixed eps is not success
#
# min_eps = [1.33670001 1.71594867 0.67750236 0.45232682 0.10246234 0.58833471]
# cur_eps = [1.55948335 2.00194012 0.79041942 0.52771463 0.11953939 0.6863905 ]
# max_eps = [1.78226668 2.28793156 0.90333648 0.60310243 0.13661645 0.78444629]
# Biggest difference: 0.5719828902497262
# Smallest difference: 0.03415411214340125
# Fixed eps is not success
#
# min_eps = [1.55948335 2.00194012 0.79041942 0.52771463 0.11953939 0.6863905 ]
# cur_eps = [1.67087502 2.14493584 0.84687795 0.56540853 0.12807792 0.73541839]
# max_eps = [1.78226668 2.28793156 0.90333648 0.60310243 0.13661645 0.78444629]
# Biggest difference: 0.28599144512486285
# Smallest difference: 0.017077056071700625
# Fixed eps is not success
#
# min_eps = [1.67087502 2.14493584 0.84687795 0.56540853 0.12807792 0.73541839]
# cur_eps = [1.72657085 2.2164337  0.87510722 0.58425548 0.13234718 0.75993234]
# max_eps = [1.78226668 2.28793156 0.90333648 0.60310243 0.13661645 0.78444629]
# Biggest difference: 0.14299572256243165
# Smallest difference: 0.008538528035850312
# Fixed eps is not success
#
# min_eps = [1.72657085 2.2164337  0.87510722 0.58425548 0.13234718 0.75993234]
# cur_eps = [1.75441877 2.25218263 0.88922185 0.59367896 0.13448182 0.77218931]
# max_eps = [1.78226668 2.28793156 0.90333648 0.60310243 0.13661645 0.78444629]
# Biggest difference: 0.0714978612812156
# Smallest difference: 0.004269264017925156
# Fixed eps is not success
#
# min_eps = [1.75441877 2.25218263 0.88922185 0.59367896 0.13448182 0.77218931]
# cur_eps = [1.76834272 2.2700571  0.89627917 0.59839069 0.13554913 0.7783178 ]
# max_eps = [1.78226668 2.28793156 0.90333648 0.60310243 0.13661645 0.78444629]
# Biggest difference: 0.03574893064060758
# Smallest difference: 0.002134632008962578
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.88417136 1.12024178 0.38365792 0.29919534 0.06777456 0.30734388]
# max_eps = [1.76834272 2.24048357 0.76731584 0.59839069 0.13554912 0.61468776]
# Biggest difference: 2.240483566324122
# Smallest difference: 0.13554911577921144
# Fixed eps is not success
#
# min_eps = [0.88417136 1.12024178 0.38365792 0.29919534 0.06777456 0.30734388]
# cur_eps = [1.32625704 1.68036267 0.57548688 0.44879302 0.10166184 0.46101582]
# max_eps = [1.76834272 2.24048357 0.76731584 0.59839069 0.13554912 0.61468776]
# Biggest difference: 1.120241783162061
# Smallest difference: 0.06777455788960572
# Fixed eps is not success
#
# min_eps = [1.32625704 1.68036267 0.57548688 0.44879302 0.10166184 0.46101582]
# cur_eps = [1.54729988 1.96042312 0.67140136 0.52359185 0.11860548 0.53785179]
# max_eps = [1.76834272 2.24048357 0.76731584 0.59839069 0.13554912 0.61468776]
# Biggest difference: 0.5601208915810305
# Smallest difference: 0.03388727894480287
# Fixed eps is not success
#
# min_eps = [1.54729988 1.96042312 0.67140136 0.52359185 0.11860548 0.53785179]
# cur_eps = [1.6578213  2.10045334 0.7193586  0.56099127 0.1270773  0.57626978]
# max_eps = [1.76834272 2.24048357 0.76731584 0.59839069 0.13554912 0.61468776]
# Biggest difference: 0.28006044579051537
# Smallest difference: 0.016943639472401434
# Fixed eps is not success
#
# min_eps = [1.6578213  2.10045334 0.7193586  0.56099127 0.1270773  0.57626978]
# cur_eps = [1.71308201 2.17046845 0.74333722 0.57969098 0.13131321 0.59547877]
# max_eps = [1.76834272 2.24048357 0.76731584 0.59839069 0.13554912 0.61468776]
# Biggest difference: 0.14003022289525768
# Smallest difference: 0.00847181973620073
# Fixed eps is not success
#
# min_eps = [1.71308201 2.17046845 0.74333722 0.57969098 0.13131321 0.59547877]
# cur_eps = [1.74071237 2.20547601 0.75532653 0.58904083 0.13343116 0.60508327]
# max_eps = [1.76834272 2.24048357 0.76731584 0.59839069 0.13554912 0.61468776]
# Biggest difference: 0.07001511144762862
# Smallest difference: 0.004235909868100379
# Fixed eps is not success
#
# min_eps = [1.74071237 2.20547601 0.75532653 0.58904083 0.13343116 0.60508327]
# cur_eps = [1.75452754 2.22297979 0.76132118 0.59371576 0.13449014 0.60988551]
# max_eps = [1.76834272 2.24048357 0.76731584 0.59839069 0.13554912 0.61468776]
# Biggest difference: 0.03500755572381431
# Smallest difference: 0.0021179549340501758
# Fixed eps is not success
#
# min_eps = [1.75452754 2.22297979 0.76132118 0.59371576 0.13449014 0.60988551]
# cur_eps = [1.76143513 2.23173168 0.76431851 0.59605322 0.13501963 0.61228664]
# max_eps = [1.76834272 2.24048357 0.76731584 0.59839069 0.13554912 0.61468776]
# Biggest difference: 0.017503777861906933
# Smallest difference: 0.001058977467025074
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.88071757 1.11213682 0.29017409 0.29802661 0.06750981 0.20254536]
# max_eps = [1.76143513 2.22427365 0.58034819 0.59605322 0.13501962 0.40509073]
# Biggest difference: 2.2242736477493406
# Smallest difference: 0.13501962048757432
# Fixed eps is not success
#
# min_eps = [0.88071757 1.11213682 0.29017409 0.29802661 0.06750981 0.20254536]
# cur_eps = [1.32107635 1.66820524 0.43526114 0.44703992 0.10126472 0.30381805]
# max_eps = [1.76143513 2.22427365 0.58034819 0.59605322 0.13501962 0.40509073]
# Biggest difference: 1.1121368238746703
# Smallest difference: 0.06750981024378716
# Fixed eps is not success
#
# min_eps = [1.32107635 1.66820524 0.43526114 0.44703992 0.10126472 0.30381805]
# cur_eps = [1.54125574 1.94623944 0.50780466 0.52154657 0.11814217 0.35445439]
# max_eps = [1.76143513 2.22427365 0.58034819 0.59605322 0.13501962 0.40509073]
# Biggest difference: 0.5560684119373351
# Smallest difference: 0.03375490512189358
# Fixed eps is not success
#
# min_eps = [1.54125574 1.94623944 0.50780466 0.52154657 0.11814217 0.35445439]
# cur_eps = [1.65134544 2.08525654 0.54407642 0.55879989 0.12658089 0.37977256]
# max_eps = [1.76143513 2.22427365 0.58034819 0.59605322 0.13501962 0.40509073]
# Biggest difference: 0.27803420596866757
# Smallest difference: 0.01687745256094679
# Fixed eps is not success
#
# min_eps = [1.65134544 2.08525654 0.54407642 0.55879989 0.12658089 0.37977256]
# cur_eps = [1.70639028 2.1547651  0.5622123  0.57742656 0.13080026 0.39243164]
# max_eps = [1.76143513 2.22427365 0.58034819 0.59605322 0.13501962 0.40509073]
# Biggest difference: 0.1390171029843339
# Smallest difference: 0.008438726280473402
# Fixed eps is not success
#
# min_eps = [1.70639028 2.1547651  0.5622123  0.57742656 0.13080026 0.39243164]
# cur_eps = [1.73391271 2.18951937 0.57128025 0.58673989 0.13290994 0.39876119]
# max_eps = [1.76143513 2.22427365 0.58034819 0.59605322 0.13501962 0.40509073]
# Biggest difference: 0.06950855149216695
# Smallest difference: 0.004219363140236687
# Fixed eps is not success
#
# min_eps = [1.73391271 2.18951937 0.57128025 0.58673989 0.13290994 0.39876119]
# cur_eps = [1.74767392 2.20689651 0.57581422 0.59139656 0.13396478 0.40192596]
# max_eps = [1.76143513 2.22427365 0.58034819 0.59605322 0.13501962 0.40509073]
# Biggest difference: 0.03475427574608325
# Smallest difference: 0.0021096815701183436
# Fixed eps is not success
#
# min_eps = [1.74767392 2.20689651 0.57581422 0.59139656 0.13396478 0.40192596]
# cur_eps = [1.75455453 2.21558508 0.5780812  0.59372489 0.1344922  0.40350834]
# max_eps = [1.76143513 2.22427365 0.58034819 0.59605322 0.13501962 0.40509073]
# Biggest difference: 0.017377137873041626
# Smallest difference: 0.0010548407850591857
# Fixed eps is not success
#
# min_eps = [1.75455453 2.21558508 0.5780812  0.59372489 0.1344922  0.40350834]
# cur_eps = [1.75799483 2.21992936 0.57921469 0.59488905 0.13475591 0.40429954]
# max_eps = [1.76143513 2.22427365 0.58034819 0.59605322 0.13501962 0.40509073]
# Biggest difference: 0.008688568936520813
# Smallest difference: 0.0005274203925295928
# Fixed eps is not success
#
# min_eps = [1.75799483 2.21992936 0.57921469 0.59488905 0.13475591 0.40429954]
# cur_eps = [1.75971498 2.22210151 0.57978144 0.59547114 0.13488777 0.40469513]
# max_eps = [1.76143513 2.22427365 0.58034819 0.59605322 0.13501962 0.40509073]
# Biggest difference: 0.0043442844682601844
# Smallest difference: 0.0002637101962648103
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.87985749 1.101841   0.17327303 0.29773556 0.06744385 0.09251019]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 2.2036819992052274
# Smallest difference: 0.13488770255356822
# Fixed eps is not success
#
# min_eps = [0.87985749 1.101841   0.17327303 0.29773556 0.06744385 0.09251019]
# cur_eps = [1.31978623 1.6527615  0.25990954 0.44660334 0.10116578 0.13876528]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 1.1018409996026137
# Smallest difference: 0.06744385127678411
# Fixed eps is not success
#
# min_eps = [1.31978623 1.6527615  0.25990954 0.44660334 0.10116578 0.13876528]
# cur_eps = [1.53975061 1.92822175 0.3032278  0.52103723 0.11802674 0.16189282]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 0.5509204998013069
# Smallest difference: 0.03372192563839205
# Fixed eps is not success
#
# min_eps = [1.53975061 1.92822175 0.3032278  0.52103723 0.11802674 0.16189282]
# cur_eps = [1.64973279 2.06595187 0.32488692 0.55825417 0.12645722 0.1734566 ]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 0.2754602499006533
# Smallest difference: 0.016860962819196024
# Fixed eps is not success
#
# min_eps = [1.64973279 2.06595187 0.32488692 0.55825417 0.12645722 0.1734566 ]
# cur_eps = [1.70472389 2.13481694 0.33571649 0.57686265 0.13067246 0.17923848]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 0.13773012495032688
# Smallest difference: 0.008430481409598012
# Fixed eps is not success
#
# min_eps = [1.70472389 2.13481694 0.33571649 0.57686265 0.13067246 0.17923848]
# cur_eps = [1.73221943 2.16924947 0.34113127 0.58616688 0.13278008 0.18212943]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 0.06886506247516344
# Smallest difference: 0.004215240704799006
# Fixed eps is not success
#
# min_eps = [1.73221943 2.16924947 0.34113127 0.58616688 0.13278008 0.18212943]
# cur_eps = [1.74596721 2.18646573 0.34383866 0.590819   0.13383389 0.1835749 ]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 0.03443253123758172
# Smallest difference: 0.002107620352399503
# Fixed eps is not success
#
# min_eps = [1.74596721 2.18646573 0.34383866 0.590819   0.13383389 0.1835749 ]
# cur_eps = [1.75284109 2.19507387 0.34519236 0.59314506 0.1343608  0.18429764]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 0.01721626561879086
# Smallest difference: 0.0010538101761997376
# Fixed eps is not success
#
# min_eps = [1.75284109 2.19507387 0.34519236 0.59314506 0.1343608  0.18429764]
# cur_eps = [1.75627804 2.19937793 0.3458692  0.59430809 0.13462425 0.184659  ]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 0.008608132809395208
# Smallest difference: 0.0005269050880998549
# Fixed eps is not success
#
# min_eps = [1.75627804 2.19937793 0.3458692  0.59430809 0.13462425 0.184659  ]
# cur_eps = [1.75799651 2.20152997 0.34620763 0.5948896  0.13475598 0.18483969]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 0.004304066404697604
# Smallest difference: 0.00026345254404994134
# Fixed eps is not success
#
# min_eps = [1.75799651 2.20152997 0.34620763 0.5948896  0.13475598 0.18483969]
# cur_eps = [1.75885574 2.20260598 0.34637684 0.59518036 0.13482184 0.18493003]
# max_eps = [1.75971498 2.203682   0.34654605 0.59547112 0.1348877  0.18502037]
# Biggest difference: 0.002152033202349024
# Smallest difference: 0.00013172627202498455
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.87942787 1.08070306 0.09963142 0.29290169 0.06740955 0.05075608]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 2.161406124689012
# Smallest difference: 0.10151215141680787
# Fixed eps is not success
#
# min_eps = [0.87942787 1.08070306 0.09963142 0.29290169 0.06740955 0.05075608]
# cur_eps = [1.31914181 1.62105459 0.14944714 0.43935253 0.10111432 0.07613411]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 1.080703062344506
# Smallest difference: 0.05075607570840394
# Fixed eps is not success
#
# min_eps = [1.31914181 1.62105459 0.14944714 0.43935253 0.10111432 0.07613411]
# cur_eps = [1.53899877 1.89123036 0.17435499 0.51257796 0.11796671 0.08882313]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.5403515311722531
# Smallest difference: 0.025378037854201965
# Fixed eps is not success
#
# min_eps = [1.53899877 1.89123036 0.17435499 0.51257796 0.11796671 0.08882313]
# cur_eps = [1.64892726 2.02631824 0.18680892 0.54919067 0.1263929  0.09516764]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.27017576558612655
# Smallest difference: 0.01268901892710099
# Fixed eps is not success
#
# min_eps = [1.64892726 2.02631824 0.18680892 0.54919067 0.1263929  0.09516764]
# cur_eps = [1.7038915  2.09386218 0.19303589 0.56749702 0.130606   0.0983399 ]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.1350878827930635
# Smallest difference: 0.006344509463550488
# Fixed eps is not success
#
# min_eps = [1.7038915  2.09386218 0.19303589 0.56749702 0.130606   0.0983399 ]
# cur_eps = [1.73137362 2.12763415 0.19614937 0.5766502  0.13271254 0.09992602]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.06754394139653153
# Smallest difference: 0.003172254731775251
# Fixed eps is not success
#
# min_eps = [1.73137362 2.12763415 0.19614937 0.5766502  0.13271254 0.09992602]
# cur_eps = [1.74511468 2.14452014 0.19770611 0.58122679 0.13376582 0.10071909]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.033771970698265985
# Smallest difference: 0.0015861273658876324
# Fixed eps is not success
#
# min_eps = [1.74511468 2.14452014 0.19770611 0.58122679 0.13376582 0.10071909]
# cur_eps = [1.75198521 2.15296313 0.19848448 0.58351508 0.13429246 0.10111562]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.01688598534913277
# Smallest difference: 0.0007930636829438092
# Fixed eps is not success
#
# min_eps = [1.75198521 2.15296313 0.19848448 0.58351508 0.13429246 0.10111562]
# cur_eps = [1.75542048 2.15718463 0.19887366 0.58465923 0.13455577 0.10131389]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.008442992674566607
# Smallest difference: 0.00039653184147191156
# Fixed eps is not success
#
# min_eps = [1.75542048 2.15718463 0.19887366 0.58465923 0.13455577 0.10131389]
# cur_eps = [1.75713811 2.15929538 0.19906826 0.5852313  0.13468743 0.10141302]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.004221496337283082
# Smallest difference: 0.00019826592073594884
# Fixed eps is not success
#
# min_eps = [1.75713811 2.15929538 0.19906826 0.5852313  0.13468743 0.10141302]
# cur_eps = [1.75799693 2.16035075 0.19916555 0.58551734 0.13475326 0.10146258]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.0021107481686413188
# Smallest difference: 9.913296036796748e-05
# Fixed eps is not success
#
# min_eps = [1.75799693 2.16035075 0.19916555 0.58551734 0.13475326 0.10146258]
# cur_eps = [1.75842633 2.16087844 0.1992142  0.58566036 0.13478618 0.10148737]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.0010553740843204373
# Smallest difference: 4.956648018399068e-05
# Fixed eps is not success
#
# min_eps = [1.75842633 2.16087844 0.1992142  0.58566036 0.13478618 0.10148737]
# cur_eps = [1.75864104 2.16114228 0.19923853 0.58573187 0.13480264 0.10149976]
# max_eps = [1.75885574 2.16140612 0.19926285 0.58580338 0.13481909 0.10151215]
# Biggest difference: 0.0005276870421604407
# Smallest difference: 2.47832400919884e-05
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.87932052 1.06021641 0.05973054 0.27212925 0.06084159 0.05073084]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 2.1204328251752838
# Smallest difference: 0.1014616890336526
# Fixed eps is not success
#
# min_eps = [0.87932052 1.06021641 0.05973054 0.27212925 0.06084159 0.05073084]
# cur_eps = [1.31898078 1.59032462 0.08959581 0.40819387 0.09126238 0.07609627]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 1.0602164125876419
# Smallest difference: 0.0507308445168263
# Fixed eps is not success
#
# min_eps = [1.31898078 1.59032462 0.08959581 0.40819387 0.09126238 0.07609627]
# cur_eps = [1.53881091 1.85537872 0.10452844 0.47622618 0.10647278 0.08877898]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.5301082062938209
# Smallest difference: 0.02536542225841315
# Fixed eps is not success
#
# min_eps = [1.53881091 1.85537872 0.10452844 0.47622618 0.10647278 0.08877898]
# cur_eps = [1.64872597 1.98790577 0.11199476 0.51024234 0.11407798 0.09512033]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.26505410314691047
# Smallest difference: 0.012682711129206575
# Fixed eps is not success
#
# min_eps = [1.64872597 1.98790577 0.11199476 0.51024234 0.11407798 0.09512033]
# cur_eps = [1.7036835  2.0541693  0.11572792 0.52725042 0.11788057 0.09829101]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.13252705157345535
# Smallest difference: 0.006341355564603288
# Fixed eps is not success
#
# min_eps = [1.7036835  2.0541693  0.11572792 0.52725042 0.11788057 0.09829101]
# cur_eps = [1.73116227 2.08730106 0.1175945  0.53575446 0.11978187 0.09987635]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.06626352578672767
# Smallest difference: 0.0031706777823016508
# Fixed eps is not success
#
# min_eps = [1.73116227 2.08730106 0.1175945  0.53575446 0.11978187 0.09987635]
# cur_eps = [1.74490165 2.10386694 0.11852779 0.54000648 0.12073252 0.10066902]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.033131762893363614
# Smallest difference: 0.0015853388911508254
# Fixed eps is not success
#
# min_eps = [1.74490165 2.10386694 0.11852779 0.54000648 0.12073252 0.10066902]
# cur_eps = [1.75177135 2.11214988 0.11899443 0.54213249 0.12120785 0.10106535]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.016565881446681807
# Smallest difference: 0.0007926694455754058
# Fixed eps is not success
#
# min_eps = [1.75177135 2.11214988 0.11899443 0.54213249 0.12120785 0.10106535]
# cur_eps = [1.75520619 2.11629135 0.11922776 0.54319549 0.12144551 0.10126352]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.008282940723340904
# Smallest difference: 0.0003963347227877029
# Fixed eps is not success
#
# min_eps = [1.75520619 2.11629135 0.11922776 0.54319549 0.12144551 0.10126352]
# cur_eps = [1.75692361 2.11836209 0.11934442 0.54372699 0.12156434 0.10136261]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.00414147036167023
# Smallest difference: 0.00019816736139385838
# Fixed eps is not success
#
# min_eps = [1.75692361 2.11836209 0.11934442 0.54372699 0.12156434 0.10136261]
# cur_eps = [1.75778233 2.11939746 0.11940275 0.54399275 0.12162376 0.10141215]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.002070735180835115
# Smallest difference: 9.908368069692919e-05
# Fixed eps is not success
#
# min_eps = [1.75778233 2.11939746 0.11940275 0.54399275 0.12162376 0.10141215]
# cur_eps = [1.75821168 2.11991514 0.11943191 0.54412562 0.12165347 0.10143692]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.0010353675904175574
# Smallest difference: 4.954184034847153e-05
# Fixed eps is not success
#
# min_eps = [1.75821168 2.11991514 0.11943191 0.54412562 0.12165347 0.10143692]
# cur_eps = [1.75842636 2.12017398 0.1194465  0.54419206 0.12166832 0.1014493 ]
# max_eps = [1.75864104 2.12043283 0.11946108 0.5442585  0.12168317 0.10146169]
# Biggest difference: 0.0005176837952087787
# Smallest difference: 2.4770920174235767e-05
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.87921318 1.04050937 0.02481897 0.26168188 0.04582369 0.05072289]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 2.081018749667125
# Smallest difference: 0.04963793414594312
# Fixed eps is not success
#
# min_eps = [0.87921318 1.04050937 0.02481897 0.26168188 0.04582369 0.05072289]
# cur_eps = [1.31881977 1.56076406 0.03722845 0.39252282 0.06873553 0.07608434]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 1.0405093748335625
# Smallest difference: 0.02481896707297156
# Fixed eps is not success
#
# min_eps = [1.31881977 1.56076406 0.03722845 0.39252282 0.06873553 0.07608434]
# cur_eps = [1.53862306 1.82089141 0.04343319 0.4579433  0.08019145 0.08876506]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.5202546874167813
# Smallest difference: 0.012409483536485778
# Fixed eps is not success
#
# min_eps = [1.53862306 1.82089141 0.04343319 0.4579433  0.08019145 0.08876506]
# cur_eps = [1.64852471 1.95095508 0.04653556 0.49065353 0.08591942 0.09510543]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.26012734370839063
# Smallest difference: 0.006204741768242893
# Fixed eps is not success
#
# min_eps = [1.64852471 1.95095508 0.04653556 0.49065353 0.08591942 0.09510543]
# cur_eps = [1.70347554 2.01598691 0.04808675 0.50700865 0.0887834  0.09827561]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.1300636718541952
# Smallest difference: 0.003102370884121443
# Fixed eps is not success
#
# min_eps = [1.70347554 2.01598691 0.04808675 0.50700865 0.0887834  0.09827561]
# cur_eps = [1.73095095 2.04850283 0.04886234 0.51518621 0.09021539 0.0998607 ]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.0650318359270976
# Smallest difference: 0.001551185442060725
# Fixed eps is not success
#
# min_eps = [1.73095095 2.04850283 0.04886234 0.51518621 0.09021539 0.0998607 ]
# cur_eps = [1.74468865 2.06476079 0.04925014 0.51927499 0.09093138 0.10065324]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.0325159179635488
# Smallest difference: 0.000775592721030359
# Fixed eps is not success
#
# min_eps = [1.74468865 2.06476079 0.04925014 0.51927499 0.09093138 0.10065324]
# cur_eps = [1.75155751 2.07288977 0.04944404 0.52131938 0.09128938 0.10104951]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.0162579589817744
# Smallest difference: 0.000387796360515176
# Fixed eps is not success
#
# min_eps = [1.75155751 2.07288977 0.04944404 0.52131938 0.09128938 0.10104951]
# cur_eps = [1.75499193 2.07695426 0.04954099 0.52234157 0.09146838 0.10124765]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.0081289794908872
# Smallest difference: 0.00019389818025759148
# Fixed eps is not success
#
# min_eps = [1.75499193 2.07695426 0.04954099 0.52234157 0.09146838 0.10124765]
# cur_eps = [1.75670915 2.0789865  0.04958946 0.52285267 0.09155788 0.10134672]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.004064489745443822
# Smallest difference: 9.694909012879921e-05
# Fixed eps is not success
#
# min_eps = [1.75670915 2.0789865  0.04958946 0.52285267 0.09155788 0.10134672]
# cur_eps = [1.75756775 2.08000263 0.0496137  0.52310822 0.09160263 0.10139625]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.002032244872721911
# Smallest difference: 4.8474545064396135e-05
# Fixed eps is not success
#
# min_eps = [1.75756775 2.08000263 0.0496137  0.52310822 0.09160263 0.10139625]
# cur_eps = [1.75799706 2.08051069 0.04962582 0.52323599 0.091625   0.10142102]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.0010161224363609556
# Smallest difference: 2.4237272532194598e-05
# Fixed eps is not success
#
# min_eps = [1.75799706 2.08051069 0.04962582 0.52323599 0.091625   0.10142102]
# cur_eps = [1.75821171 2.08076472 0.04963187 0.52329988 0.09163619 0.1014334 ]
# max_eps = [1.75842636 2.08101875 0.04963793 0.52336377 0.09164738 0.10144579]
# Biggest difference: 0.0005080612181806998
# Smallest difference: 1.211863626609383e-05
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0.]
# cur_eps = [0.87910585 1.02153347 0.01951353 0.25174395 0.03806108 0.05071541]
# max_eps = [1.75821171 2.04306694 0.03902707 0.50348789 0.07612215 0.10143081]
# Biggest difference: 2.043066942988718
# Smallest difference: 0.039027066368633526
# Fixed eps is not success
#
# min_eps = [0.87910585 1.02153347 0.01951353 0.25174395 0.03806108 0.05071541]
# cur_eps = [1.31865878 1.53230021 0.0292703  0.37761592 0.05709161 0.07607311]
# max_eps = [1.75821171 2.04306694 0.03902707 0.50348789 0.07612215 0.10143081]
# Biggest difference: 1.021533471494359
# Smallest difference: 0.019513533184316763
# Fixed eps is not success
#
# min_eps = [1.31865878 1.53230021 0.0292703  0.37761592 0.05709161 0.07607311]
# cur_eps = [1.53843524 1.78768358 0.03414868 0.44055191 0.06660688 0.08875196]
# max_eps = [1.75821171 2.04306694 0.03902707 0.50348789 0.07612215 0.10143081]
# Biggest difference: 0.5107667357471795
# Smallest difference: 0.009756766592158381
# Fixed eps is not success
#
# min_eps = [1.53843524 1.78768358 0.03414868 0.44055191 0.06660688 0.08875196]
# cur_eps = [1.64832348 1.91537526 0.03658787 0.4720199  0.07136452 0.09509139]
# max_eps = [1.75821171 2.04306694 0.03902707 0.50348789 0.07612215 0.10143081]
# Biggest difference: 0.25538336787358973
# Smallest difference: 0.004878383296079189
# Fixed eps is not success
#
# min_eps = [1.64832348 1.91537526 0.03658787 0.4720199  0.07136452 0.09509139]
# cur_eps = [1.70326759 1.9792211  0.03780747 0.4877539  0.07374333 0.0982611 ]
# max_eps = [1.75821171 2.04306694 0.03902707 0.50348789 0.07612215 0.10143081]
# ...
#  1.84993928e-03]
# Biggest difference: 0.04831688580372208
# Smallest difference: 4.566374336268922e-05
# Fixed eps is not success
#
# min_eps = [7.23787155e-05 6.84956150e-05 4.42274474e-04 7.24753287e-02
#  1.93325622e-02 6.42999654e-02 1.99742723e-03 8.37824036e-03
#  1.38745446e-03]
# cur_eps = [8.44418347e-05 7.99115509e-05 5.15986886e-04 8.45545502e-02
#  2.25546559e-02 7.50166263e-02 2.33033177e-03 9.77461376e-03
#  1.61869687e-03]
# max_eps = [9.65049540e-05 9.13274867e-05 5.89699299e-04 9.66337716e-02
#  2.57767496e-02 8.57332872e-02 2.66323631e-03 1.11709872e-02
#  1.84993928e-03]
# Biggest difference: 0.024158442901861032
# Smallest difference: 2.2831871681344603e-05
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# cur_eps = [2.10894625e-05 1.94737367e-05 1.17800896e-04 4.22765737e-02
#  1.12759262e-02 3.75075170e-02 1.16516647e-03 4.88578053e-03
#  4.84011279e-04]
# max_eps = [4.21789250e-05 3.89474735e-05 2.35601792e-04 8.45531474e-02
#  2.25518523e-02 7.50150340e-02 2.33033294e-03 9.77156105e-03
#  9.68022558e-04]
# Biggest difference: 0.08455314740344445
# Smallest difference: 3.894747349812445e-05
# Fixed eps is not success
#
# min_eps = [2.10894625e-05 1.94737367e-05 1.17800896e-04 4.22765737e-02
#  1.12759262e-02 3.75075170e-02 1.16516647e-03 4.88578053e-03
#  4.84011279e-04]
# cur_eps = [3.16341937e-05 2.92106051e-05 1.76701344e-04 6.34148606e-02
#  1.69138892e-02 5.62612755e-02 1.74774970e-03 7.32867079e-03
#  7.26016918e-04]
# max_eps = [4.21789250e-05 3.89474735e-05 2.35601792e-04 8.45531474e-02
#  2.25518523e-02 7.50150340e-02 2.33033294e-03 9.77156105e-03
#  9.68022558e-04]
# Biggest difference: 0.04227657370172223
# Smallest difference: 1.9473736749062225e-05
# Fixed eps is not success
#
# Completed Region 5/6 in 21.45759677886963s
#
# Starting Region 6/6
# min_eps = [0. 0. 0. 0. 0. 0. 0. 0.]
# cur_eps = [0.89104626 1.64472927 0.94159301 0.84100455 0.08732154 0.79045779
#  0.02999239 0.10994173]
# max_eps = [1.78209252 3.28945853 1.88318603 1.6820091  0.17464308 1.58091559
#  0.05998478 0.21988346]
# Biggest difference: 3.2894585322173886
# Smallest difference: 0.05998478354689829
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0. 0. 0.]
# cur_eps = [0.36871559 0.63148704 0.4707965  0.42050226 0.04366077 0.32753933
#  0.0149962  0.05497087]
# max_eps = [0.73743118 1.26297408 0.94159301 0.84100453 0.08732154 0.65507865
#  0.02999239 0.10994173]
# Biggest difference: 1.2629740798162337
# Smallest difference: 0.029992392734754944
# Fixed eps is not success
#
# min_eps = [0.36871559 0.63148704 0.4707965  0.42050226 0.04366077 0.32753933
#  0.0149962  0.05497087]
# cur_eps = [0.55307338 0.94723056 0.70619476 0.63075339 0.06549116 0.49130899
#  0.02249429 0.0824563 ]
# max_eps = [0.73743118 1.26297408 0.94159301 0.84100453 0.08732154 0.65507865
#  0.02999239 0.10994173]
# Biggest difference: 0.6314870399081168
# Smallest difference: 0.014996196367377472
# Fixed eps is not success
#
# min_eps = [0.55307338 0.94723056 0.70619476 0.63075339 0.06549116 0.49130899
#  0.02249429 0.0824563 ]
# cur_eps = [0.64525228 1.10510232 0.82389388 0.73587896 0.07640635 0.57319382
#  0.02624334 0.09619901]
# max_eps = [0.73743118 1.26297408 0.94159301 0.84100453 0.08732154 0.65507865
#  0.02999239 0.10994173]
# Biggest difference: 0.31574351995405836
# Smallest difference: 0.007498098183688736
# Fixed eps is not success
#
# min_eps = [0.64525228 1.10510232 0.82389388 0.73587896 0.07640635 0.57319382
#  0.02624334 0.09619901]
# cur_eps = [0.69134173 1.1840382  0.88274345 0.78844174 0.08186395 0.61413624
#  0.02811787 0.10307037]
# max_eps = [0.73743118 1.26297408 0.94159301 0.84100453 0.08732154 0.65507865
#  0.02999239 0.10994173]
# Biggest difference: 0.15787175997702918
# Smallest difference: 0.0037490490918443697
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0. 0. 0.]
# cur_eps = [0.27284993 0.31906641 0.44137162 0.3821781  0.04093197 0.23345371
#  0.01405893 0.05153519]
# max_eps = [0.54569985 0.63813283 0.88274324 0.76435621 0.08186395 0.46690741
#  0.02811787 0.10307037]
# Biggest difference: 0.8827432378972678
# Smallest difference: 0.028117868217515555
# Fixed eps is not success
#
# min_eps = [0.27284993 0.31906641 0.44137162 0.3821781  0.04093197 0.23345371
#  0.01405893 0.05153519]
# cur_eps = [0.40927489 0.47859962 0.66205743 0.57326716 0.06139796 0.35018056
#  0.0210884  0.07730278]
# max_eps = [0.54569985 0.63813283 0.88274324 0.76435621 0.08186395 0.46690741
#  0.02811787 0.10307037]
# Biggest difference: 0.4413716189486339
# Smallest difference: 0.014058934108757777
# Fixed eps is not success
#
# min_eps = [0.40927489 0.47859962 0.66205743 0.57326716 0.06139796 0.35018056
#  0.0210884  0.07730278]
# cur_eps = [0.47748737 0.55836622 0.77240033 0.66881168 0.07163095 0.40854399
#  0.02460313 0.09018658]
# max_eps = [0.54569985 0.63813283 0.88274324 0.76435621 0.08186395 0.46690741
#  0.02811787 0.10307037]
# Biggest difference: 0.22068580947431693
# Smallest difference: 0.007029467054378888
# Fixed eps is not success
#
# min_eps = [0.47748737 0.55836622 0.77240033 0.66881168 0.07163095 0.40854399
#  0.02460313 0.09018658]
# cur_eps = [0.51159361 0.59824952 0.82757179 0.71658394 0.07674745 0.4377257
#  0.0263605  0.09662847]
# max_eps = [0.54569985 0.63813283 0.88274324 0.76435621 0.08186395 0.46690741
#  0.02811787 0.10307037]
# Biggest difference: 0.11034290473715846
# Smallest difference: 0.003514733527189444
# Fixed eps is not success
#
# min_eps = [0.51159361 0.59824952 0.82757179 0.71658394 0.07674745 0.4377257
#  0.0263605  0.09662847]
# cur_eps = [0.52864673 0.61819117 0.85515751 0.74047008 0.0793057  0.45231656
#  0.02723918 0.09984942]
# max_eps = [0.54569985 0.63813283 0.88274324 0.76435621 0.08186395 0.46690741
#  0.02811787 0.10307037]
# Biggest difference: 0.05517145236857923
# Smallest difference: 0.001757366763594722
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0. 0. 0.]
# cur_eps = [0.10126563 0.10152282 0.41937828 0.35934046 0.03965285 0.11559706
#  0.01361959 0.04992471]
# max_eps = [0.20253126 0.20304563 0.83875657 0.71868092 0.0793057  0.23119412
#  0.02723918 0.09984942]
# Biggest difference: 0.8387565699091832
# Smallest difference: 0.027239184844891056
# Fixed eps is not success
#
# min_eps = [0.10126563 0.10152282 0.41937828 0.35934046 0.03965285 0.11559706
#  0.01361959 0.04992471]
# cur_eps = [0.15189844 0.15228422 0.62906743 0.53901069 0.05947927 0.17339559
#  0.02042939 0.07488707]
# max_eps = [0.20253126 0.20304563 0.83875657 0.71868092 0.0793057  0.23119412
#  0.02723918 0.09984942]
# Biggest difference: 0.4193782849545916
# Smallest difference: 0.013619592422445528
# Fixed eps is not success
#
# min_eps = [0.15189844 0.15228422 0.62906743 0.53901069 0.05947927 0.17339559
#  0.02042939 0.07488707]
# cur_eps = [0.17721485 0.17766493 0.733912   0.62884581 0.06939249 0.20229486
#  0.02383429 0.08736825]
# max_eps = [0.20253126 0.20304563 0.83875657 0.71868092 0.0793057  0.23119412
#  0.02723918 0.09984942]
# Biggest difference: 0.20968914247729575
# Smallest difference: 0.006809796211222765
# Fixed eps is not success
#
# min_eps = [0.17721485 0.17766493 0.733912   0.62884581 0.06939249 0.20229486
#  0.02383429 0.08736825]
# cur_eps = [0.18987305 0.19035528 0.78633428 0.67376336 0.07434909 0.21674449
#  0.02553674 0.09360883]
# max_eps = [0.20253126 0.20304563 0.83875657 0.71868092 0.0793057  0.23119412
#  0.02723918 0.09984942]
# Biggest difference: 0.10484457123864788
# Smallest difference: 0.0034048981056113807
# Fixed eps is not success
#
# min_eps = [0.18987305 0.19035528 0.78633428 0.67376336 0.07434909 0.21674449
#  0.02553674 0.09360883]
# cur_eps = [0.19620215 0.19670046 0.81254543 0.69622214 0.07682739 0.2239693
#  0.02638796 0.09672913]
# max_eps = [0.20253126 0.20304563 0.83875657 0.71868092 0.0793057  0.23119412
#  0.02723918 0.09984942]
# Biggest difference: 0.05242228561932394
# Smallest difference: 0.0017024490528056886
# Fixed eps is not success
#
# min_eps = [0.19620215 0.19670046 0.81254543 0.69622214 0.07682739 0.2239693
#  0.02638796 0.09672913]
# cur_eps = [0.19936671 0.19987305 0.825651   0.70745153 0.07806655 0.22758171
#  0.02681357 0.09828928]
# max_eps = [0.20253126 0.20304563 0.83875657 0.71868092 0.0793057  0.23119412
#  0.02723918 0.09984942]
# Biggest difference: 0.02621114280966197
# Smallest difference: 0.000851224526402846
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0. 0. 0.]
# cur_eps = [0.00792769 0.00776438 0.4057046  0.34064884 0.03903327 0.00882569
#  0.01340679 0.04914464]
# max_eps = [0.01585537 0.01552876 0.81140921 0.68129769 0.07806655 0.01765138
#  0.02681357 0.09828928]
# Biggest difference: 0.8114092070176097
# Smallest difference: 0.01552875879671409
# Fixed eps is not success
#
# min_eps = [0.00792769 0.00776438 0.4057046  0.34064884 0.03903327 0.00882569
#  0.01340679 0.04914464]
# cur_eps = [0.01189153 0.01164657 0.60855691 0.51097326 0.05854991 0.01323854
#  0.02011018 0.07371696]
# max_eps = [0.01585537 0.01552876 0.81140921 0.68129769 0.07806655 0.01765138
#  0.02681357 0.09828928]
# Biggest difference: 0.40570460350880483
# Smallest difference: 0.007764379398357045
# Fixed eps is not success
#
# min_eps = [0.01189153 0.01164657 0.60855691 0.51097326 0.05854991 0.01323854
#  0.02011018 0.07371696]
# cur_eps = [0.01387345 0.01358766 0.70998306 0.59613547 0.06830823 0.01544496
#  0.02346188 0.08600312]
# max_eps = [0.01585537 0.01552876 0.81140921 0.68129769 0.07806655 0.01765138
#  0.02681357 0.09828928]
# Biggest difference: 0.2028523017544024
# Smallest difference: 0.003882189699178522
# Fixed eps is not success
#
# min_eps = [0.01387345 0.01358766 0.70998306 0.59613547 0.06830823 0.01544496
#  0.02346188 0.08600312]
# cur_eps = [0.01486441 0.01455821 0.76069613 0.63871658 0.07318739 0.01654817
#  0.02513773 0.0921462 ]
# max_eps = [0.01585537 0.01552876 0.81140921 0.68129769 0.07806655 0.01765138
#  0.02681357 0.09828928]
# Biggest difference: 0.1014261508772012
# Smallest difference: 0.001941094849589261
# Fixed eps is not success
#
# min_eps = [0.01486441 0.01455821 0.76069613 0.63871658 0.07318739 0.01654817
#  0.02513773 0.0921462 ]
# cur_eps = [0.01535989 0.01504349 0.78605267 0.66000713 0.07562697 0.01709978
#  0.02597565 0.09521774]
# max_eps = [0.01585537 0.01552876 0.81140921 0.68129769 0.07806655 0.01765138
#  0.02681357 0.09828928]
# Biggest difference: 0.0507130754386006
# Smallest difference: 0.0009705474247946305
# Fixed eps is not success
#
# min_eps = [0.01535989 0.01504349 0.78605267 0.66000713 0.07562697 0.01709978
#  0.02597565 0.09521774]
# cur_eps = [0.01560763 0.01528612 0.79873094 0.67065241 0.07684676 0.01737558
#  0.02639461 0.09675351]
# max_eps = [0.01585537 0.01552876 0.81140921 0.68129769 0.07806655 0.01765138
#  0.02681357 0.09828928]
# Biggest difference: 0.025356537719300243
# Smallest difference: 0.0004852737123973161
# Fixed eps is not success
#
# min_eps = [0.01560763 0.01528612 0.79873094 0.67065241 0.07684676 0.01737558
#  0.02639461 0.09675351]
# cur_eps = [0.0157315  0.01540744 0.80507007 0.67597505 0.07745665 0.01751348
#  0.02660409 0.09752139]
# max_eps = [0.01585537 0.01552876 0.81140921 0.68129769 0.07806655 0.01765138
#  0.02681357 0.09828928]
# Biggest difference: 0.012678268859650177
# Smallest difference: 0.00024263685619865805
# Fixed eps is not success
#
# min_eps = [0.0157315  0.01540744 0.80507007 0.67597505 0.07745665 0.01751348
#  0.02660409 0.09752139]
# cur_eps = [0.01579344 0.0154681  0.80823964 0.67863637 0.0777616  0.01758243
#  0.02670883 0.09790533]
# max_eps = [0.01585537 0.01552876 0.81140921 0.68129769 0.07806655 0.01765138
#  0.02681357 0.09828928]
# Biggest difference: 0.006339134429825033
# Smallest difference: 0.00012131842809932902
# Fixed eps is success
# Fixed mults is success
#
# min_eps = [0. 0. 0. 0. 0. 0. 0. 0.]
# cur_eps = [0.00576675 0.00551282 0.39625672 0.32261802 0.0388808  0.00631909
#  0.01335442 0.04895267]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.7925134476397075
# Smallest difference: 0.01102563390595781
# Fixed eps is not success
#
# min_eps = [0.00576675 0.00551282 0.39625672 0.32261802 0.0388808  0.00631909
#  0.01335442 0.04895267]
# cur_eps = [0.00865012 0.00826923 0.59438509 0.48392703 0.0583212  0.00947864
#  0.02003163 0.073429  ]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.3962567238198538
# Smallest difference: 0.005512816952978905
# Fixed eps is not success
#
# min_eps = [0.00865012 0.00826923 0.59438509 0.48392703 0.0583212  0.00947864
#  0.02003163 0.073429  ]
# cur_eps = [0.01009181 0.00964743 0.69344927 0.56458154 0.0680414  0.01105842
#  0.02337023 0.08566717]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.1981283619099269
# Smallest difference: 0.002756408476489452
# Fixed eps is not success
#
# min_eps = [0.01009181 0.00964743 0.69344927 0.56458154 0.0680414  0.01105842
#  0.02337023 0.08566717]
# cur_eps = [0.01081265 0.01033653 0.74298136 0.60490879 0.0729015  0.0118483
#  0.02503953 0.09178625]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.0990641809549635
# Smallest difference: 0.0013782042382447252
# Fixed eps is not success
#
# min_eps = [0.01081265 0.01033653 0.74298136 0.60490879 0.0729015  0.0118483
#  0.02503953 0.09178625]
# cur_eps = [0.01117307 0.01068108 0.7677474  0.62507242 0.07533155 0.01224325
#  0.02587419 0.09484579]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.04953209047748175
# Smallest difference: 0.0006891021191223635
# Fixed eps is not success
#
# min_eps = [0.01117307 0.01068108 0.7677474  0.62507242 0.07533155 0.01224325
#  0.02587419 0.09484579]
# cur_eps = [0.01135329 0.01085336 0.78013043 0.63515423 0.07654657 0.01244072
#  0.02629151 0.09637557]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.02476604523874082
# Smallest difference: 0.0003445510595611826
# Fixed eps is not success
#
# min_eps = [0.01135329 0.01085336 0.78013043 0.63515423 0.07654657 0.01244072
#  0.02629151 0.09637557]
# cur_eps = [0.01144339 0.0109395  0.78632194 0.64019514 0.07715409 0.01253945
#  0.02650017 0.09714045]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.01238302261937041
# Smallest difference: 0.00017227552978059217
# Fixed eps is not success
#
# min_eps = [0.01144339 0.0109395  0.78632194 0.64019514 0.07715409 0.01253945
#  0.02650017 0.09714045]
# cur_eps = [0.01148844 0.01098257 0.78941769 0.64271559 0.07745784 0.01258882
#  0.02660451 0.09752289]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.006191511309685205
# Smallest difference: 8.613776489029522e-05
# Fixed eps is not success
#
# min_eps = [0.01148844 0.01098257 0.78941769 0.64271559 0.07745784 0.01258882
#  0.02660451 0.09752289]
# cur_eps = [0.01151097 0.0110041  0.79096557 0.64397582 0.07760972 0.01261351
#  0.02665667 0.09771411]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.003095755654842547
# Smallest difference: 4.306888244514674e-05
# Fixed eps is not success
#
# min_eps = [0.01151097 0.0110041  0.79096557 0.64397582 0.07760972 0.01261351
#  0.02665667 0.09771411]
# cur_eps = [0.01152223 0.01101487 0.79173951 0.64460593 0.07768566 0.01262585
#  0.02668275 0.09780973]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.0015478778274212734
# Smallest difference: 2.1534441222574238e-05
# Fixed eps is not success
#
# min_eps = [0.01152223 0.01101487 0.79173951 0.64460593 0.07768566 0.01262585
#  0.02668275 0.09780973]
# cur_eps = [0.01152786 0.01102025 0.79212648 0.64492099 0.07772363 0.01263202
#  0.0266958  0.09785753]
# max_eps = [0.0115335  0.01102563 0.79251345 0.64523604 0.0777616  0.01263819
#  0.02670884 0.09790534]
# Biggest difference: 0.0007739389137106922
# Smallest difference: 1.0767220611286252e-05
# Fixed eps is not success
#
# Completed Region 6/6 in 53.516930103302s
#
# Total time to certify = 304.0252254009247s

# %%
# uncomment to visualize planes (TODO)
# visualizer.region_to_collision_pair_to_plane_dictionary = iris_generator.linesearch_regions_to_certificates_by_collision_pair_map

# %%
do_alt_cert = True
if do_alt_cert:
    iris_generator.certify_and_adjust_regions_by_bilinear_alternation(max_iter = 1000, 
                                                                 stopped_improving_count_threshold = 5,
                                                                 not_improving_threshold = 1e-4)
# Out:
# Starting Region 1/6
# iter 0/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.73205081 3.31720902 0.21664655 1.73205081 0.14689259 3.1431908 ]
# Improvement 0.10426427066397319
# iter 10/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.51218244 3.30523328 0.17057381 0.73758415 0.14689259 2.65998685]
# Improvement 0.5305377038298164
# iter 20/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.08032016 3.10716154 0.06966456 0.06089033 0.06712827 2.58579345]
# Improvement 0.021140962448768758
# iter 30/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.05276473 2.95748536 0.04661461 0.03967758 0.0469623  2.52146813]
# Improvement 0.014987268338882712
# iter 40/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.0332597  2.83493678 0.0299659  0.02501605 0.03132887 2.50162385]
# Improvement 0.011037746365975305
# iter 50/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.02144302 2.74451625 0.01939793 0.01590539 0.01995039 2.49646023]
# Improvement 0.008083574419157207
# iter 60/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.01463628 2.6877381  0.01277079 0.01069139 0.01301783 2.4881028 ]
# Improvement 0.004260673500541937
# iter 70/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.01060452 2.66046896 0.00861702 0.00774409 0.00860236 2.47023613]
# Improvement 0.002782608539259794
# iter 80/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.00834793 2.64165536 0.00684551 0.00605979 0.0067923  2.45466682]
# Improvement 0.002242334165352271
# iter 90/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.00658302 2.62573479 0.00537714 0.00469492 0.00533389 2.44170538]
# Improvement 0.0019323519604759125
# iter 100/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.00536773 2.61278059 0.00453771 0.00389546 0.00452766 2.43079164]
# Improvement 0.001537759964157478
# iter 110/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.00433762 2.60235297 0.00370916 0.00309394 0.0036386  2.42181868]
# Improvement 0.0012740798223612676
# iter 120/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [3.47548990e-03 2.59365824e+00 2.89406469e-03 2.38334520e-03
#  2.75130063e-03 2.41432802e+00]
# Improvement 0.0010510477108030664
# iter 130/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.91690888e-03 2.58627357e+00 2.40987304e-03 1.92319689e-03
#  2.27054018e-03 2.40797327e+00]
# Improvement 0.0008874596422368866
# iter 140/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.06435429e-03 2.58048901e+00 1.65839556e-03 1.31896625e-03
#  1.54161171e-03 2.40257395e+00]
# Improvement 0.000694317045707669
# iter 150/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.45239855e-03 2.57561832e+00 1.17435240e-03 8.29332456e-04
#  1.03685718e-03 2.39833036e+00]
# Improvement 0.000601015640380006
# iter 160/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [6.88342313e-04 2.57110113e+00 4.70890503e-04 1.25513007e-04
#  3.01293558e-04 2.39454997e+00]
# Improvement 0.0006185207624561462
# iter 170/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.22511435e-04 2.56709468e+00 5.32292450e-05 3.89343511e-07
#  1.07751118e-05 2.39109572e+00]
# Improvement 0.0004586367486534564
# iter 180/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.48383567e-04 2.56359208e+00 2.67085817e-08 3.13569588e-10
#  9.34419475e-09 2.38793764e+00]
# Improvement 0.0004380892521249608
# iter 190/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.84256336e-08 2.56054633e+00 2.34180141e-11 3.06220300e-13
#  9.12519019e-12 2.38521155e+00]
# Improvement 0.00038846499118449796
# iter 200/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [7.93298070e-12 2.55795688e+00 2.28691544e-14 2.99043262e-16
#  8.91131854e-15 2.38276884e+00]
# Improvement 0.00033821995049090767
# iter 210/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [7.74705147e-15 2.55573097e+00 2.23331586e-17 2.92034436e-19
#  8.70245951e-18 2.38057402e+00]
# Improvement 0.00029596890575831326
# iter 220/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [7.56547995e-18 2.55379687e+00 2.18097252e-20 2.85189879e-22
#  8.49849562e-21 2.37863482e+00]
# Improvement 0.00026385195867294886
# iter 230/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [7.38816401e-21 2.55203859e+00 2.12985597e-23 2.78505741e-25
#  8.29931213e-24 2.37696804e+00]
# Improvement 0.00023307145843868264
# iter 240/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [7.21500392e-24 2.55046123e+00 2.07993747e-26 2.71978263e-28
#  8.10479700e-27 2.37543732e+00]
# Improvement 0.00020663825968564073
# iter 250/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [7.04590226e-27 2.54916031e+00 2.03118894e-29 2.65603772e-31
#  7.91484082e-30 2.37400056e+00]
# Improvement 0.000179500464168123
# iter 260/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [6.88076393e-30 2.54799260e+00 1.98358295e-32 2.59378684e-34
#  7.72933674e-33 2.37276008e+00]
# Improvement 0.0001772546294650554
# iter 270/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [6.71949602e-33 2.54690616e+00 1.93709272e-35 2.53299496e-37
#  7.54818041e-36 2.37168585e+00]
# Improvement 0.00014858886484203607
# iter 280/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [6.56200784e-36 2.54589255e+00 1.89169211e-38 2.47362789e-40
#  7.37126993e-39 2.37068526e+00]
# Improvement 0.00013705644493958006
# iter 290/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [6.40821078e-39 2.54483346e+00 1.84735558e-41 2.41565223e-43
#  7.19850579e-42 2.36989268e+00]
# Improvement 0.0001330985613856849
# iter 300/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [6.25801834e-42 2.54398749e+00 1.80405818e-44 2.35903538e-46
#  7.02979081e-45 2.36903387e+00]
# Improvement 0.00011584794832290168
# iter 310/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [6.11134603e-45 2.54322089e+00 1.76177557e-47 2.30374549e-49
#  6.86503009e-48 2.36824690e+00]
# Improvement 0.00010525957880525472
# iter 320/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [5.96811136e-48 2.54251221e+00 1.72048395e-50 2.24975146e-52
#  6.70413095e-51 2.36752704e+00]
# Improvement 9.733486189302359e-05
# Completed Region 1/6 in 429.54643750190735s
#
# Starting Region 2/6
# iter 0/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.2783533  3.20022191 1.47670889 1.18574832 0.17464308 1.98739273]
# Improvement 0.08923661866018273
# iter 10/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.27835326 1.50073766 1.36214602 1.18226203 0.17464308 1.17560592]
# Improvement 0.20415891364687813
# iter 20/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.27835322 1.44335937 0.05254305 1.18226201 0.06519439 0.43157817]
# Improvement 0.12387058242952803
# iter 30/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.27835318 0.5619704  0.0525429  1.182262   0.03734314 0.09687382]
# Improvement 0.12279281889738142
# iter 40/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.19660642 0.09993735 0.02357675 1.1768472  0.02066473 0.02420249]
# Improvement 0.012558943260609046
# iter 50/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.1078507  0.09422908 0.02357663 1.10072862 0.02066468 0.02050379]
# Improvement 0.011020698591694874
# iter 60/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.04820213 0.07693578 0.0235765  1.03387113 0.0206646  0.01493874]
# Improvement 0.008320887680632296
# iter 70/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [2.00573738 0.07693268 0.02357642 0.95003704 0.02066455 0.01493864]
# Improvement 0.010177501961526456
# iter 80/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.97418802 0.07693195 0.02357627 0.84056077 0.02066444 0.01493859]
# Improvement 0.01268463756730489
# iter 90/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.94893578 0.07693174 0.02357616 0.70374935 0.02066437 0.01493855]
# Improvement 0.015000186898203451
# iter 100/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.92885451 0.07693126 0.02357568 0.54600915 0.02066417 0.01493842]
# Improvement 0.017157487885932916
# iter 110/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.91226917 0.07693053 0.02357444 0.36393952 0.02066395 0.01493825]
# Improvement 0.019129646309580486
# iter 120/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.8992242  0.05237393 0.01346718 0.16723516 0.02066355 0.01493753]
# Improvement 0.021448257426609846
# iter 130/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.88891443e+00 1.00431215e-02 1.83393265e-03 1.80682169e-03
#  2.06632927e-02 1.82585879e-03]
# Improvement 0.002603226193921834
# iter 140/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.87930066e+00 9.10165609e-03 1.48406710e-03 1.35649360e-03
#  2.06624135e-02 1.43148974e-03]
# Improvement 0.0008595839044336222
# iter 150/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.87103574e+00 8.52031573e-03 1.23452915e-03 1.14653564e-03
#  2.06608496e-02 1.18810293e-03]
# Improvement 0.0008076887171110576
# iter 160/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.86360620e+00 7.92250722e-03 1.04184683e-03 1.00582058e-03
#  1.64846491e-02 9.86805624e-04]
# Improvement 0.0017557091335560022
# iter 170/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.85733598e+00 7.72273969e-03 8.13135764e-04 8.56552337e-04
#  2.32422953e-03 7.87079517e-04]
# Improvement 0.0006214749606241336
# iter 180/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.85190351e+00 7.26401246e-03 6.45267439e-04 7.23126787e-04
#  1.82653428e-03 6.30998030e-04]
# Improvement 0.0005403763374526552
# iter 190/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.84677937e+00 6.55493455e-03 5.16173886e-04 6.39431995e-04
#  1.65135269e-03 5.06533679e-04]
# Improvement 0.0005179558665336408
# iter 200/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.84206098e+00 5.85221950e-03 4.08529580e-04 5.50878308e-04
#  1.50935303e-03 4.02141749e-04]
# Improvement 0.00046232877478238205
# iter 210/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.83775975e+00 5.30529636e-03 1.95755714e-04 4.22874236e-04
#  1.18041136e-03 1.79873628e-04]
# Improvement 0.0004209676996641825
# iter 220/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.83380599e+00 4.99043088e-03 4.42320947e-07 3.42961478e-04
#  9.05442389e-04 4.10421891e-07]
# Improvement 0.00038274055734380876
# iter 230/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.83024271e+00 4.94132644e-03 9.78332781e-11 3.30610904e-04
#  7.71343756e-04 1.35978022e-10]
# Improvement 0.0003426278643229529
# iter 240/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.82704902e+00 4.92524686e-03 9.55403106e-14 3.24764504e-04
#  6.41381323e-04 1.32791037e-13]
# Improvement 0.0003014227205346311
# iter 250/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.82422348e+00 4.91573381e-03 9.33010846e-17 3.20753527e-04
#  5.62250781e-04 1.29678747e-16]
# Improvement 0.0002611153634814636
# iter 260/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.82177353e+00 4.91356748e-03 9.11143404e-20 3.19738176e-04
#  5.36030885e-04 1.26639401e-19]
# Improvement 0.00023516990397544693
# iter 270/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.81974106e+00 4.91319743e-03 8.89788481e-23 3.19503652e-04
#  5.28605575e-04 1.23671290e-22]
# Improvement 0.00019084838924609374
# iter 280/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.81803160e+00 4.91285119e-03 8.68934063e-26 3.19265401e-04
#  5.19975329e-04 1.20772744e-25]
# Improvement 0.0001658660545769358
# iter 290/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.81648295e+00 4.91115512e-03 8.48568421e-29 3.18031605e-04
#  4.64640596e-04 1.17942133e-28]
# Improvement 0.00015254587168420656
# iter 300/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.81503176e+00 4.90837251e-03 8.28680099e-32 3.15535879e-04
#  3.95340098e-04 1.15177865e-31]
# Improvement 0.00013680840633994583
# iter 310/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.81370450e+00 4.90452882e-03 8.09257909e-35 3.12995110e-04
#  3.11536362e-04 1.12478383e-34]
# Improvement 0.00012794766596217077
# iter 320/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.81243793e+00 4.90187324e-03 7.90290927e-38 3.11126477e-04
#  2.78882430e-04 1.09842171e-37]
# Improvement 0.00012477565273070405
# iter 330/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.81125092e+00 4.89978229e-03 7.71768483e-41 3.09523605e-04
#  2.50945220e-04 1.07267745e-40]
# Improvement 0.00011780935983148335
# iter 340/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.81012712e+00 4.89819867e-03 7.53680159e-44 3.08307236e-04
#  2.48227206e-04 1.04753658e-43]
# Improvement 0.00010769805358126612
# iter 350/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.80907302e+00 4.89791402e-03 7.36015780e-47 3.08072513e-04
#  2.46127216e-04 1.02298494e-46]
# Improvement 0.00010245503756238592
# Completed Region 2/6 in 447.63696336746216s
#
# Starting Region 3/6
# iter 0/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.56839207 2.15484403 1.47670889 1.88318603 1.30925759 1.98739273
#  0.18819386 0.05764061 0.05693344 0.06506144 0.03529044]
# Improvement 0.012523515293753746
# iter 10/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.02594576 2.15484398 1.00570503 1.88318599 1.30925757 1.64398454
#  0.18819386 0.05764061 0.05693344 0.06506144 0.03529044]
# Improvement 0.23448403722954517
# iter 20/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.0259455  2.15484391 0.05372049 1.88318588 0.8302796  1.07076088
#  0.18819385 0.05764061 0.05693345 0.06506144 0.03529044]
# Improvement 0.2642371858559958
# iter 30/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.02594355 1.96737359 0.02865825 1.82921625 0.03766898 1.06933817
#  0.18819386 0.05764059 0.05693344 0.06506144 0.03529043]
# Improvement 0.026072825756129615
# iter 40/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.02124799 1.75480603 0.0212333  1.79693889 0.01997863 1.06933814
#  0.18819386 0.05764047 0.05693344 0.06506144 0.03529038]
# Improvement 0.015319805450212534
# iter 50/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.01105282 1.6559257  0.01170538 1.75990278 0.01127469 1.06933811
#  0.18819386 0.04170335 0.05693344 0.06506144 0.0352903 ]
# Improvement 0.008593980785698695
# iter 60/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.00457036 1.60264354 0.00357096 1.74067353 0.00440086 1.06362184
#  0.18766766 0.01294229 0.05693343 0.06506144 0.0183249 ]
# Improvement 0.007867646958439204
# iter 70/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.0025039  1.5701094  0.00189814 1.74067347 0.0023543  1.06362178
#  0.00525194 0.00662169 0.05605681 0.06506144 0.00820844]
# Improvement 0.002797232289951713
# iter 80/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.55520496e-03 1.54822403e+00 1.14839882e-03 1.74067341e+00
#  1.43030969e-03 1.06362173e+00 3.23817416e-03 4.00846226e-03
#  5.46588954e-02 6.50614406e-02 4.85378725e-03]
# Improvement 0.0018188894784035153
# iter 90/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [8.90504301e-04 1.53479818e+00 6.43606707e-04 1.74067335e+00
#  8.05134262e-04 1.06362166e+00 1.86686432e-03 2.27545580e-03
#  5.37267088e-02 6.50614382e-02 2.70392001e-03]
# Improvement 0.0010696473717532794
# iter 100/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [4.21253563e-04 1.52736168e+00 2.84312153e-04 1.74067326e+00
#  3.71175003e-04 1.06362157e+00 9.35327234e-04 1.13835260e-03
#  5.31816303e-02 6.50614401e-02 1.34628005e-03]
# Improvement 0.0005641207754449122
# iter 110/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.20521327e-04 1.52362164e+00 7.56913972e-05 1.74067319e+00
#  1.03102653e-04 1.06362148e+00 3.52746730e-04 4.47202186e-04
#  5.28992033e-02 6.50614388e-02 5.45539272e-04]
# Improvement 0.00027537610853988934
# iter 120/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.16121677e-06 1.52188910e+00 3.26117110e-07 1.74067317e+00
#  6.81463752e-07 1.06362145e+00 1.29862406e-04 1.84433169e-04
#  5.27663997e-02 6.50614373e-02 2.31706912e-04]
# Improvement 0.00012085154456954248
# iter 130/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.25155346e-09 1.52111773e+00 3.32236611e-10 1.74067316e+00
#  7.10815528e-10 1.06362142e+00 6.70221890e-06 2.57549339e-05
#  5.27071292e-02 6.50614369e-02 5.19300369e-05]
# Improvement 5.978038302131021e-05
# Completed Region 3/6 in 246.51854729652405s
#
# Starting Region 4/6
# iter 0/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.60639567 2.76027681 1.85770594 1.85770594 0.70241225 1.60639567
#  0.18527251 0.05397811 0.07390459 0.05357686 0.07474873 0.04829697
#  0.03983942 0.07230074 0.06943746]
# Improvement 0.0014125497350461777
# iter 10/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.60639562 0.00601882 1.85770592 1.85770586 0.70241225 1.564913
#  0.18527251 0.05397811 0.07390459 0.05357686 0.07474873 0.04829697
#  0.03983942 0.07230074 0.06943746]
# Improvement 0.027225817151967965
# iter 20/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.60639561 0.00597027 1.85770591 1.60077199 0.70241225 0.00892978
#  0.18527251 0.05397811 0.07390459 0.05357686 0.07474873 0.04829697
#  0.03983942 0.07230074 0.06943746]
# Improvement 0.13891300688430963
# iter 30/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.54685232 0.0028595  1.83273181 0.00395687 0.70241224 0.00390557
#  0.18527251 0.05397811 0.07390459 0.05357686 0.07474873 0.04829696
#  0.03983942 0.07230074 0.06943746]
# Improvement 0.03507533922412995
# iter 40/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.01241561 0.00285918 1.75950945 0.00395662 0.70241224 0.00390535
#  0.18527251 0.05397811 0.07390459 0.05357686 0.07474873 0.04829696
#  0.03983942 0.07230074 0.06943746]
# Improvement 0.016375863981923346
# Completed Region 4/6 in 133.9484508037567s
#
# Starting Region 5/6
# iter 0/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.69703651 2.99141324 1.83238548 1.76706511 0.47189259 1.63171614
#  0.04869908 0.20435335 0.0672561 ]
# Improvement 0.0007957830931639374
# iter 10/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.69695452 0.01905967 1.83238546 1.76706508 0.47189259 1.53041177
#  0.04869908 0.20435335 0.0672561 ]
# Improvement 0.05702111331033019
# iter 20/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [1.66149102 0.00648404 1.83190344 1.64797407 0.47189258 0.01046181
#  0.04869908 0.20435335 0.0672561 ]
# Improvement 0.03520843035072513
# iter 30/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.04195641 0.00648368 1.82772464 0.90866507 0.47189251 0.01046167
#  0.04869909 0.20435334 0.06725588]
# Improvement 0.09644341900255239
# iter 40/1000
# Fixed eps is success = True
# Fixed mult program is success = True
# Cur eps is
# [0.0073849  0.00646966 1.81300634 0.3535561  0.36550282 0.01046084
#  0.04869908 0.20435332 0.06725583]
# Improvement 0.033154668087668294

# %%
# plot new regions
if do_viz:
    if do_alt_cert:
        visualizer.plot_regions(iris_generator.alternation_search_regions, region_suffix = '_new_by_alternation')
    if do_linesearch_cert:
        visualizer.plot_regions(iris_generator.linesearch_regions, region_suffix = '_new_by_linesearch')

# %%
from pydrake.all import BsplineTrajectoryThroughUnionOfHPolyhedra
# Solve path planning
start_time = time.time()
# trajectory through linesearch_regions
spp = BsplineTrajectoryThroughUnionOfHPolyhedra(trajectory_start.squeeze(), trajectory_end.squeeze(), 
                                                iris_generator.linesearch_regions)
spp.set_max_velocity(0.3*np.ones(plant.num_positions()))
spp.set_extra_control_points_per_region(3)
traj_iris = spp.SolveVerbose()
visualizer.draw_traj_tspace(traj_iris, 100, 'iris')

# %%
print(time.time() - start_time)
print(traj_iris.start_time())
print(traj_iris.end_time())
# draw_traj_tspace(traj_iris, 100, 'iris')
#animate Iris + spp sol
substeps = 1000
its = 10
visualizer.animate_t(traj_iris, substeps, its*substeps)
